# %%
import os
import re
import datetime
import time
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## <font color=#c51b8a>Amino Acid Property Analysis: (Part 1)</font>
# ### A pre-grid-search analysis of the best amino acid properties combinations for training ML models on different opsin datasets...

# %%
report_dir = './vpod_1.2/aa_prop_combos_analysis_2024-12-16_16-57-42'

# %% [markdown]
# ### <font color=#c994c7>Whole Dataset (WDS)</font>

# %%
wds_file = f'{report_dir}/wds_aa_prop_combos_results.csv'
wds_df = pd.read_csv(wds_file)
wds_df.head()
# Out:
#   Dataset Props_Used          Model        R2       MAE      MAPE         MSE  \
# 0     wds        H1_            xgb  0.964836  6.004033  0.013601  134.073611
# 1     wds        H1_            gbr  0.963463  6.328310  0.014547  138.600034
# 2     wds        H1_             rf  0.962085  5.862054  0.013251  143.891148
# 3     wds        H1_  BayesianRidge  0.945354  9.771495  0.022451  207.011990
# 4     wds        H2_            xgb  0.961466  5.894490  0.013388  146.704646
#
#         RMSE
# 0  11.315286
# 1  11.554425
# 2  11.762819
# 3  14.311313
# 4  11.822667

# %%
wds_df_filtered = wds_df.copy()
wds_df_filtered.sort_values('R2',ascending=False,inplace=True)
wds_df_filtered.reset_index(inplace=True, drop=True)
wds_df_filtered['Ranked_By'] = 'R2'
wds_df_filtered.head()
# Out:
#   Dataset                          Props_Used Model        R2       MAE  \
# 0     wds  H1_H2_H3_P1_P2_V_SASA_SCT_PKA_PKB_   gbr  0.968836  5.815975
# 1     wds              H1_H2_H3_P2_V_SCT_PKA_   xgb  0.968700  5.584713
# 2     wds     H1_H2_H3_P1_P2_V_MASS_SASA_SCT_   gbr  0.968699  5.937826
# 3     wds            H1_H2_NCI_MASS_SASA_PKB_   gbr  0.968595  5.883918
# 4     wds         H1_H2_H3_MASS_SASA_SCT_PKB_   gbr  0.968479  5.736124
#
#        MAPE         MSE       RMSE Ranked_By
# 0  0.013326  118.476535  10.772182        R2
# 1  0.012641  119.005642  10.694938        R2
# 2  0.013603  118.399741  10.729280        R2
# 3  0.013509  119.665746  10.794597        R2
# 4  0.013116  119.719386  10.731194        R2

# %%
wds_df_filtered2 = wds_df.copy()
wds_df_filtered2.sort_values('MAE',ascending=True,inplace=True)
wds_df_filtered2.reset_index(inplace=True, drop=True)
wds_df_filtered2['Ranked_By'] = 'MAE'
wds_df_filtered2.head()
# Out:
#   Dataset               Props_Used Model        R2       MAE      MAPE  \
# 0     wds               H1_P2_SCT_    rf  0.963549  5.525469  0.012328
# 1     wds             H1_SASA_SCT_    rf  0.963176  5.536853  0.012377
# 2     wds            H2_P2_V_SASA_   xgb  0.967122  5.539737  0.012535
# 3     wds  H1_H2_H3_P2_V_SASA_SCT_   xgb  0.967100  5.541833  0.012525
# 4     wds       H1_H2_H3_P2_V_SCT_   xgb  0.967439  5.546996  0.012525
#
#           MSE       RMSE Ranked_By
# 0  137.938787  11.372965       MAE
# 1  139.214654  11.436566       MAE
# 2  125.168998  10.963956       MAE
# 3  124.945831  10.868227       MAE
# 4  123.751668  10.785951       MAE

# %%
top_aa_prop_df = pd.concat([wds_df_filtered[0:5], wds_df_filtered2[0:5]], ignore_index=True)

# %% [markdown]
# ### <font color=#c994c7>Wild-Type Dataset (WT)</font>

# %%
wt_file = f'{report_dir}/wt_aa_prop_combos_results.csv'
wt_df = pd.read_csv(wt_file)
wt_df.head()
# Out:
#   Dataset Props_Used          Model        R2        MAE      MAPE  \
# 0      wt        H1_             rf  0.922910   8.601873  0.018920
# 1      wt        H1_            gbr  0.920426   8.475219  0.018695
# 2      wt        H1_  BayesianRidge  0.910199  11.172247  0.024392
# 3      wt        H1_            xgb  0.897170   9.556674  0.020886
# 4      wt        H2_             rf  0.915391   9.198966  0.020216
#
#           MSE       RMSE
# 0  234.212181  14.770771
# 1  240.593545  14.968405
# 2  261.090311  16.063695
# 3  311.024303  17.181301
# 4  258.077694  15.423515

# %%
wt_df_filtered = wt_df.copy()
wt_df_filtered.sort_values('R2',ascending=False,inplace=True)
wt_df_filtered.reset_index(inplace=True, drop=True)
wt_df_filtered['Ranked_By'] = 'R2'
wt_df_filtered.head()
# Out:
#   Dataset                      Props_Used Model        R2       MAE      MAPE  \
# 0      wt               H1_H3_P1_NCI_PKA_   gbr  0.939306  7.988286  0.017367
# 1      wt               H2_H3_P1_NCI_PKA_   gbr  0.939214  8.014395  0.017276
# 2      wt      H1_P1_P2_NCI_MASS_PKA_PKB_   gbr  0.938709  8.195275  0.017629
# 3      wt        H1_H2_H3_P1_NCI_SCT_PKB_   gbr  0.938494  7.955590  0.017264
# 4      wt  H1_H2_H3_P1_MASS_SASA_PKA_PKB_   gbr  0.938227  7.901994  0.016949
#
#           MSE       RMSE Ranked_By
# 0  176.983955  13.128133        R2
# 1  180.659277  13.045880        R2
# 2  181.608472  13.255662        R2
# 3  179.503400  13.233635        R2
# 4  185.298178  13.198679        R2

# %%
wt_df_filtered2 = wt_df.copy()
wt_df_filtered2.sort_values('MAE',ascending=True,inplace=True)
wt_df_filtered2.reset_index(inplace=True, drop=True)
wt_df_filtered2['Ranked_By'] = 'MAE'
wt_df_filtered2.head()
# Out:
#   Dataset                      Props_Used Model        R2       MAE      MAPE  \
# 0      wt          H1_H3_P2_NCI_SASA_SCT_   gbr  0.935655  7.836841  0.017132
# 1      wt                   H1_V_PKA_PKB_   gbr  0.937621  7.890320  0.017140
# 2      wt  H1_H2_H3_P1_MASS_SASA_PKA_PKB_   gbr  0.938227  7.901994  0.016949
# 3      wt                         H3_PKA_   gbr  0.931147  7.925474  0.017177
# 4      wt             H1_P1_P2_V_NCI_PKA_   gbr  0.933588  7.939524  0.017235
#
#           MSE       RMSE Ranked_By
# 0  191.196628  13.546977       MAE
# 1  181.888654  13.237769       MAE
# 2  185.298178  13.198679       MAE
# 3  208.020001  13.936483       MAE
# 4  198.462461  13.866247       MAE

# %%
top_aa_prop_df = pd.concat([top_aa_prop_df, wt_df_filtered[0:5], wt_df_filtered2[0:5]], ignore_index=True)

# %% [markdown]
# ### <font color=#c994c7>Vertebrate Dataset (Vert)</font>

# %%
vert_file = f'{report_dir}/vert_aa_prop_combos_results.csv'
vert_df = pd.read_csv(vert_file)
vert_df.head()
# Out:
#   Dataset Props_Used          Model        R2       MAE      MAPE         MSE  \
# 0    vert        H1_             rf  0.978668  5.282291  0.011782   80.496098
# 1    vert        H1_            xgb  0.977837  5.274730  0.011761   83.660893
# 2    vert        H1_            gbr  0.975760  5.359604  0.011978   91.426823
# 3    vert        H1_  BayesianRidge  0.952567  9.536876  0.021940  178.354665
# 4    vert        H2_             rf  0.976510  5.555795  0.012310   88.587994
#
#         RMSE
# 0   8.874717
# 1   9.010396
# 2   9.416843
# 3  13.302946
# 4   9.283032

# %%
vert_df_filtered = vert_df.copy()
vert_df_filtered.sort_values('R2',ascending=False,inplace=True)
vert_df_filtered.reset_index(inplace=True, drop=True)
vert_df_filtered['Ranked_By'] = 'R2'
vert_df_filtered.head()
# Out:
#   Dataset          Props_Used Model        R2       MAE      MAPE        MSE  \
# 0    vert  H2_H3_NCI_SCT_PKB_   xgb  0.980808  4.935295  0.010916  73.004131
# 1    vert   H1_H2_H3_NCI_PKB_   gbr  0.980476  4.944569  0.010948  73.980611
# 2    vert      H2_H3_NCI_PKB_   xgb  0.980445  5.037150  0.011176  74.253910
# 3    vert      H1_H2_NCI_PKB_   gbr  0.980379  5.002461  0.011075  74.383624
# 4    vert    H1_H2_H3_P1_NCI_    rf  0.980372  5.116075  0.011414  74.191393
#
#        RMSE Ranked_By
# 0  8.392039        R2
# 1  8.479772        R2
# 2  8.484706        R2
# 3  8.490553        R2
# 4  8.494845        R2

# %%
vert_df_filtered2= vert_df.copy()
vert_df_filtered2.sort_values('MAE',ascending=True,inplace=True)
vert_df_filtered2.reset_index(inplace=True, drop=True)
vert_df_filtered2['Ranked_By'] = 'MAE'
vert_df_filtered2.head()
# Out:
#   Dataset              Props_Used Model        R2       MAE      MAPE  \
# 0    vert  H2_H3_P2_NCI_SASA_SCT_   gbr  0.978035  4.914302  0.010886
# 1    vert       H1_P2_V_SASA_SCT_   gbr  0.979744  4.930994  0.010914
# 2    vert       H1_P1_V_SASA_PKA_   gbr  0.979817  4.935150  0.010924
# 3    vert      H2_H3_NCI_SCT_PKB_   xgb  0.980808  4.935295  0.010916
# 4    vert          H2_H3_P2_SASA_   gbr  0.978250  4.935346  0.010928
#
#          MSE      RMSE Ranked_By
# 0  82.078538  8.898818       MAE
# 1  76.253790  8.595901       MAE
# 2  76.142473  8.567762       MAE
# 3  73.004131  8.392039       MAE
# 4  81.382856  8.862316       MAE

# %%
top_aa_prop_df = pd.concat([top_aa_prop_df, vert_df_filtered[0:5], vert_df_filtered2[0:5]], ignore_index=True)

# %% [markdown]
# ### <font color=#c994c7>Wild-Type Vertebrates Dataset (WT-Vert)</font>

# %%
wt_vert_file = f'{report_dir}/wt_vert_aa_prop_combos_results.csv'
wt_vert_df = pd.read_csv(wt_vert_file)
wt_vert_df.head()
# Out:
#    Dataset Props_Used          Model        R2       MAE      MAPE  \
# 0  wt_vert        H1_            gbr  0.974343  4.960323  0.010692
# 1  wt_vert        H1_            xgb  0.973985  4.904034  0.010533
# 2  wt_vert        H1_             rf  0.971004  5.172302  0.011083
# 3  wt_vert        H1_  BayesianRidge  0.926300  8.647717  0.019191
# 4  wt_vert        H2_            gbr  0.979033  4.665929  0.010004
#
#           MSE       RMSE
# 0   68.916935   7.956320
# 1   69.370715   7.995950
# 2   72.533714   8.228527
# 3  178.282027  13.013624
# 4   54.863623   7.185818

# %%
wt_vert_df_filtered = wt_vert_df.copy()
wt_vert_df_filtered.sort_values('R2',ascending=False,inplace=True)
wt_vert_df_filtered.reset_index(inplace=True, drop=True)
wt_vert_df_filtered['Ranked_By'] = 'R2'
wt_vert_df_filtered.head()
# Out:
#    Dataset     Props_Used Model        R2       MAE      MAPE        MSE  \
# 0  wt_vert  H2_P2_V_MASS_   gbr  0.979630  4.625349  0.009816  55.391988
# 1  wt_vert       H2_H3_V_   gbr  0.979554  4.609259  0.009793  55.358151
# 2  wt_vert       H2_P2_V_   gbr  0.979446  4.619346  0.009802  55.294406
# 3  wt_vert      H1_H2_H3_   gbr  0.979308  4.502663  0.009670  56.275580
# 4  wt_vert      H1_H2_P2_   gbr  0.979262  4.551335  0.009714  54.880108
#
#        RMSE Ranked_By
# 0  7.065266        R2
# 1  7.065029        R2
# 2  7.085095        R2
# 3  7.135008        R2
# 4  7.143088        R2

# %%
wt_vert_df_filtered2 = wt_vert_df.copy()
wt_vert_df_filtered2.sort_values('MAE',ascending=True,inplace=True)
wt_vert_df_filtered2.reset_index(inplace=True, drop=True)
wt_vert_df_filtered2['Ranked_By'] = 'MAE'
wt_vert_df_filtered2.head()
# Out:
#    Dataset      Props_Used Model        R2       MAE      MAPE        MSE  \
# 0  wt_vert   H1_H2_H3_PKB_   gbr  0.978618  4.462230  0.009474  55.741160
# 1  wt_vert       H1_H2_H3_   gbr  0.979308  4.502663  0.009670  56.275580
# 2  wt_vert    H1_H2_H3_P2_   gbr  0.978995  4.507244  0.009621  55.712441
# 3  wt_vert  H1_H2_SCT_PKB_   gbr  0.978773  4.548813  0.009648  55.543803
# 4  wt_vert      H1_H2_PKB_   gbr  0.978494  4.549819  0.009698  56.872034
#
#        RMSE Ranked_By
# 0  7.222893       MAE
# 1  7.135008       MAE
# 2  7.201111       MAE
# 3  7.211900       MAE
# 4  7.263243       MAE

# %%
top_aa_prop_df = pd.concat([top_aa_prop_df, wt_vert_df_filtered[0:5], wt_vert_df_filtered2[0:5]], ignore_index=True)

# %% [markdown]
# ### <font color=#c994c7>Invertebrate Dataset (Inv)</font>

# %%
inv_file = f'{report_dir}/inv_aa_prop_combos_results.csv'
inv_df = pd.read_csv(inv_file)
inv_df.head()
# Out:
#   Dataset Props_Used          Model        R2        MAE      MAPE  \
# 0     inv        H1_            gbr  0.829782  13.470825  0.028957
# 1     inv        H1_  BayesianRidge  0.828731  14.474503  0.031647
# 2     inv        H1_            xgb  0.823843  14.480657  0.031294
# 3     inv        H1_             rf  0.805686  15.174023  0.033278
# 4     inv        H2_             rf  0.803825  15.290007  0.033529
#
#           MSE       RMSE
# 0  523.195942  21.296935
# 1  566.778289  21.895207
# 2  549.296754  22.077985
# 3  624.905790  23.597051
# 4  631.113876  23.786247

# %%
inv_df_filtered = inv_df.copy()
inv_df_filtered.sort_values('R2',ascending=False,inplace=True)
inv_df_filtered.reset_index(inplace=True, drop=True)
inv_df_filtered['Ranked_By'] = 'R2'
inv_df_filtered.head()
# Out:
#   Dataset                    Props_Used Model        R2        MAE      MAPE  \
# 0     inv                        H1_H3_   gbr  0.839023  13.109937  0.028111
# 1     inv  H1_H2_P1_P2_V_MASS_SASA_SCT_   gbr  0.838573  12.829127  0.027563
# 2     inv            H2_H3_P2_MASS_SCT_   gbr  0.838251  12.759714  0.027545
# 3     inv            H2_P1_P2_MASS_SCT_   gbr  0.838144  12.866207  0.027606
# 4     inv               H1_P1_MASS_SCT_   gbr  0.838143  13.042821  0.028199
#
#           MSE       RMSE Ranked_By
# 0  497.631891  20.692100        R2
# 1  515.405708  20.989757        R2
# 2  521.720579  21.130178        R2
# 3  517.468957  21.012091        R2
# 4  525.576706  20.965555        R2

# %%
inv_df_filtered2 = inv_df.copy()
inv_df_filtered2.sort_values('MAE',ascending=True,inplace=True)
inv_df_filtered2.reset_index(inplace=True, drop=True)
inv_df_filtered2['Ranked_By'] = 'MAE'
inv_df_filtered2.head()
# Out:
#   Dataset                    Props_Used Model        R2        MAE      MAPE  \
# 0     inv            H2_H3_P2_MASS_SCT_   gbr  0.838251  12.759714  0.027545
# 1     inv                   H2_P2_MASS_   gbr  0.835180  12.783172  0.027487
# 2     inv              H1_H2_P2_V_MASS_   gbr  0.837207  12.798861  0.027551
# 3     inv           H2_P1_P2_MASS_SASA_   gbr  0.836175  12.801303  0.027539
# 4     inv  H1_H2_P1_P2_V_MASS_SASA_SCT_   gbr  0.838573  12.829127  0.027563
#
#           MSE       RMSE Ranked_By
# 0  521.720579  21.130178       MAE
# 1  527.024628  21.254557       MAE
# 2  517.761489  21.187476       MAE
# 3  521.256836  21.208294       MAE
# 4  515.405708  20.989757       MAE

# %%
top_aa_prop_df = pd.concat([top_aa_prop_df, inv_df_filtered[0:5], inv_df_filtered2[0:5]], ignore_index=True)

# %% [markdown]
# ### <font color=#c994c7>Type-One Microbial Opsin Dataset (T1)</font>

# %%
t1_file = f'{report_dir}/t1_aa_prop_combos_results.csv'
t1_df = pd.read_csv(t1_file)
t1_df.head()
# Out:
#   Dataset Props_Used Model        R2        MAE      MAPE         MSE  \
# 0      t1        H1_   xgb  0.837258   8.605884  0.016044  150.836218
# 1      t1        H2_   xgb  0.841295   8.481036  0.015786  145.887429
# 2      t1        H3_   xgb  0.719601  11.236318  0.020875  262.022685
# 3      t1        P1_   xgb  0.849117   8.345540  0.015562  139.382110
# 4      t1        P2_   xgb  0.803277   9.245236  0.017192  180.689286
#
#         RMSE
# 0  12.230893
# 1  12.031368
# 2  16.105301
# 3  11.756137
# 4  13.351700

# %%
t1_df_filtered = t1_df.copy()
t1_df_filtered.sort_values('R2',ascending=False,inplace=True)
t1_df_filtered.reset_index(inplace=True, drop=True)
t1_df_filtered['Ranked_By'] = 'R2'
t1_df_filtered.head()
# Out:
#   Dataset              Props_Used Model        R2       MAE      MAPE  \
# 0      t1              H3_P1_PKB_   xgb  0.867098  7.711729  0.014381
# 1      t1        P1_SASA_PKA_PKB_   xgb  0.866905  7.508190  0.014006
# 2      t1  H1_H2_H3_SASA_SCT_PKB_   xgb  0.866602  7.602643  0.014163
# 3      t1     H1_P1_SASA_PKA_PKB_   xgb  0.864982  7.612981  0.014190
# 4      t1       H1_P1_V_SASA_PKB_   xgb  0.864908  7.594316  0.014159
#
#           MSE       RMSE Ranked_By
# 0  122.902828  11.033555        R2
# 1  122.649584  11.012273        R2
# 2  123.214758  11.026521        R2
# 3  124.540729  11.107244        R2
# 4  124.163686  11.070840        R2

# %%
t1_df_filtered2 = t1_df.copy()
t1_df_filtered2.sort_values('MAE',ascending=True,inplace=True)
t1_df_filtered2.reset_index(inplace=True, drop=True)
t1_df_filtered2['Ranked_By'] = 'MAE'
t1_df_filtered2.head()
# Out:
#   Dataset                   Props_Used Model        R2       MAE      MAPE  \
# 0      t1             P1_SASA_PKA_PKB_   xgb  0.866905  7.508190  0.014006
# 1      t1  H1_H2_P1_NCI_MASS_SASA_PKB_   xgb  0.863582  7.536787  0.014065
# 2      t1         H1_H2_H3_V_MASS_PKB_   xgb  0.861579  7.549904  0.014080
# 3      t1            H2_P2_V_SASA_PKB_   xgb  0.859690  7.551450  0.014096
# 4      t1            P2_MASS_SASA_PKB_   xgb  0.860502  7.561929  0.014119
#
#           MSE       RMSE Ranked_By
# 0  122.649584  11.012273       MAE
# 1  125.593133  11.137883       MAE
# 2  127.383779  11.208814       MAE
# 3  128.785731  11.253854       MAE
# 4  128.444377  11.258262       MAE

# %%
top_aa_prop_df = pd.concat([top_aa_prop_df, t1_df_filtered[0:5], t1_df_filtered2[0:5]], ignore_index=True)

# %%
top_aa_prop_df
# Out:
#     Dataset                          Props_Used Model        R2        MAE  \
# 0       wds  H1_H2_H3_P1_P2_V_SASA_SCT_PKA_PKB_   gbr  0.968836   5.815975
# 1       wds              H1_H2_H3_P2_V_SCT_PKA_   xgb  0.968700   5.584713
# 2       wds     H1_H2_H3_P1_P2_V_MASS_SASA_SCT_   gbr  0.968699   5.937826
# 3       wds            H1_H2_NCI_MASS_SASA_PKB_   gbr  0.968595   5.883918
# 4       wds         H1_H2_H3_MASS_SASA_SCT_PKB_   gbr  0.968479   5.736124
# 5       wds                          H1_P2_SCT_    rf  0.963549   5.525469
# 6       wds                        H1_SASA_SCT_    rf  0.963176   5.536853
# 7       wds                       H2_P2_V_SASA_   xgb  0.967122   5.539737
# 8       wds             H1_H2_H3_P2_V_SASA_SCT_   xgb  0.967100   5.541833
# 9       wds                  H1_H2_H3_P2_V_SCT_   xgb  0.967439   5.546996
# 10       wt                   H1_H3_P1_NCI_PKA_   gbr  0.939306   7.988286
# 11       wt                   H2_H3_P1_NCI_PKA_   gbr  0.939214   8.014395
# 12       wt          H1_P1_P2_NCI_MASS_PKA_PKB_   gbr  0.938709   8.195275
# 13       wt            H1_H2_H3_P1_NCI_SCT_PKB_   gbr  0.938494   7.955590
# 14       wt      H1_H2_H3_P1_MASS_SASA_PKA_PKB_   gbr  0.938227   7.901994
# 15       wt              H1_H3_P2_NCI_SASA_SCT_   gbr  0.935655   7.836841
# 16       wt                       H1_V_PKA_PKB_   gbr  0.937621   7.890320
# 17       wt      H1_H2_H3_P1_MASS_SASA_PKA_PKB_   gbr  0.938227   7.901994
# 18       wt                             H3_PKA_   gbr  0.931147   7.925474
# 19       wt                 H1_P1_P2_V_NCI_PKA_   gbr  0.933588   7.939524
# 20     vert                  H2_H3_NCI_SCT_PKB_   xgb  0.980808   4.935295
# 21     vert                   H1_H2_H3_NCI_PKB_   gbr  0.980476   4.944569
# 22     vert                      H2_H3_NCI_PKB_   xgb  0.980445   5.037150
# 23     vert                      H1_H2_NCI_PKB_   gbr  0.980379   5.002461
# 24     vert                    H1_H2_H3_P1_NCI_    rf  0.980372   5.116075
# 25     vert              H2_H3_P2_NCI_SASA_SCT_   gbr  0.978035   4.914302
# 26     vert                   H1_P2_V_SASA_SCT_   gbr  0.979744   4.930994
# 27     vert                   H1_P1_V_SASA_PKA_   gbr  0.979817   4.935150
# 28     vert                  H2_H3_NCI_SCT_PKB_   xgb  0.980808   4.935295
# 29     vert                      H2_H3_P2_SASA_   gbr  0.978250   4.935346
# 30  wt_vert                       H2_P2_V_MASS_   gbr  0.979630   4.625349
# 31  wt_vert                            H2_H3_V_   gbr  0.979554   4.609259
# 32  wt_vert                            H2_P2_V_   gbr  0.979446   4.619346
# 33  wt_vert                           H1_H2_H3_   gbr  0.979308   4.502663
# 34  wt_vert                           H1_H2_P2_   gbr  0.979262   4.551335
# 35  wt_vert                       H1_H2_H3_PKB_   gbr  0.978618   4.462230
# 36  wt_vert                           H1_H2_H3_   gbr  0.979308   4.502663
# 37  wt_vert                        H1_H2_H3_P2_   gbr  0.978995   4.507244
# 38  wt_vert                      H1_H2_SCT_PKB_   gbr  0.978773   4.548813
# 39  wt_vert                          H1_H2_PKB_   gbr  0.978494   4.549819
# 40      inv                              H1_H3_   gbr  0.839023  13.109937
# 41      inv        H1_H2_P1_P2_V_MASS_SASA_SCT_   gbr  0.838573  12.829127
# 42      inv                  H2_H3_P2_MASS_SCT_   gbr  0.838251  12.759714
# 43      inv                  H2_P1_P2_MASS_SCT_   gbr  0.838144  12.866207
# 44      inv                     H1_P1_MASS_SCT_   gbr  0.838143  13.042821
# 45      inv                  H2_H3_P2_MASS_SCT_   gbr  0.838251  12.759714
# 46      inv                         H2_P2_MASS_   gbr  0.835180  12.783172
# 47      inv                    H1_H2_P2_V_MASS_   gbr  0.837207  12.798861
# 48      inv                 H2_P1_P2_MASS_SASA_   gbr  0.836175  12.801303
# 49      inv        H1_H2_P1_P2_V_MASS_SASA_SCT_   gbr  0.838573  12.829127
# 50       t1                          H3_P1_PKB_   xgb  0.867098   7.711729
# 51       t1                    P1_SASA_PKA_PKB_   xgb  0.866905   7.508190
# 52       t1              H1_H2_H3_SASA_SCT_PKB_   xgb  0.866602   7.602643
# 53       t1                 H1_P1_SASA_PKA_PKB_   xgb  0.864982   7.612981
# 54       t1                   H1_P1_V_SASA_PKB_   xgb  0.864908   7.594316
# 55       t1                    P1_SASA_PKA_PKB_   xgb  0.866905   7.508190
# 56       t1         H1_H2_P1_NCI_MASS_SASA_PKB_   xgb  0.863582   7.536787
# 57       t1                H1_H2_H3_V_MASS_PKB_   xgb  0.861579   7.549904
# 58       t1                   H2_P2_V_SASA_PKB_   xgb  0.859690   7.551450
# 59       t1                   P2_MASS_SASA_PKB_   xgb  0.860502   7.561929
#
#         MAPE         MSE       RMSE Ranked_By
# 0   0.013326  118.476535  10.772182        R2
# 1   0.012641  119.005642  10.694938        R2
# 2   0.013603  118.399741  10.729280        R2
# 3   0.013509  119.665746  10.794597        R2
# 4   0.013116  119.719386  10.731194        R2
# 5   0.012328  137.938787  11.372965       MAE
# 6   0.012377  139.214654  11.436566       MAE
# 7   0.012535  125.168998  10.963956       MAE
# 8   0.012525  124.945831  10.868227       MAE
# 9   0.012525  123.751668  10.785951       MAE
# 10  0.017367  176.983955  13.128133        R2
# 11  0.017276  180.659277  13.045880        R2
# 12  0.017629  181.608472  13.255662        R2
# 13  0.017264  179.503400  13.233635        R2
# 14  0.016949  185.298178  13.198679        R2
# 15  0.017132  191.196628  13.546977       MAE
# 16  0.017140  181.888654  13.237769       MAE
# 17  0.016949  185.298178  13.198679       MAE
# 18  0.017177  208.020001  13.936483       MAE
# 19  0.017235  198.462461  13.866247       MAE
# 20  0.010916   73.004131   8.392039        R2
# 21  0.010948   73.980611   8.479772        R2
# 22  0.011176   74.253910   8.484706        R2
# 23  0.011075   74.383624   8.490553        R2
# 24  0.011414   74.191393   8.494845        R2
# 25  0.010886   82.078538   8.898818       MAE
# 26  0.010914   76.253790   8.595901       MAE
# 27  0.010924   76.142473   8.567762       MAE
# 28  0.010916   73.004131   8.392039       MAE
# 29  0.010928   81.382856   8.862316       MAE
# 30  0.009816   55.391988   7.065266        R2
# 31  0.009793   55.358151   7.065029        R2
# 32  0.009802   55.294406   7.085095        R2
# 33  0.009670   56.275580   7.135008        R2
# 34  0.009714   54.880108   7.143088        R2
# 35  0.009474   55.741160   7.222893       MAE
# 36  0.009670   56.275580   7.135008       MAE
# 37  0.009621   55.712441   7.201111       MAE
# 38  0.009648   55.543803   7.211900       MAE
# 39  0.009698   56.872034   7.263243       MAE
# 40  0.028111  497.631891  20.692100        R2
# 41  0.027563  515.405708  20.989757        R2
# 42  0.027545  521.720579  21.130178        R2
# 43  0.027606  517.468957  21.012091        R2
# 44  0.028199  525.576706  20.965555        R2
# 45  0.027545  521.720579  21.130178       MAE
# 46  0.027487  527.024628  21.254557       MAE
# 47  0.027551  517.761489  21.187476       MAE
# 48  0.027539  521.256836  21.208294       MAE
# 49  0.027563  515.405708  20.989757       MAE
# 50  0.014381  122.902828  11.033555        R2
# 51  0.014006  122.649584  11.012273        R2
# 52  0.014163  123.214758  11.026521        R2
# 53  0.014190  124.540729  11.107244        R2
# 54  0.014159  124.163686  11.070840        R2
# 55  0.014006  122.649584  11.012273       MAE
# 56  0.014065  125.593133  11.137883       MAE
# 57  0.014080  127.383779  11.208814       MAE
# 58  0.014096  128.785731  11.253854       MAE
# 59  0.014119  128.444377  11.258262       MAE

# %%
top_aa_prop_df.to_csv(f'{report_dir}/top_aa_props_all_datasets.csv')

# %% [markdown]
# ## <font color=#c51b8a>Amino Acid Property Analysis: (Part 2)</font>
# ### A post-grid-search analysis of the best amino acid properties combinations for training ML models on different opsin datasets...

# %%
import os
import re
import datetime
import time
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ### This is actually less of an analysis, and more just a way to see the final results of the aa_prop grid-search.
# - Note - only one group of aa-properties, one model algorythm and one set of model parameters is chosen for each dataset in the end.

# %%
report_dir = './vpod_1.2/aa_prop_combos_analysis_2024-12-16_16-57-42'

# %%
top_aa_prop_file = f'{report_dir}/filtered_top_aa_props_all_datasets_gs.csv'
top_aa_prop_df = pd.read_csv(top_aa_prop_file, index_col=0)
top_aa_prop_df.head()
# Out:
#    Dataset                          Props_Used best_gs_model  best_gs_r2  \
# 0      wds  H1_H2_H3_P1_P2_V_SASA_SCT_PKA_PKB_           gbr    0.968836
# 1       wt                   H1_H3_P1_NCI_PKA_           gbr    0.939306
# 2     vert                  H2_H3_NCI_SCT_PKB_           xgb    0.981047
# 3  wt_vert                       H2_P2_V_MASS_           gbr    0.979911
# 4      inv                              H1_H3_           gbr    0.839023
#
#                                       best_gs_params
# 0  {'gbr__learning_rate': 0.2, 'gbr__max_depth': ...
# 1  {'gbr__learning_rate': 0.1, 'gbr__max_depth': ...
# 2  {'xgb__colsample_bytree': 1.0, 'xgb__gamma': 0...
# 3  {'gbr__learning_rate': 0.1, 'gbr__max_depth': ...
# 4  {'gbr__learning_rate': 0.01, 'gbr__max_depth':...
