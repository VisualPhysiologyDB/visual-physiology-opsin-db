# %%
from Bio import Phylo
tree = Phylo.read("./opsin_wt_tree/vpod_1.1_wt/wt_aligned_VPOD_1.1_het.fasta.treefile", "newick")

# %%
from ete3 import Tree
import ete3
tree = Tree("./opsin_wt_tree/vpod_1.1_wt/wt_aligned_VPOD_1.1_het.fasta.treefile", format=1)

# %%
# Assign unique names to unnamed clades
def assign_unique_names(tree):
    counter = 1
    for clade in tree.find_clades():
        if clade.name is None:
            clade.name = f'Node{counter}'
            counter += 1

assign_unique_names(tree)

# %%
clades = list(tree.find_clades(order='level'))

clades
# Out:
# [Clade(name='Node1'),
#  Clade(branch_length=0.040201682, name='Bovine'),
#  Clade(branch_length=0.0477538258, confidence=97, name='Node2'),
#  Clade(branch_length=0.0130588113, confidence=85, name='Node350'),
#  Clade(branch_length=0.0109293208, confidence=50, name='Node3'),
#  Clade(branch_length=0.0001375959, name='S245'),
#  Clade(branch_length=0.0058539809, confidence=87, name='Node351'),
#  Clade(branch_length=0.0180398811, confidence=93, name='Node355'),
#  Clade(branch_length=0.0183666775, confidence=52, name='Node4'),
#  Clade(branch_length=0.0114811752, confidence=92, name='Node340'),
#  Clade(branch_length=0.0186175675, confidence=93, name='Node352'),
#  Clade(branch_length=0.0092278303, confidence=96, name='Node353'),
#  Clade(branch_length=0.0297588075, confidence=100, name='Node356'),
#  Clade(branch_length=0.0103421649, name='S349'),
#  Clade(branch_length=0.0200437049, confidence=92, name='Node5'),
#  Clade(branch_length=0.0215849477, confidence=56, name='Node336'),
#  Clade(branch_length=0.075262427, confidence=100, name='Node341'),
#  Clade(branch_length=0.0403362052, confidence=100, name='Node346'),
#  Clade(branch_length=0.0328809403, name='S61'),
#  Clade(branch_length=0.0205239292, name='S106'),
#  Clade(branch_length=0.0160955267, confidence=100, name='Node354'),
#  Clade(branch_length=0.0373745588, name='S194'),
#  Clade(branch_length=0.0032603551, confidence=77, name='Node357'),
#  Clade(branch_length=0.0128938544, name='S302'),
#  Clade(branch_length=0.01191206, confidence=98, name='Node6'),
#  Clade(branch_length=0.022550761, confidence=93, name='Node86'),
#  Clade(branch_length=0.0796086839, name='S40'),
#  Clade(branch_length=0.0266492236, confidence=100, name='Node337'),
#  Clade(branch_length=0.0708495184, name='S68'),
#  Clade(branch_length=0.0259101821, confidence=100, name='Node342'),
#  Clade(branch_length=0.0051013599, confidence=100, name='Node347'),
#  Clade(branch_length=0.0025763614, name='S187'),
#  Clade(branch_length=0.003223395, name='S104'),
#  Clade(branch_length=0.0098248263, name='S105'),
#  Clade(branch_length=0.0029443034, confidence=74, name='Node358'),
#  Clade(branch_length=2.2432e-06, name='S348'),
#  Clade(branch_length=0.0392024144, confidence=100, name='Node7'),
#  Clade(branch_length=2.8888e-06, name='S48'),
#  Clade(branch_length=0.0292550791, confidence=51, name='Node87'),
#  Clade(branch_length=0.0260259897, confidence=51, name='Node89'),
#  Clade(branch_length=0.0350336414, confidence=100, name='Node338'),
#  Clade(branch_length=0.0552597215, name='S115'),
#  Clade(branch_length=0.0250304658, confidence=100, name='Node343'),
#  Clade(branch_length=0.0593963935, name='S342'),
#  Clade(branch_length=0.0044904765, confidence=100, name='Node348'),
#  Clade(branch_length=0.0085375353, name='S117'),
#  Clade(branch_length=0.0130701389, confidence=100, name='Node359'),
#  Clade(branch_length=0.0367145001, name='S103'),
#  Clade(branch_length=2.0202e-06, confidence=94, name='Node8'),
#  Clade(branch_length=2.2642e-06, name='S49'),
#  Clade(branch_length=0.0950348126, name='S60'),
#  Clade(branch_length=0.1841878397, confidence=100, name='Node88'),
#  Clade(branch_length=0.0838378232, confidence=100, name='Node90'),
#  Clade(branch_length=0.1008483598, confidence=100, name='Node335'),
#  Clade(branch_length=0.060752003, name='S112'),
#  Clade(branch_length=0.0426258386, confidence=100, name='Node339'),
#  Clade(branch_length=0.0069728884, confidence=100, name='Node344'),
#  Clade(branch_length=0.0239747656, confidence=100, name='Node345'),
#  Clade(branch_length=0.0125764012, name='S116'),
#  Clade(branch_length=0.0082943348, confidence=100, name='Node349'),
#  Clade(branch_length=0.0096733787, confidence=100, name='Node360'),
#  Clade(branch_length=2.5602e-06, name='S101'),
#  Clade(branch_length=0.0643327722, confidence=61, name='Node9'),
#  Clade(branch_length=0.0227601489, confidence=55, name='Node81'),
#  Clade(branch_length=0.0772097796, name='S178'),
#  Clade(branch_length=0.0523966269, name='S180'),
#  Clade(branch_length=0.0661169296, confidence=100, name='Node91'),
#  Clade(branch_length=0.0622208851, confidence=100, name='Node333'),
#  Clade(branch_length=0.0349727217, name='S350'),
#  Clade(branch_length=0.0010329384, name='S351'),
#  Clade(branch_length=0.018050168, name='S113'),
#  Clade(branch_length=0.00746164, name='S114'),
#  Clade(branch_length=0.0053147923, name='S304'),
#  Clade(branch_length=0.0008900932, name='S305'),
#  Clade(branch_length=0.006227914, name='S306'),
#  Clade(branch_length=0.0061811369, name='S307'),
#  Clade(branch_length=0.0031459696, name='S118'),
#  Clade(branch_length=1.0017e-06, name='S243'),
#  Clade(branch_length=0.0031903929, name='S72'),
#  Clade(branch_length=0.0095497568, name='S102'),
#  Clade(branch_length=0.0135897839, confidence=33, name='Node10'),
#  Clade(branch_length=0.0619509572, confidence=100, name='Node79'),
#  Clade(branch_length=2.2918e-06, name='S50'),
#  Clade(branch_length=0.0031790408, confidence=55, name='Node82'),
#  Clade(branch_length=0.0348169011, confidence=96, name='Node92'),
#  Clade(branch_length=0.0185353754, confidence=100, name='Node271'),
#  Clade(branch_length=0.037728285, name='S82'),
#  Clade(branch_length=0.0210834865, confidence=100, name='Node334'),
#  Clade(branch_length=0.0542531464, confidence=61, name='Node11'),
#  Clade(branch_length=0.0814399911, name='S70'),
#  Clade(branch_length=0.0173099629, confidence=100, name='Node80'),
#  Clade(branch_length=0.0250346641, name='S179'),
#  Clade(branch_length=0.0221407179, confidence=100, name='Node83'),
#  Clade(branch_length=0.015648187, confidence=60, name='Node84'),
#  Clade(branch_length=0.3654029639, confidence=100, name='Node93'),
#  Clade(branch_length=0.1751427126, name='S171'),
#  Clade(branch_length=0.0459964063, confidence=100, name='Node272'),
#  Clade(branch_length=2.2992e-06, name='S246'),
#  Clade(branch_length=0.0608032207, name='S170'),
#  Clade(branch_length=0.0474282087, name='S259'),
#  Clade(branch_length=0.0119226788, confidence=75, name='Node12'),
#  Clade(branch_length=0.0361644294, confidence=44, name='Node74'),
#  Clade(branch_length=0.0582494145, name='S110'),
#  Clade(branch_length=0.0432487416, name='S177'),
#  Clade(branch_length=2.5822e-06, name='S51'),
#  Clade(branch_length=0.0833248946, name='S59'),
#  Clade(branch_length=0.0257440516, confidence=100, name='Node85'),
#  Clade(branch_length=0.2330889812, name='S192'),
#  Clade(branch_length=0.1038897902, confidence=100, name='Node94'),
#  Clade(branch_length=0.1978418883, confidence=100, name='Node245'),
#  Clade(branch_length=0.0206342642, confidence=100, name='Node273'),
#  Clade(branch_length=2.0977e-06, name='S247'),
#  Clade(branch_length=0.0510729086, confidence=98, name='Node13'),
#  Clade(branch_length=0.0209776869, confidence=82, name='Node23'),
#  Clade(branch_length=0.0728272623, name='S191'),
#  Clade(branch_length=0.5782135812, confidence=100, name='Node75'),
#  Clade(branch_length=2.3957e-06, name='S52'),
#  Clade(branch_length=0.0720459115, name='S69'),
#  Clade(branch_length=0.2481524426, confidence=100, name='Node95'),
#  Clade(branch_length=0.3748384298, confidence=100, name='Node191'),
#  Clade(branch_length=0.0602913106, confidence=100, name='Node246'),
#  Clade(branch_length=0.2737409837, name='S169'),
#  Clade(branch_length=0.0124173621, confidence=99, name='Node274'),
#  Clade(branch_length=0.1634890562, name='S260'),
#  Clade(branch_length=0.0209046625, confidence=89, name='Node14'),
#  Clade(branch_length=0.0469241923, confidence=100, name='Node22'),
#  Clade(branch_length=0.0163299429, confidence=72, name='Node24'),
#  Clade(branch_length=0.0197761333, confidence=96, name='Node72'),
#  Clade(branch_length=0.2334839609, name='S357'),
#  Clade(branch_length=0.0838907947, confidence=92, name='Node76'),
#  Clade(branch_length=0.1078503554, confidence=95, name='Node96'),
#  Clade(branch_length=0.401581616, confidence=100, name='Node190'),
#  Clade(branch_length=0.1930583528, confidence=100, name='Node192'),
#  Clade(branch_length=0.0210876888, confidence=99, name='Node204'),
#  Clade(branch_length=0.1385890122, confidence=100, name='Node247'),
#  Clade(branch_length=0.1266329052, confidence=100, name='Node267'),
#  Clade(branch_length=0.0130571658, confidence=47, name='Node275'),
#  Clade(branch_length=0.1215263884, confidence=100, name='Node286'),
#  Clade(branch_length=0.0102652145, confidence=73, name='Node15'),
#  Clade(branch_length=0.0167511868, confidence=100, name='Node20'),
#  Clade(branch_length=0.0096626701, name='S10'),
#  Clade(branch_length=0.0270368737, name='S11'),
#  Clade(branch_length=0.03617755, confidence=100, name='Node25'),
#  Clade(branch_length=0.0160547647, confidence=83, name='Node59'),
#  Clade(branch_length=0.0394175594, confidence=100, name='Node73'),
#  Clade(branch_length=0.0212591872, name='S338'),
#  Clade(branch_length=0.0623487199, name='S358'),
#  Clade(branch_length=0.0113747544, confidence=77, name='Node77'),
#  Clade(branch_length=0.670410466, confidence=100, name='Node97'),
#  Clade(branch_length=0.6060499233, confidence=100, name='Node144'),
#  Clade(branch_length=0.1468237708, name='S150'),
#  Clade(branch_length=0.2328381805, name='S151'),
#  Clade(branch_length=0.02790431, confidence=100, name='Node193'),
#  Clade(branch_length=0.0016894152, name='S321'),
#  Clade(branch_length=0.0671118236, confidence=99, name='Node205'),
#  Clade(branch_length=0.0046735285, name='S261'),
#  Clade(branch_length=0.1291536688, confidence=100, name='Node248'),
#  Clade(branch_length=0.1218725305, confidence=100, name='Node264'),
#  Clade(branch_length=0.0663729724, name='S129'),
#  Clade(branch_length=0.0706337379, confidence=100, name='Node268'),
#  Clade(branch_length=0.0412016089, confidence=48, name='Node276'),
#  Clade(branch_length=2.4163e-06, name='S256'),
#  Clade(branch_length=0.0318772347, confidence=100, name='Node287'),
#  Clade(branch_length=2.2239e-06, name='S248'),
#  Clade(branch_length=0.0062732967, confidence=73, name='Node16'),
#  Clade(branch_length=0.0433250584, confidence=99, name='Node18'),
#  Clade(branch_length=0.0134197604, name='S5'),
#  Clade(branch_length=0.003086515, confidence=100, name='Node21'),
#  Clade(branch_length=2.5188e-06, confidence=64, name='Node26'),
#  Clade(branch_length=0.0189259193, name='S39'),
#  Clade(branch_length=0.0089361657, confidence=83, name='Node60'),
#  Clade(branch_length=0.0917427969, confidence=100, name='Node71'),
#  Clade(branch_length=0.0265063602, name='S111'),
#  Clade(branch_length=0.0131942888, name='S167'),
#  Clade(branch_length=0.0227415334, confidence=83, name='Node78'),
#  Clade(branch_length=0.0264892897, name='S360'),
#  Clade(branch_length=0.0468830736, confidence=71, name='Node98'),
#  Clade(branch_length=0.0590172075, confidence=95, name='Node122'),
#  Clade(branch_length=0.1830694071, confidence=100, name='Node145'),
#  Clade(branch_length=1.2236737674, name='S182'),
#  Clade(branch_length=0.1148994431, confidence=100, name='Node194'),
#  Clade(branch_length=0.054838772, confidence=100, name='Node197'),
#  Clade(branch_length=0.0253067189, confidence=96, name='Node206'),
#  Clade(branch_length=0.254096728, name='S168'),
#  Clade(branch_length=0.0197162908, confidence=63, name='Node249'),
#  Clade(branch_length=0.122328501, name='S225'),
#  Clade(branch_length=0.1169233649, confidence=100, name='Node265'),
#  Clade(branch_length=0.1305004629, confidence=100, name='Node266'),
#  Clade(branch_length=0.0467638183, confidence=100, name='Node269'),
#  Clade(branch_length=0.0642176091, name='S131'),
#  Clade(branch_length=0.1813565594, confidence=100, name='Node277'),
#  Clade(branch_length=0.0177366623, confidence=97, name='Node278'),
#  Clade(branch_length=2.0706e-06, confidence=86, name='Node288'),
#  Clade(branch_length=2.7372e-06, name='S249'),
#  Clade(branch_length=0.0284308719, confidence=100, name='Node17'),
#  Clade(branch_length=0.0238945438, name='S4'),
#  Clade(branch_length=0.0356674046, name='S3'),
#  Clade(branch_length=0.0393406289, confidence=100, name='Node19'),
#  Clade(branch_length=0.0031672279, name='S6'),
#  Clade(branch_length=0.0263880244, name='S7'),
#  Clade(branch_length=0.0070017657, confidence=79, name='Node27'),
#  Clade(branch_length=0.0045256952, name='S33'),
#  Clade(branch_length=0.0235517927, confidence=84, name='Node61'),
#  Clade(branch_length=2.8558e-06, name='S54'),
#  Clade(branch_length=2.6864e-06, name='S62'),
#  Clade(branch_length=2.5561e-06, name='S71'),
#  Clade(branch_length=0.0901675977, name='S359'),
#  Clade(branch_length=0.1035635177, name='S361'),
#  Clade(branch_length=0.0075849829, confidence=71, name='Node99'),
#  Clade(branch_length=0.015074624, confidence=94, name='Node115'),
#  Clade(branch_length=0.0135055173, confidence=95, name='Node123'),
#  Clade(branch_length=0.0807006035, name='S346'),
#  Clade(branch_length=0.1461106142, confidence=99, name='Node146'),
#  Clade(branch_length=1.5177366656, name='S314'),
#  Clade(branch_length=0.0774159453, confidence=100, name='Node195'),
#  Clade(branch_length=0.08903526, name='S86'),
#  Clade(branch_length=0.0485729179, confidence=92, name='Node198'),
#  Clade(branch_length=0.2406341344, name='S326'),
#  Clade(branch_length=0.0088156278, confidence=97, name='Node207'),
#  Clade(branch_length=2.2152e-06, confidence=74, name='Node209'),
#  Clade(branch_length=0.0178274732, confidence=99, name='Node250'),
#  Clade(branch_length=0.0953490974, confidence=100, name='Node258'),
#  Clade(branch_length=1.0017e-06, name='S128'),
#  Clade(branch_length=1.0017e-06, name='S230'),
#  Clade(branch_length=1.0017e-06, name='S229'),
#  Clade(branch_length=2.1206e-06, name='S231'),
#  Clade(branch_length=0.0270756643, confidence=100, name='Node270'),
#  Clade(branch_length=0.0222800995, name='S190'),
#  Clade(branch_length=2.0889e-06, name='S74'),
#  Clade(branch_length=2.02e-06, name='S122'),
#  Clade(branch_length=0.0029628763, confidence=96, name='Node279'),
#  Clade(branch_length=2.063e-06, confidence=97, name='Node285'),
#  Clade(branch_length=0.0448988826, confidence=100, name='Node289'),
#  Clade(branch_length=0.0188286958, confidence=100, name='Node320'),
#  Clade(branch_length=0.0128301945, name='S1'),
#  Clade(branch_length=2.7671e-06, name='S2'),
#  Clade(branch_length=0.0064623803, name='S8'),
#  Clade(branch_length=2.0734e-06, name='S9'),
#  Clade(branch_length=0.0092710533, confidence=77, name='Node28'),
#  Clade(branch_length=2.3485e-06, confidence=89, name='Node56'),
#  Clade(branch_length=2.0788e-06, name='S53'),
#  Clade(branch_length=0.0064282419, confidence=81, name='Node62'),
#  Clade(branch_length=0.0224962622, confidence=71, name='Node100'),
#  Clade(branch_length=2.1699e-06, name='S283'),
#  Clade(branch_length=0.0098729061, confidence=92, name='Node116'),
#  Clade(branch_length=2.4626e-06, name='S284'),
#  Clade(branch_length=0.1880398745, name='S81'),
#  Clade(branch_length=0.0306262848, confidence=73, name='Node124'),
#  Clade(branch_length=1.12173157, confidence=100, name='Node147'),
#  Clade(branch_length=0.3521039098, confidence=99, name='Node187'),
#  Clade(branch_length=1.9805e-06, name='Node196'),
#  Clade(branch_length=1.0017e-06, name='S126'),
#  Clade(branch_length=0.0772135935, confidence=100, name='Node199'),
#  Clade(branch_length=0.0234590238, confidence=92, name='Node203'),
#  Clade(branch_length=0.0068068857, confidence=97, name='Node208'),
#  Clade(branch_length=0.1393391554, name='S88'),
#  Clade(branch_length=0.0216952004, confidence=99, name='Node210'),
#  Clade(branch_length=2.6577e-06, name='S262'),
#  Clade(branch_length=0.0573922441, confidence=100, name='Node251'),
#  Clade(branch_length=0.0563001407, confidence=100, name='Node256'),
#  Clade(branch_length=0.039752727, confidence=99, name='Node259'),
#  Clade(branch_length=0.0274939715, confidence=100, name='Node262'),
#  Clade(branch_length=0.0372286762, name='S130'),
#  Clade(branch_length=0.1268341973, name='S132'),
#  Clade(branch_length=0.0375631581, confidence=100, name='Node280'),
#  Clade(branch_length=0.0470682125, confidence=100, name='Node281'),
#  Clade(branch_length=1.0017e-06, name='S257'),
#  Clade(branch_length=1.0017e-06, name='S258'),
#  Clade(branch_length=0.0688100102, confidence=100, name='Node290'),
#  Clade(branch_length=0.0019321553, name='S252'),
#  Clade(branch_length=0.039642942, confidence=99, name='Node321'),
#  Clade(branch_length=2.6863e-06, name='S250'),
#  Clade(branch_length=0.0064140964, confidence=72, name='Node29'),
#  Clade(branch_length=0.00640386, name='S25'),
#  Clade(branch_length=0.0074716874, name='S20'),
#  Clade(branch_length=0.0066187237, confidence=92, name='Node57'),
#  Clade(branch_length=0.0070783433, confidence=99, name='Node63'),
#  Clade(branch_length=0.0599028602, confidence=82, name='Node70'),
#  Clade(branch_length=2.4936e-06, confidence=53, name='Node101'),
#  Clade(branch_length=1.0017e-06, name='S285'),
#  Clade(branch_length=0.0042083282, confidence=92, name='Node117'),
#  Clade(branch_length=0.013964096, name='S139'),
#  Clade(branch_length=0.0108164076, confidence=51, name='Node125'),
#  Clade(branch_length=0.0535584729, confidence=98, name='Node143'),
#  Clade(branch_length=0.4072133574, confidence=100, name='Node148'),
#  Clade(branch_length=0.3570328849, confidence=100, name='Node170'),
#  Clade(branch_length=0.919722351, confidence=100, name='Node188'),
#  Clade(branch_length=1.7496219905, name='S352'),
#  Clade(branch_length=0.0, name='S85'),
#  Clade(branch_length=0.0, name='S327'),
#  Clade(branch_length=0.0272850587, confidence=41, name='Node200'),
#  Clade(branch_length=0.0443212838, confidence=100, name='Node202'),
#  Clade(branch_length=0.0484550986, name='S324'),
#  Clade(branch_length=0.210626574, name='S339'),
#  Clade(branch_length=0.191186712, name='S87'),
#  Clade(branch_length=2.5135e-06, name='S263'),
#  Clade(branch_length=0.0092672724, confidence=58, name='Node211'),
#  Clade(branch_length=2.437e-06, name='S264'),
#  Clade(branch_length=0.0549530245, confidence=100, name='Node252'),
#  Clade(branch_length=0.0721845324, name='S330'),
#  Clade(branch_length=0.0754467248, confidence=100, name='Node257'),
#  Clade(branch_length=0.1062541699, name='S227'),
#  Clade(branch_length=0.0626347496, confidence=100, name='Node260'),
#  Clade(branch_length=0.1151287462, name='S226'),
#  Clade(branch_length=0.0835306316, name='S220'),
#  Clade(branch_length=0.0745962201, confidence=100, name='Node263'),
#  Clade(branch_length=1.0017e-06, name='S76'),
#  Clade(branch_length=2.4193e-06, name='S121'),
#  Clade(branch_length=0.0086712353, confidence=65, name='Node282'),
#  Clade(branch_length=0.036717846, name='S124'),
#  Clade(branch_length=2.0751e-06, confidence=40, name='Node291'),
#  Clade(branch_length=0.1057233698, confidence=100, name='Node302'),
#  Clade(branch_length=0.0330986344, confidence=98, name='Node322'),
#  Clade(branch_length=2.6747e-06, name='S251'),
#  Clade(branch_length=2.293e-06, confidence=41, name='Node30'),
#  Clade(branch_length=0.0030541521, confidence=57, name='Node42'),
#  Clade(branch_length=0.0075882786, confidence=100, name='Node58'),
#  Clade(branch_length=0.0066793512, name='S32'),
#  Clade(branch_length=0.0058543997, confidence=100, name='Node64'),
#  Clade(branch_length=0.0861236165, confidence=100, name='Node68'),
#  Clade(branch_length=0.1549540381, name='S65'),
#  Clade(branch_length=0.1343454708, name='S356'),
#  Clade(branch_length=0.0193040366, confidence=69, name='Node102'),
#  Clade(branch_length=0.0285069003, name='S149'),
#  Clade(branch_length=7.5166e-06, confidence=85, name='Node118'),
#  Clade(branch_length=2.159e-06, name='S289'),
#  Clade(branch_length=0.0157782186, confidence=47, name='Node126'),
#  Clade(branch_length=0.0459465405, name='S134'),
#  Clade(branch_length=0.0505893313, name='S308'),
#  Clade(branch_length=0.0397096454, name='S341'),
#  Clade(branch_length=0.0628577354, confidence=100, name='Node149'),
#  Clade(branch_length=0.0966359509, confidence=98, name='Node169'),
#  Clade(branch_length=0.4484081421, confidence=100, name='Node171'),
#  Clade(branch_length=1.4302705758, name='S318'),
#  Clade(branch_length=1.574633935, confidence=100, name='Node189'),
#  Clade(branch_length=0.8149530408, name='S353'),
#  Clade(branch_length=0.0853462412, confidence=100, name='Node201'),
#  Clade(branch_length=0.0916319307, name='S335'),
#  Clade(branch_length=0.0397882535, name='S240'),
#  Clade(branch_length=0.0129598276, name='S328'),
#  Clade(branch_length=0.0136686494, confidence=94, name='Node212'),
#  Clade(branch_length=0.0386434594, confidence=100, name='Node229'),
#  Clade(branch_length=0.1960654961, confidence=100, name='Node253'),
#  Clade(branch_length=0.0185038947, confidence=75, name='Node254'),
#  Clade(branch_length=1.0017e-06, name='S164'),
#  Clade(branch_length=1.0017e-06, name='S223'),
#  Clade(branch_length=0.0175400866, confidence=100, name='Node261'),
#  Clade(branch_length=0.0522233065, name='S228'),
#  Clade(branch_length=0.0277390691, name='S239'),
#  Clade(branch_length=0.0187323503, name='S329'),
#  Clade(branch_length=0.0063477627, confidence=66, name='Node283'),
#  Clade(branch_length=2.3789e-06, confidence=91, name='Node284'),
#  Clade(branch_length=0.0413339, confidence=99, name='Node292'),
#  Clade(branch_length=1.0017e-06, name='S253'),
#  Clade(branch_length=0.0639739302, confidence=99, name='Node303'),
#  Clade(branch_length=2.7353e-06, name='S255'),
#  Clade(branch_length=0.0111433045, confidence=97, name='Node323'),
#  Clade(branch_length=0.0157393305, confidence=100, name='Node330'),
#  Clade(branch_length=0.0093088078, confidence=47, name='Node31'),
#  Clade(branch_length=0.0031829094, confidence=51, name='Node33'),
#  Clade(branch_length=0.0038644137, confidence=58, name='Node43'),
#  Clade(branch_length=0.0030702029, confidence=73, name='Node50'),
#  Clade(branch_length=0.0075225305, name='S21'),
#  Clade(branch_length=2.3048e-06, name='S30'),
#  Clade(branch_length=2.6123e-06, name='S55'),
#  Clade(branch_length=0.0632075739, confidence=100, name='Node65'),
#  Clade(branch_length=0.0032932346, confidence=100, name='Node69'),
#  Clade(branch_length=0.0488604162, name='S66'),
#  Clade(branch_length=0.0064883468, confidence=45, name='Node103'),
#  Clade(branch_length=0.0490030832, confidence=100, name='Node114'),
#  Clade(branch_length=0.0255426173, name='S138'),
#  Clade(branch_length=0.017010838, confidence=94, name='Node119'),
#  Clade(branch_length=2.9414e-06, confidence=44, name='Node127'),
#  Clade(branch_length=0.0498731246, confidence=96, name='Node140'),
#  Clade(branch_length=0.1099699325, confidence=100, name='Node150'),
#  Clade(branch_length=0.5933244013, confidence=100, name='Node168'),
#  Clade(branch_length=0.3099794812, name='S319'),
#  Clade(branch_length=0.4083845947, name='S347'),
#  Clade(branch_length=0.3025905059, confidence=100, name='Node172'),
#  Clade(branch_length=0.1799691216, confidence=89, name='Node180'),
#  Clade(branch_length=0.0509074813, name='S195'),
#  Clade(branch_length=0.0442381521, name='S196'),
#  Clade(branch_length=0.0206473057, name='S166'),
#  Clade(branch_length=0.0491662025, name='S325'),
#  Clade(branch_length=0.0381861075, confidence=98, name='Node213'),
#  Clade(branch_length=2.0591e-06, confidence=40, name='Node216'),
#  Clade(branch_length=0.0170095331, confidence=58, name='Node230'),
#  Clade(branch_length=0.0530764101, confidence=100, name='Node244'),
#  Clade(branch_length=1.0017e-06, name='S84'),
#  Clade(branch_length=1.0017e-06, name='S109'),
#  Clade(branch_length=0.0907859337, confidence=100, name='Node255'),
#  Clade(branch_length=0.0331962249, name='S222'),
#  Clade(branch_length=1.0017e-06, name='S165'),
#  Clade(branch_length=1.0017e-06, name='S224'),
#  Clade(branch_length=0.0094406831, name='S123'),
#  Clade(branch_length=0.012881977, name='S188'),
#  Clade(branch_length=1.0017e-06, name='S125'),
#  Clade(branch_length=1.0017e-06, name='S244'),
#  Clade(branch_length=0.0583882839, confidence=99, name='Node293'),
#  Clade(branch_length=2.1771e-06, name='S254'),
#  Clade(branch_length=0.0174330257, confidence=83, name='Node304'),
#  Clade(branch_length=0.0040329079, confidence=87, name='Node317'),
#  Clade(branch_length=0.0428508586, confidence=98, name='Node324'),
#  Clade(branch_length=0.0221344321, confidence=100, name='Node329'),
#  Clade(branch_length=0.0712116943, confidence=100, name='Node331'),
#  Clade(branch_length=0.0328835245, confidence=100, name='Node332'),
#  Clade(branch_length=0.0079138728, confidence=100, name='Node32'),
#  Clade(branch_length=0.0186237177, name='S45'),
#  Clade(branch_length=0.0008059854, confidence=63, name='Node34'),
#  Clade(branch_length=2.8329e-06, name='S31'),
#  Clade(branch_length=2.8058e-06, confidence=76, name='Node44'),
#  Clade(branch_length=0.0129759963, confidence=78, name='Node48'),
#  Clade(branch_length=0.0075477328, confidence=90, name='Node51'),
#  Clade(branch_length=0.0097056629, confidence=66, name='Node54'),
#  Clade(branch_length=2.0602e-06, confidence=98, name='Node66'),
#  Clade(branch_length=0.0614530519, confidence=100, name='Node67'),
#  Clade(branch_length=2.469e-06, name='S56'),
#  Clade(branch_length=0.1002647665, name='S67'),
#  Clade(branch_length=0.0091285334, confidence=49, name='Node104'),
#  Clade(branch_length=0.0058121329, confidence=67, name='Node111'),
#  Clade(branch_length=0.0143220058, name='S142'),
#  Clade(branch_length=0.002827564, name='S143'),
#  Clade(branch_length=0.0142140773, name='S309'),
#  Clade(branch_length=0.0052407469, confidence=97, name='Node120'),
#  Clade(branch_length=0.0112596571, confidence=71, name='Node128'),
#  Clade(branch_length=0.0028036043, name='S286'),
#  Clade(branch_length=0.0133577352, confidence=96, name='Node141'),
#  Clade(branch_length=0.0514789723, name='S136'),
#  Clade(branch_length=0.0479572575, confidence=98, name='Node151'),
#  Clade(branch_length=0.5429795106, name='S355'),
#  Clade(branch_length=2.8017e-06, name='S183'),
#  Clade(branch_length=2.146e-06, name='S354'),
#  Clade(branch_length=0.1363253265, confidence=100, name='Node173'),
#  Clade(branch_length=0.7053010024, name='S316'),
#  Clade(branch_length=0.3442664133, name='S156'),
#  Clade(branch_length=0.0954688147, confidence=89, name='Node181'),
#  Clade(branch_length=0.0248202474, confidence=100, name='Node214'),
#  Clade(branch_length=0.0178749144, confidence=91, name='Node215'),
#  Clade(branch_length=0.0094828457, confidence=100, name='Node217'),
#  Clade(branch_length=2.9514e-06, name='S265'),
#  Clade(branch_length=0.0289610803, confidence=83, name='Node231'),
#  Clade(branch_length=2.9027e-06, name='S322'),
#  Clade(branch_length=0.0388056394, name='S100'),
#  Clade(branch_length=0.0398523976, name='S345'),
#  Clade(branch_length=1.0017e-06, name='S219'),
#  Clade(branch_length=1.0017e-06, name='S221'),
#  Clade(branch_length=0.0756820559, confidence=100, name='Node294'),
#  Clade(branch_length=0.0546540628, confidence=100, name='Node301'),
#  Clade(branch_length=0.0590627344, name='S162'),
#  Clade(branch_length=0.0275175869, confidence=86, name='Node305'),
#  Clade(branch_length=0.0116014439, confidence=98, name='Node318'),
#  Clade(branch_length=0.0313158632, confidence=98, name='Node319'),
#  Clade(branch_length=0.1148835528, confidence=100, name='Node325'),
#  Clade(branch_length=0.0308696697, confidence=100, name='Node328'),
#  Clade(branch_length=1.0017e-06, name='S80'),
#  Clade(branch_length=0.0032253041, name='S235'),
#  Clade(branch_length=2.5366e-06, name='S119'),
#  Clade(branch_length=2.7919e-06, name='S241'),
#  Clade(branch_length=2.3177e-06, name='S120'),
#  Clade(branch_length=2.7213e-06, name='S242'),
#  Clade(branch_length=2.0046e-06, name='S12'),
#  Clade(branch_length=2.1996e-06, name='S14'),
#  Clade(branch_length=0.022073216, name='S17'),
#  Clade(branch_length=0.0061315755, confidence=96, name='Node35'),
#  Clade(branch_length=0.0075344323, name='S13'),
#  Clade(branch_length=0.0075328708, confidence=80, name='Node45'),
#  Clade(branch_length=0.0228292584, confidence=100, name='Node49'),
#  Clade(branch_length=2.3768e-06, name='S43'),
#  Clade(branch_length=0.0151671085, name='S15'),
#  Clade(branch_length=0.003767333, confidence=89, name='Node52'),
#  Clade(branch_length=0.0055390453, name='S16'),
#  Clade(branch_length=0.0230176014, confidence=97, name='Node55'),
#  Clade(branch_length=2.9748e-06, name='S57'),
#  Clade(branch_length=0.1172147307, name='S63'),
#  Clade(branch_length=0.0082707427, name='S58'),
#  Clade(branch_length=0.0706312424, name='S64'),
#  Clade(branch_length=0.03327625, confidence=100, name='Node105'),
#  Clade(branch_length=0.0131821282, confidence=40, name='Node110'),
#  Clade(branch_length=0.0027280667, confidence=67, name='Node112'),
#  Clade(branch_length=2.2093e-06, name='S288'),
#  Clade(branch_length=0.0090699203, confidence=100, name='Node121'),
#  Clade(branch_length=0.0198020984, name='S312'),
#  Clade(branch_length=0.0226592984, confidence=99, name='Node129'),
#  Clade(branch_length=2.0452e-06, name='S282'),
#  Clade(branch_length=0.0079857167, confidence=99, name='Node142'),
#  Clade(branch_length=0.0180204605, name='S137'),
#  Clade(branch_length=0.0492986129, confidence=99, name='Node152'),
#  Clade(branch_length=0.2466581372, confidence=100, name='Node167'),
#  Clade(branch_length=0.1941929042, confidence=100, name='Node174'),
#  Clade(branch_length=0.36450093, name='S313'),
#  Clade(branch_length=0.1100191216, confidence=100, name='Node182'),
#  Clade(branch_length=0.3843828784, confidence=100, name='Node186'),
#  Clade(branch_length=2.8276e-06, name='S89'),
#  Clade(branch_length=2.6285e-06, name='S176'),
#  Clade(branch_length=0.1321443939, name='S90'),
#  Clade(branch_length=0.0963527416, name='S343'),
#  Clade(branch_length=0.0315320498, confidence=100, name='Node218'),
#  Clade(branch_length=0.0031284132, name='S268'),
#  Clade(branch_length=0.0127216087, confidence=84, name='Node232'),
#  Clade(branch_length=2.6715e-06, name='S323'),
#  Clade(branch_length=0.0149569324, confidence=100, name='Node295'),
#  Clade(branch_length=0.0125456204, confidence=90, name='Node298'),
#  Clade(branch_length=0.0432247769, name='S238'),
#  Clade(branch_length=0.0087929431, name='S331'),
#  Clade(branch_length=0.0484432751, confidence=99, name='Node306'),
#  Clade(branch_length=0.1710550918, name='S340'),
#  Clade(branch_length=0.0207072581, name='S236'),
#  Clade(branch_length=0.0098399297, name='S333'),
#  Clade(branch_length=0.0246210271, name='S237'),
#  Clade(branch_length=0.0114909874, name='S332'),
#  Clade(branch_length=0.0736255541, confidence=100, name='Node326'),
#  Clade(branch_length=0.0237694491, confidence=100, name='Node327'),
#  Clade(branch_length=1.0017e-06, name='S79'),
#  Clade(branch_length=1.0017e-06, name='S234'),
#  Clade(branch_length=0.0060019872, confidence=99, name='Node36'),
#  Clade(branch_length=0.0117151318, name='S23'),
#  Clade(branch_length=0.0037458039, confidence=80, name='Node46'),
#  Clade(branch_length=2.7739e-06, name='S27'),
#  Clade(branch_length=2.1958e-06, name='S37'),
#  Clade(branch_length=0.0097136468, name='S38'),
#  Clade(branch_length=0.0075438162, confidence=89, name='Node53'),
#  Clade(branch_length=1.0017e-06, name='S28'),
#  Clade(branch_length=0.0214198729, name='S34'),
#  Clade(branch_length=0.0248897906, name='S35'),
#  Clade(branch_length=0.0085389398, confidence=77, name='Node106'),
#  Clade(branch_length=0.0340419678, name='S145'),
#  Clade(branch_length=0.0454576817, name='S193'),
#  Clade(branch_length=0.0562017999, name='S269'),
#  Clade(branch_length=0.0088474132, confidence=80, name='Node113'),
#  Clade(branch_length=0.0085722745, name='S290'),
#  Clade(branch_length=0.0060962204, name='S310'),
#  Clade(branch_length=0.0143504769, name='S311'),
#  Clade(branch_length=0.0027789006, confidence=99, name='Node130'),
#  Clade(branch_length=2.0409e-06, name='S281'),
#  Clade(branch_length=0.0361297932, name='S135'),
#  Clade(branch_length=0.0263057134, name='S186'),
#  Clade(branch_length=0.0315909071, confidence=100, name='Node153'),
#  Clade(branch_length=0.0765829137, confidence=99, name='Node166'),
#  Clade(branch_length=0.342837033, name='S293'),
#  Clade(branch_length=0.4417928659, name='S294'),
#  Clade(branch_length=0.0808770881, confidence=95, name='Node175'),
#  Clade(branch_length=0.0761957846, confidence=100, name='Node179'),
#  Clade(branch_length=0.2808908852, name='S270'),
#  Clade(branch_length=0.0997504577, confidence=100, name='Node183'),
#  Clade(branch_length=1.0017e-06, name='S315'),
#  Clade(branch_length=1.0017e-06, name='S317'),
#  Clade(branch_length=0.0085786637, confidence=100, name='Node219'),
#  Clade(branch_length=2.9216e-06, name='S266'),
#  Clade(branch_length=0.0296891502, confidence=95, name='Node233'),
#  Clade(branch_length=2.0092e-06, name='S320'),
#  Clade(branch_length=0.0140267012, confidence=100, name='Node296'),
#  Clade(branch_length=0.0113932462, name='S207'),
#  Clade(branch_length=0.0942747835, name='S163'),
#  Clade(branch_length=0.0086428211, confidence=51, name='Node299'),
#  Clade(branch_length=0.0011049426, confidence=89, name='Node307'),
#  Clade(branch_length=0.0149452712, name='S211'),
#  Clade(branch_length=1.0017e-06, name='S77'),
#  Clade(branch_length=1.0017e-06, name='S232'),
#  Clade(branch_length=2.9335e-06, name='S78'),
#  Clade(branch_length=1.0017e-06, name='S233'),
#  Clade(branch_length=2.7865e-06, name='S18'),
#  Clade(branch_length=0.0064363008, confidence=100, name='Node37'),
#  Clade(branch_length=0.0094189847, confidence=80, name='Node47'),
#  Clade(branch_length=2.7463e-06, name='S36'),
#  Clade(branch_length=0.0113493912, name='S22'),
#  Clade(branch_length=0.0352999162, name='S26'),
#  Clade(branch_length=0.023687602, confidence=100, name='Node107'),
#  Clade(branch_length=0.0160224983, name='S146'),
#  Clade(branch_length=0.044106061, name='S141'),
#  Clade(branch_length=0.0577650678, name='S148'),
#  Clade(branch_length=0.0286508922, confidence=100, name='Node131'),
#  Clade(branch_length=2.165e-06, name='S280'),
#  Clade(branch_length=0.1185147504, confidence=100, name='Node154'),
#  Clade(branch_length=0.0894279138, confidence=100, name='Node162'),
#  Clade(branch_length=0.2543449078, name='S295'),
#  Clade(branch_length=0.2824150654, name='S296'),
#  Clade(branch_length=0.0602789063, confidence=100, name='Node176'),
#  Clade(branch_length=0.0504842591, confidence=95, name='Node177'),
#  Clade(branch_length=0.1510808613, name='S184'),
#  Clade(branch_length=0.1833875613, name='S185'),
#  Clade(branch_length=0.2861623661, confidence=100, name='Node184'),
#  Clade(branch_length=0.1469921082, confidence=100, name='Node185'),
#  Clade(branch_length=0.0163371753, confidence=95, name='Node220'),
#  Clade(branch_length=0.0458123844, confidence=100, name='Node227'),
#  Clade(branch_length=0.0051475472, confidence=79, name='Node234'),
#  Clade(branch_length=0.0043066754, confidence=78, name='Node238'),
#  Clade(branch_length=0.0031500494, confidence=100, name='Node297'),
#  Clade(branch_length=2.5211e-06, name='S204'),
#  Clade(branch_length=0.0053414817, name='S210'),
#  Clade(branch_length=0.0181114977, confidence=100, name='Node300'),
#  Clade(branch_length=0.0097295797, confidence=99, name='Node308'),
#  Clade(branch_length=0.0056366391, confidence=91, name='Node310'),
#  Clade(branch_length=0.009648144, confidence=98, name='Node38'),
#  Clade(branch_length=2.8685e-06, confidence=97, name='Node40'),
#  Clade(branch_length=0.0258185435, name='S24'),
#  Clade(branch_length=0.0354880443, name='S29'),
#  Clade(branch_length=0.0503332257, confidence=100, name='Node108'),
#  Clade(branch_length=0.0104391652, confidence=100, name='Node109'),
#  Clade(branch_length=0.0445861987, confidence=100, name='Node132'),
#  Clade(branch_length=2.8884e-06, name='S287'),
#  Clade(branch_length=0.0457089672, confidence=100, name='Node155'),
#  Clade(branch_length=0.0460892367, confidence=100, name='Node160'),
#  Clade(branch_length=0.1611867018, name='S271'),
#  Clade(branch_length=0.0785453245, confidence=100, name='Node163'),
#  Clade(branch_length=0.1256613439, name='S153'),
#  Clade(branch_length=0.278999927, name='S154'),
#  Clade(branch_length=0.0777182629, confidence=100, name='Node178'),
#  Clade(branch_length=0.1080028948, name='S199'),
#  Clade(branch_length=0.0322227238, name='S272'),
#  Clade(branch_length=0.0192979889, name='S275'),
#  Clade(branch_length=0.0144646928, name='S273'),
#  Clade(branch_length=0.0238596391, name='S274'),
#  Clade(branch_length=0.0233522757, confidence=95, name='Node221'),
#  Clade(branch_length=0.1337524559, confidence=100, name='Node225'),
#  Clade(branch_length=0.0478937833, confidence=100, name='Node228'),
#  Clade(branch_length=0.0434885568, name='S292'),
#  Clade(branch_length=0.1001361627, confidence=100, name='Node235'),
#  Clade(branch_length=0.0154034638, confidence=84, name='Node236'),
#  Clade(branch_length=0.0193649766, confidence=94, name='Node239'),
#  Clade(branch_length=0.0089257258, name='S267'),
#  Clade(branch_length=1.0017e-06, name='S75'),
#  Clade(branch_length=1.0017e-06, name='S201'),
#  Clade(branch_length=0.0154304788, name='S213'),
#  Clade(branch_length=0.0344675512, name='S216'),
#  Clade(branch_length=0.0096819244, confidence=100, name='Node309'),
#  Clade(branch_length=2.0736e-06, name='S208'),
#  Clade(branch_length=0.0301790164, confidence=100, name='Node311'),
#  Clade(branch_length=0.0099488084, confidence=93, name='Node316'),
#  Clade(branch_length=0.0032299986, confidence=100, name='Node39'),
#  Clade(branch_length=0.0164132122, name='S42'),
#  Clade(branch_length=0.0036226011, confidence=100, name='Node41'),
#  Clade(branch_length=0.012956285, name='S46'),
#  Clade(branch_length=1.0017e-06, name='S73'),
#  Clade(branch_length=1.0017e-06, name='S144'),
#  Clade(branch_length=0.007842366, name='S140'),
#  Clade(branch_length=0.0102549601, name='S147'),
#  Clade(branch_length=0.0693727866, confidence=100, name='Node133'),
#  Clade(branch_length=0.0461266749, confidence=100, name='Node134'),
#  Clade(branch_length=0.0256704646, confidence=100, name='Node156'),
#  Clade(branch_length=0.1084528227, name='S297'),
#  Clade(branch_length=0.0512760921, name='S298'),
#  Clade(branch_length=0.0575352592, confidence=100, name='Node161'),
#  Clade(branch_length=0.3185822424, confidence=100, name='Node164'),
#  Clade(branch_length=0.0822917804, confidence=100, name='Node165'),
#  Clade(branch_length=0.0119262341, name='S198'),
#  Clade(branch_length=0.0302065931, name='S200'),
#  Clade(branch_length=0.0382271242, confidence=100, name='Node222'),
#  Clade(branch_length=0.0062143228, confidence=89, name='Node223'),
#  Clade(branch_length=2.3485e-06, name='Node226'),
#  Clade(branch_length=2.2555e-06, name='S127'),
#  Clade(branch_length=1.0017e-06, name='S92'),
#  Clade(branch_length=2.3673e-06, name='S152'),
#  Clade(branch_length=2.8866e-06, name='S95'),
#  Clade(branch_length=2.6889e-06, name='S181'),
#  Clade(branch_length=0.0156882566, confidence=76, name='Node237'),
#  Clade(branch_length=0.0780287698, name='S197'),
#  Clade(branch_length=0.0343074759, confidence=100, name='Node240'),
#  Clade(branch_length=0.0127732514, confidence=94, name='Node242'),
#  Clade(branch_length=2.3289e-06, name='S202'),
#  Clade(branch_length=2.0276e-06, name='S205'),
#  Clade(branch_length=0.0064306785, confidence=100, name='Node312'),
#  Clade(branch_length=0.0129535656, confidence=100, name='Node314'),
#  Clade(branch_length=0.0294928898, name='S214'),
#  Clade(branch_length=0.0037096358, name='S217'),
#  Clade(branch_length=1.0017e-06, name='S19'),
#  Clade(branch_length=1.0017e-06, name='S41'),
#  Clade(branch_length=0.0095809483, name='S44'),
#  Clade(branch_length=0.0063445378, name='S47'),
#  Clade(branch_length=2.7713e-06, name='S83'),
#  Clade(branch_length=2.4128e-06, name='S133'),
#  Clade(branch_length=0.0284710108, confidence=100, name='Node135'),
#  Clade(branch_length=0.0253940613, name='S334'),
#  Clade(branch_length=0.0665649634, confidence=100, name='Node157'),
#  Clade(branch_length=0.1870826393, confidence=100, name='Node158'),
#  Clade(branch_length=0.0071706175, name='S299'),
#  Clade(branch_length=0.027912599, name='S300'),
#  Clade(branch_length=0.0883739028, name='S276'),
#  Clade(branch_length=0.0775589979, name='S278'),
#  Clade(branch_length=0.052903868, name='S277'),
#  Clade(branch_length=0.0150468713, name='S279'),
#  Clade(branch_length=1.0017e-06, name='S91'),
#  Clade(branch_length=1.0017e-06, name='S173'),
#  Clade(branch_length=0.0981262691, confidence=100, name='Node224'),
#  Clade(branch_length=0.0247247483, name='S189'),
#  Clade(branch_length=0.0, name='S93'),
#  Clade(branch_length=0.0, name='S174'),
#  Clade(branch_length=0.0643417359, name='S99'),
#  Clade(branch_length=0.1232332713, name='S303'),
#  Clade(branch_length=0.0147968714, name='S96'),
#  Clade(branch_length=0.0172628535, confidence=99, name='Node241'),
#  Clade(branch_length=0.1063655738, confidence=100, name='Node243'),
#  Clade(branch_length=0.0625151082, name='S344'),
#  Clade(branch_length=0.0127417895, confidence=100, name='Node313'),
#  Clade(branch_length=0.0094979432, name='S209'),
#  Clade(branch_length=0.0258232949, confidence=100, name='Node315'),
#  Clade(branch_length=0.0061013149, name='S218'),
#  Clade(branch_length=0.0085812908, confidence=98, name='Node136'),
#  Clade(branch_length=2.756e-06, name='S336'),
#  Clade(branch_length=0.1375488754, name='S107'),
#  Clade(branch_length=0.1117712527, name='S108'),
#  Clade(branch_length=0.0244597051, confidence=100, name='Node159'),
#  Clade(branch_length=0.0105555973, name='S157'),
#  Clade(branch_length=2.18e-06, name='S94'),
#  Clade(branch_length=2.4008e-06, name='S175'),
#  Clade(branch_length=0.0274350788, name='S97'),
#  Clade(branch_length=0.07645183, name='S291'),
#  Clade(branch_length=1.0017e-06, name='S98'),
#  Clade(branch_length=1.0017e-06, name='S172'),
#  Clade(branch_length=0.0063137284, name='S203'),
#  Clade(branch_length=1.0017e-06, name='S206'),
#  Clade(branch_length=0.0062550112, name='S212'),
#  Clade(branch_length=2.1328e-06, name='S215'),
#  Clade(branch_length=0.0178129685, confidence=100, name='Node137'),
#  Clade(branch_length=0.0093015476, name='S337'),
#  Clade(branch_length=0.0164209146, name='S155'),
#  Clade(branch_length=0.0383535642, name='S301'),
#  Clade(branch_length=0.0128164574, confidence=100, name='Node138'),
#  Clade(branch_length=0.1022715385, name='S160'),
#  Clade(branch_length=0.0031323366, confidence=99, name='Node139'),
#  Clade(branch_length=0.0057127311, name='S159'),
#  Clade(branch_length=2.1813e-06, name='S158'),
#  Clade(branch_length=0.0180829221, name='S161')]

# %%
# Create a mapping from node names to indices
node_to_index = {clade.name: idx for idx, clade in enumerate(clades)}
node_to_index
# Out:
# {'Node1': 0,
#  'Bovine': 1,
#  'Node2': 2,
#  'Node350': 3,
#  'Node3': 4,
#  'S245': 5,
#  'Node351': 6,
#  'Node355': 7,
#  'Node4': 8,
#  'Node340': 9,
#  'Node352': 10,
#  'Node353': 11,
#  'Node356': 12,
#  'S349': 13,
#  'Node5': 14,
#  'Node336': 15,
#  'Node341': 16,
#  'Node346': 17,
#  'S61': 18,
#  'S106': 19,
#  'Node354': 20,
#  'S194': 21,
#  'Node357': 22,
#  'S302': 23,
#  'Node6': 24,
#  'Node86': 25,
#  'S40': 26,
#  'Node337': 27,
#  'S68': 28,
#  'Node342': 29,
#  'Node347': 30,
#  'S187': 31,
#  'S104': 32,
#  'S105': 33,
#  'Node358': 34,
#  'S348': 35,
#  'Node7': 36,
#  'S48': 37,
#  'Node87': 38,
#  'Node89': 39,
#  'Node338': 40,
#  'S115': 41,
#  'Node343': 42,
#  'S342': 43,
#  'Node348': 44,
#  'S117': 45,
#  'Node359': 46,
#  'S103': 47,
#  'Node8': 48,
#  'S49': 49,
#  'S60': 50,
#  'Node88': 51,
#  'Node90': 52,
#  'Node335': 53,
#  'S112': 54,
#  'Node339': 55,
#  'Node344': 56,
#  'Node345': 57,
#  'S116': 58,
#  'Node349': 59,
#  'Node360': 60,
#  'S101': 61,
#  'Node9': 62,
#  'Node81': 63,
#  'S178': 64,
#  'S180': 65,
#  'Node91': 66,
#  'Node333': 67,
#  'S350': 68,
#  'S351': 69,
#  'S113': 70,
#  'S114': 71,
#  'S304': 72,
#  'S305': 73,
#  'S306': 74,
#  'S307': 75,
#  'S118': 76,
#  'S243': 77,
#  'S72': 78,
#  'S102': 79,
#  'Node10': 80,
#  'Node79': 81,
#  'S50': 82,
#  'Node82': 83,
#  'Node92': 84,
#  'Node271': 85,
#  'S82': 86,
#  'Node334': 87,
#  'Node11': 88,
#  'S70': 89,
#  'Node80': 90,
#  'S179': 91,
#  'Node83': 92,
#  'Node84': 93,
#  'Node93': 94,
#  'S171': 95,
#  'Node272': 96,
#  'S246': 97,
#  'S170': 98,
#  'S259': 99,
#  'Node12': 100,
#  'Node74': 101,
#  'S110': 102,
#  'S177': 103,
#  'S51': 104,
#  'S59': 105,
#  'Node85': 106,
#  'S192': 107,
#  'Node94': 108,
#  'Node245': 109,
#  'Node273': 110,
#  'S247': 111,
#  'Node13': 112,
#  'Node23': 113,
#  'S191': 114,
#  'Node75': 115,
#  'S52': 116,
#  'S69': 117,
#  'Node95': 118,
#  'Node191': 119,
#  'Node246': 120,
#  'S169': 121,
#  'Node274': 122,
#  'S260': 123,
#  'Node14': 124,
#  'Node22': 125,
#  'Node24': 126,
#  'Node72': 127,
#  'S357': 128,
#  'Node76': 129,
#  'Node96': 130,
#  'Node190': 131,
#  'Node192': 132,
#  'Node204': 133,
#  'Node247': 134,
#  'Node267': 135,
#  'Node275': 136,
#  'Node286': 137,
#  'Node15': 138,
#  'Node20': 139,
#  'S10': 140,
#  'S11': 141,
#  'Node25': 142,
#  'Node59': 143,
#  'Node73': 144,
#  'S338': 145,
#  'S358': 146,
#  'Node77': 147,
#  'Node97': 148,
#  'Node144': 149,
#  'S150': 150,
#  'S151': 151,
#  'Node193': 152,
#  'S321': 153,
#  'Node205': 154,
#  'S261': 155,
#  'Node248': 156,
#  'Node264': 157,
#  'S129': 158,
#  'Node268': 159,
#  'Node276': 160,
#  'S256': 161,
#  'Node287': 162,
#  'S248': 163,
#  'Node16': 164,
#  'Node18': 165,
#  'S5': 166,
#  'Node21': 167,
#  'Node26': 168,
#  'S39': 169,
#  'Node60': 170,
#  'Node71': 171,
#  'S111': 172,
#  'S167': 173,
#  'Node78': 174,
#  'S360': 175,
#  'Node98': 176,
#  'Node122': 177,
#  'Node145': 178,
#  'S182': 179,
#  'Node194': 180,
#  'Node197': 181,
#  'Node206': 182,
#  'S168': 183,
#  'Node249': 184,
#  'S225': 185,
#  'Node265': 186,
#  'Node266': 187,
#  'Node269': 188,
#  'S131': 189,
#  'Node277': 190,
#  'Node278': 191,
#  'Node288': 192,
#  'S249': 193,
#  'Node17': 194,
#  'S4': 195,
#  'S3': 196,
#  'Node19': 197,
#  'S6': 198,
#  'S7': 199,
#  'Node27': 200,
#  'S33': 201,
#  'Node61': 202,
#  'S54': 203,
#  'S62': 204,
#  'S71': 205,
#  'S359': 206,
#  'S361': 207,
#  'Node99': 208,
#  'Node115': 209,
#  'Node123': 210,
#  'S346': 211,
#  'Node146': 212,
#  'S314': 213,
#  'Node195': 214,
#  'S86': 215,
#  'Node198': 216,
#  'S326': 217,
#  'Node207': 218,
#  'Node209': 219,
#  'Node250': 220,
#  'Node258': 221,
#  'S128': 222,
#  'S230': 223,
#  'S229': 224,
#  'S231': 225,
#  'Node270': 226,
#  'S190': 227,
#  'S74': 228,
#  'S122': 229,
#  'Node279': 230,
#  'Node285': 231,
#  'Node289': 232,
#  'Node320': 233,
#  'S1': 234,
#  'S2': 235,
#  'S8': 236,
#  'S9': 237,
#  'Node28': 238,
#  'Node56': 239,
#  'S53': 240,
#  'Node62': 241,
#  'Node100': 242,
#  'S283': 243,
#  'Node116': 244,
#  'S284': 245,
#  'S81': 246,
#  'Node124': 247,
#  'Node147': 248,
#  'Node187': 249,
#  'Node196': 250,
#  'S126': 251,
#  'Node199': 252,
#  'Node203': 253,
#  'Node208': 254,
#  'S88': 255,
#  'Node210': 256,
#  'S262': 257,
#  'Node251': 258,
#  'Node256': 259,
#  'Node259': 260,
#  'Node262': 261,
#  'S130': 262,
#  'S132': 263,
#  'Node280': 264,
#  'Node281': 265,
#  'S257': 266,
#  'S258': 267,
#  'Node290': 268,
#  'S252': 269,
#  'Node321': 270,
#  'S250': 271,
#  'Node29': 272,
#  'S25': 273,
#  'S20': 274,
#  'Node57': 275,
#  'Node63': 276,
#  'Node70': 277,
#  'Node101': 278,
#  'S285': 279,
#  'Node117': 280,
#  'S139': 281,
#  'Node125': 282,
#  'Node143': 283,
#  'Node148': 284,
#  'Node170': 285,
#  'Node188': 286,
#  'S352': 287,
#  'S85': 288,
#  'S327': 289,
#  'Node200': 290,
#  'Node202': 291,
#  'S324': 292,
#  'S339': 293,
#  'S87': 294,
#  'S263': 295,
#  'Node211': 296,
#  'S264': 297,
#  'Node252': 298,
#  'S330': 299,
#  'Node257': 300,
#  'S227': 301,
#  'Node260': 302,
#  'S226': 303,
#  'S220': 304,
#  'Node263': 305,
#  'S76': 306,
#  'S121': 307,
#  'Node282': 308,
#  'S124': 309,
#  'Node291': 310,
#  'Node302': 311,
#  'Node322': 312,
#  'S251': 313,
#  'Node30': 314,
#  'Node42': 315,
#  'Node58': 316,
#  'S32': 317,
#  'Node64': 318,
#  'Node68': 319,
#  'S65': 320,
#  'S356': 321,
#  'Node102': 322,
#  'S149': 323,
#  'Node118': 324,
#  'S289': 325,
#  'Node126': 326,
#  'S134': 327,
#  'S308': 328,
#  'S341': 329,
#  'Node149': 330,
#  'Node169': 331,
#  'Node171': 332,
#  'S318': 333,
#  'Node189': 334,
#  'S353': 335,
#  'Node201': 336,
#  'S335': 337,
#  'S240': 338,
#  'S328': 339,
#  'Node212': 340,
#  'Node229': 341,
#  'Node253': 342,
#  'Node254': 343,
#  'S164': 344,
#  'S223': 345,
#  'Node261': 346,
#  'S228': 347,
#  'S239': 348,
#  'S329': 349,
#  'Node283': 350,
#  'Node284': 351,
#  'Node292': 352,
#  'S253': 353,
#  'Node303': 354,
#  'S255': 355,
#  'Node323': 356,
#  'Node330': 357,
#  'Node31': 358,
#  'Node33': 359,
#  'Node43': 360,
#  'Node50': 361,
#  'S21': 362,
#  'S30': 363,
#  'S55': 364,
#  'Node65': 365,
#  'Node69': 366,
#  'S66': 367,
#  'Node103': 368,
#  'Node114': 369,
#  'S138': 370,
#  'Node119': 371,
#  'Node127': 372,
#  'Node140': 373,
#  'Node150': 374,
#  'Node168': 375,
#  'S319': 376,
#  'S347': 377,
#  'Node172': 378,
#  'Node180': 379,
#  'S195': 380,
#  'S196': 381,
#  'S166': 382,
#  'S325': 383,
#  'Node213': 384,
#  'Node216': 385,
#  'Node230': 386,
#  'Node244': 387,
#  'S84': 388,
#  'S109': 389,
#  'Node255': 390,
#  'S222': 391,
#  'S165': 392,
#  'S224': 393,
#  'S123': 394,
#  'S188': 395,
#  'S125': 396,
#  'S244': 397,
#  'Node293': 398,
#  'S254': 399,
#  'Node304': 400,
#  'Node317': 401,
#  'Node324': 402,
#  'Node329': 403,
#  'Node331': 404,
#  'Node332': 405,
#  'Node32': 406,
#  'S45': 407,
#  'Node34': 408,
#  'S31': 409,
#  'Node44': 410,
#  'Node48': 411,
#  'Node51': 412,
#  'Node54': 413,
#  'Node66': 414,
#  'Node67': 415,
#  'S56': 416,
#  'S67': 417,
#  'Node104': 418,
#  'Node111': 419,
#  'S142': 420,
#  'S143': 421,
#  'S309': 422,
#  'Node120': 423,
#  'Node128': 424,
#  'S286': 425,
#  'Node141': 426,
#  'S136': 427,
#  'Node151': 428,
#  'S355': 429,
#  'S183': 430,
#  'S354': 431,
#  'Node173': 432,
#  'S316': 433,
#  'S156': 434,
#  'Node181': 435,
#  'Node214': 436,
#  'Node215': 437,
#  'Node217': 438,
#  'S265': 439,
#  'Node231': 440,
#  'S322': 441,
#  'S100': 442,
#  'S345': 443,
#  'S219': 444,
#  'S221': 445,
#  'Node294': 446,
#  'Node301': 447,
#  'S162': 448,
#  'Node305': 449,
#  'Node318': 450,
#  'Node319': 451,
#  'Node325': 452,
#  'Node328': 453,
#  'S80': 454,
#  'S235': 455,
#  'S119': 456,
#  'S241': 457,
#  'S120': 458,
#  'S242': 459,
#  'S12': 460,
#  'S14': 461,
#  'S17': 462,
#  'Node35': 463,
#  'S13': 464,
#  'Node45': 465,
#  'Node49': 466,
#  'S43': 467,
#  'S15': 468,
#  'Node52': 469,
#  'S16': 470,
#  'Node55': 471,
#  'S57': 472,
#  'S63': 473,
#  'S58': 474,
#  'S64': 475,
#  'Node105': 476,
#  'Node110': 477,
#  'Node112': 478,
#  'S288': 479,
#  'Node121': 480,
#  'S312': 481,
#  'Node129': 482,
#  'S282': 483,
#  'Node142': 484,
#  'S137': 485,
#  'Node152': 486,
#  'Node167': 487,
#  'Node174': 488,
#  'S313': 489,
#  'Node182': 490,
#  'Node186': 491,
#  'S89': 492,
#  'S176': 493,
#  'S90': 494,
#  'S343': 495,
#  'Node218': 496,
#  'S268': 497,
#  'Node232': 498,
#  'S323': 499,
#  'Node295': 500,
#  'Node298': 501,
#  'S238': 502,
#  'S331': 503,
#  'Node306': 504,
#  'S340': 505,
#  'S236': 506,
#  'S333': 507,
#  'S237': 508,
#  'S332': 509,
#  'Node326': 510,
#  'Node327': 511,
#  'S79': 512,
#  'S234': 513,
#  'Node36': 514,
#  'S23': 515,
#  'Node46': 516,
#  'S27': 517,
#  'S37': 518,
#  'S38': 519,
#  'Node53': 520,
#  'S28': 521,
#  'S34': 522,
#  'S35': 523,
#  'Node106': 524,
#  'S145': 525,
#  'S193': 526,
#  'S269': 527,
#  'Node113': 528,
#  'S290': 529,
#  'S310': 530,
#  'S311': 531,
#  'Node130': 532,
#  'S281': 533,
#  'S135': 534,
#  'S186': 535,
#  'Node153': 536,
#  'Node166': 537,
#  'S293': 538,
#  'S294': 539,
#  'Node175': 540,
#  'Node179': 541,
#  'S270': 542,
#  'Node183': 543,
#  'S315': 544,
#  'S317': 545,
#  'Node219': 546,
#  'S266': 547,
#  'Node233': 548,
#  'S320': 549,
#  'Node296': 550,
#  'S207': 551,
#  'S163': 552,
#  'Node299': 553,
#  'Node307': 554,
#  'S211': 555,
#  'S77': 556,
#  'S232': 557,
#  'S78': 558,
#  'S233': 559,
#  'S18': 560,
#  'Node37': 561,
#  'Node47': 562,
#  'S36': 563,
#  'S22': 564,
#  'S26': 565,
#  'Node107': 566,
#  'S146': 567,
#  'S141': 568,
#  'S148': 569,
#  'Node131': 570,
#  'S280': 571,
#  'Node154': 572,
#  'Node162': 573,
#  'S295': 574,
#  'S296': 575,
#  'Node176': 576,
#  'Node177': 577,
#  'S184': 578,
#  'S185': 579,
#  'Node184': 580,
#  'Node185': 581,
#  'Node220': 582,
#  'Node227': 583,
#  'Node234': 584,
#  'Node238': 585,
#  'Node297': 586,
#  'S204': 587,
#  'S210': 588,
#  'Node300': 589,
#  'Node308': 590,
#  'Node310': 591,
#  'Node38': 592,
#  'Node40': 593,
#  'S24': 594,
#  'S29': 595,
#  'Node108': 596,
#  'Node109': 597,
#  'Node132': 598,
#  'S287': 599,
#  'Node155': 600,
#  'Node160': 601,
#  'S271': 602,
#  'Node163': 603,
#  'S153': 604,
#  'S154': 605,
#  'Node178': 606,
#  'S199': 607,
#  'S272': 608,
#  'S275': 609,
#  'S273': 610,
#  'S274': 611,
#  'Node221': 612,
#  'Node225': 613,
#  'Node228': 614,
#  'S292': 615,
#  'Node235': 616,
#  'Node236': 617,
#  'Node239': 618,
#  'S267': 619,
#  'S75': 620,
#  'S201': 621,
#  'S213': 622,
#  'S216': 623,
#  'Node309': 624,
#  'S208': 625,
#  'Node311': 626,
#  'Node316': 627,
#  'Node39': 628,
#  'S42': 629,
#  'Node41': 630,
#  'S46': 631,
#  'S73': 632,
#  'S144': 633,
#  'S140': 634,
#  'S147': 635,
#  'Node133': 636,
#  'Node134': 637,
#  'Node156': 638,
#  'S297': 639,
#  'S298': 640,
#  'Node161': 641,
#  'Node164': 642,
#  'Node165': 643,
#  'S198': 644,
#  'S200': 645,
#  'Node222': 646,
#  'Node223': 647,
#  'Node226': 648,
#  'S127': 649,
#  'S92': 650,
#  'S152': 651,
#  'S95': 652,
#  'S181': 653,
#  'Node237': 654,
#  'S197': 655,
#  'Node240': 656,
#  'Node242': 657,
#  'S202': 658,
#  'S205': 659,
#  'Node312': 660,
#  'Node314': 661,
#  'S214': 662,
#  'S217': 663,
#  'S19': 664,
#  'S41': 665,
#  'S44': 666,
#  'S47': 667,
#  'S83': 668,
#  'S133': 669,
#  'Node135': 670,
#  'S334': 671,
#  'Node157': 672,
#  'Node158': 673,
#  'S299': 674,
#  'S300': 675,
#  'S276': 676,
#  'S278': 677,
#  'S277': 678,
#  'S279': 679,
#  'S91': 680,
#  'S173': 681,
#  'Node224': 682,
#  'S189': 683,
#  'S93': 684,
#  'S174': 685,
#  'S99': 686,
#  'S303': 687,
#  'S96': 688,
#  'Node241': 689,
#  'Node243': 690,
#  'S344': 691,
#  'Node313': 692,
#  'S209': 693,
#  'Node315': 694,
#  'S218': 695,
#  'Node136': 696,
#  'S336': 697,
#  'S107': 698,
#  'S108': 699,
#  'Node159': 700,
#  'S157': 701,
#  'S94': 702,
#  'S175': 703,
#  'S97': 704,
#  'S291': 705,
#  'S98': 706,
#  'S172': 707,
#  'S203': 708,
#  'S206': 709,
#  'S212': 710,
#  'S215': 711,
#  'Node137': 712,
#  'S337': 713,
#  'S155': 714,
#  'S301': 715,
#  'Node138': 716,
#  'S160': 717,
#  'Node139': 718,
#  'S159': 719,
#  'S158': 720,
#  'S161': 721}

# %%
def get_parent_dict(tree):
    parent_dict = {}
    for clade in tree.find_clades(order='level'):
        for child in clade.clades:
            parent_dict[child] = clade
    return parent_dict

# Create the parent dictionary
parent_dict = get_parent_dict(tree)
parent_dict
# Out:
# {Clade(branch_length=0.040201682, name='Bovine'): Clade(name='Node1'),
#  Clade(branch_length=0.0477538258, confidence=97, name='Node2'): Clade(name='Node1'),
#  Clade(branch_length=0.0130588113, confidence=85, name='Node350'): Clade(name='Node1'),
#  Clade(branch_length=0.0109293208, confidence=50, name='Node3'): Clade(branch_length=0.0477538258, confidence=97, name='Node2'),
#  Clade(branch_length=0.0001375959, name='S245'): Clade(branch_length=0.0477538258, confidence=97, name='Node2'),
#  Clade(branch_length=0.0058539809, confidence=87, name='Node351'): Clade(branch_length=0.0130588113, confidence=85, name='Node350'),
#  Clade(branch_length=0.0180398811, confidence=93, name='Node355'): Clade(branch_length=0.0130588113, confidence=85, name='Node350'),
#  Clade(branch_length=0.0183666775, confidence=52, name='Node4'): Clade(branch_length=0.0109293208, confidence=50, name='Node3'),
#  Clade(branch_length=0.0114811752, confidence=92, name='Node340'): Clade(branch_length=0.0109293208, confidence=50, name='Node3'),
#  Clade(branch_length=0.0186175675, confidence=93, name='Node352'): Clade(branch_length=0.0058539809, confidence=87, name='Node351'),
#  Clade(branch_length=0.0092278303, confidence=96, name='Node353'): Clade(branch_length=0.0058539809, confidence=87, name='Node351'),
#  Clade(branch_length=0.0297588075, confidence=100, name='Node356'): Clade(branch_length=0.0180398811, confidence=93, name='Node355'),
#  Clade(branch_length=0.0103421649, name='S349'): Clade(branch_length=0.0180398811, confidence=93, name='Node355'),
#  Clade(branch_length=0.0200437049, confidence=92, name='Node5'): Clade(branch_length=0.0183666775, confidence=52, name='Node4'),
#  Clade(branch_length=0.0215849477, confidence=56, name='Node336'): Clade(branch_length=0.0183666775, confidence=52, name='Node4'),
#  Clade(branch_length=0.075262427, confidence=100, name='Node341'): Clade(branch_length=0.0114811752, confidence=92, name='Node340'),
#  Clade(branch_length=0.0403362052, confidence=100, name='Node346'): Clade(branch_length=0.0114811752, confidence=92, name='Node340'),
#  Clade(branch_length=0.0328809403, name='S61'): Clade(branch_length=0.0186175675, confidence=93, name='Node352'),
#  Clade(branch_length=0.0205239292, name='S106'): Clade(branch_length=0.0186175675, confidence=93, name='Node352'),
#  Clade(branch_length=0.0160955267, confidence=100, name='Node354'): Clade(branch_length=0.0092278303, confidence=96, name='Node353'),
#  Clade(branch_length=0.0373745588, name='S194'): Clade(branch_length=0.0092278303, confidence=96, name='Node353'),
#  Clade(branch_length=0.0032603551, confidence=77, name='Node357'): Clade(branch_length=0.0297588075, confidence=100, name='Node356'),
#  Clade(branch_length=0.0128938544, name='S302'): Clade(branch_length=0.0297588075, confidence=100, name='Node356'),
#  Clade(branch_length=0.01191206, confidence=98, name='Node6'): Clade(branch_length=0.0200437049, confidence=92, name='Node5'),
#  Clade(branch_length=0.022550761, confidence=93, name='Node86'): Clade(branch_length=0.0200437049, confidence=92, name='Node5'),
#  Clade(branch_length=0.0796086839, name='S40'): Clade(branch_length=0.0215849477, confidence=56, name='Node336'),
#  Clade(branch_length=0.0266492236, confidence=100, name='Node337'): Clade(branch_length=0.0215849477, confidence=56, name='Node336'),
#  Clade(branch_length=0.0708495184, name='S68'): Clade(branch_length=0.075262427, confidence=100, name='Node341'),
#  Clade(branch_length=0.0259101821, confidence=100, name='Node342'): Clade(branch_length=0.075262427, confidence=100, name='Node341'),
#  Clade(branch_length=0.0051013599, confidence=100, name='Node347'): Clade(branch_length=0.0403362052, confidence=100, name='Node346'),
#  Clade(branch_length=0.0025763614, name='S187'): Clade(branch_length=0.0403362052, confidence=100, name='Node346'),
#  Clade(branch_length=0.003223395, name='S104'): Clade(branch_length=0.0160955267, confidence=100, name='Node354'),
#  Clade(branch_length=0.0098248263, name='S105'): Clade(branch_length=0.0160955267, confidence=100, name='Node354'),
#  Clade(branch_length=0.0029443034, confidence=74, name='Node358'): Clade(branch_length=0.0032603551, confidence=77, name='Node357'),
#  Clade(branch_length=2.2432e-06, name='S348'): Clade(branch_length=0.0032603551, confidence=77, name='Node357'),
#  Clade(branch_length=0.0392024144, confidence=100, name='Node7'): Clade(branch_length=0.01191206, confidence=98, name='Node6'),
#  Clade(branch_length=2.8888e-06, name='S48'): Clade(branch_length=0.01191206, confidence=98, name='Node6'),
#  Clade(branch_length=0.0292550791, confidence=51, name='Node87'): Clade(branch_length=0.022550761, confidence=93, name='Node86'),
#  Clade(branch_length=0.0260259897, confidence=51, name='Node89'): Clade(branch_length=0.022550761, confidence=93, name='Node86'),
#  Clade(branch_length=0.0350336414, confidence=100, name='Node338'): Clade(branch_length=0.0266492236, confidence=100, name='Node337'),
#  Clade(branch_length=0.0552597215, name='S115'): Clade(branch_length=0.0266492236, confidence=100, name='Node337'),
#  Clade(branch_length=0.0250304658, confidence=100, name='Node343'): Clade(branch_length=0.0259101821, confidence=100, name='Node342'),
#  Clade(branch_length=0.0593963935, name='S342'): Clade(branch_length=0.0259101821, confidence=100, name='Node342'),
#  Clade(branch_length=0.0044904765, confidence=100, name='Node348'): Clade(branch_length=0.0051013599, confidence=100, name='Node347'),
#  Clade(branch_length=0.0085375353, name='S117'): Clade(branch_length=0.0051013599, confidence=100, name='Node347'),
#  Clade(branch_length=0.0130701389, confidence=100, name='Node359'): Clade(branch_length=0.0029443034, confidence=74, name='Node358'),
#  Clade(branch_length=0.0367145001, name='S103'): Clade(branch_length=0.0029443034, confidence=74, name='Node358'),
#  Clade(branch_length=2.0202e-06, confidence=94, name='Node8'): Clade(branch_length=0.0392024144, confidence=100, name='Node7'),
#  Clade(branch_length=2.2642e-06, name='S49'): Clade(branch_length=0.0392024144, confidence=100, name='Node7'),
#  Clade(branch_length=0.0950348126, name='S60'): Clade(branch_length=0.0292550791, confidence=51, name='Node87'),
#  Clade(branch_length=0.1841878397, confidence=100, name='Node88'): Clade(branch_length=0.0292550791, confidence=51, name='Node87'),
#  Clade(branch_length=0.0838378232, confidence=100, name='Node90'): Clade(branch_length=0.0260259897, confidence=51, name='Node89'),
#  Clade(branch_length=0.1008483598, confidence=100, name='Node335'): Clade(branch_length=0.0260259897, confidence=51, name='Node89'),
#  Clade(branch_length=0.060752003, name='S112'): Clade(branch_length=0.0350336414, confidence=100, name='Node338'),
#  Clade(branch_length=0.0426258386, confidence=100, name='Node339'): Clade(branch_length=0.0350336414, confidence=100, name='Node338'),
#  Clade(branch_length=0.0069728884, confidence=100, name='Node344'): Clade(branch_length=0.0250304658, confidence=100, name='Node343'),
#  Clade(branch_length=0.0239747656, confidence=100, name='Node345'): Clade(branch_length=0.0250304658, confidence=100, name='Node343'),
#  Clade(branch_length=0.0125764012, name='S116'): Clade(branch_length=0.0044904765, confidence=100, name='Node348'),
#  Clade(branch_length=0.0082943348, confidence=100, name='Node349'): Clade(branch_length=0.0044904765, confidence=100, name='Node348'),
#  Clade(branch_length=0.0096733787, confidence=100, name='Node360'): Clade(branch_length=0.0130701389, confidence=100, name='Node359'),
#  Clade(branch_length=2.5602e-06, name='S101'): Clade(branch_length=0.0130701389, confidence=100, name='Node359'),
#  Clade(branch_length=0.0643327722, confidence=61, name='Node9'): Clade(branch_length=2.0202e-06, confidence=94, name='Node8'),
#  Clade(branch_length=0.0227601489, confidence=55, name='Node81'): Clade(branch_length=2.0202e-06, confidence=94, name='Node8'),
#  Clade(branch_length=0.0772097796, name='S178'): Clade(branch_length=0.1841878397, confidence=100, name='Node88'),
#  Clade(branch_length=0.0523966269, name='S180'): Clade(branch_length=0.1841878397, confidence=100, name='Node88'),
#  Clade(branch_length=0.0661169296, confidence=100, name='Node91'): Clade(branch_length=0.0838378232, confidence=100, name='Node90'),
#  Clade(branch_length=0.0622208851, confidence=100, name='Node333'): Clade(branch_length=0.0838378232, confidence=100, name='Node90'),
#  Clade(branch_length=0.0349727217, name='S350'): Clade(branch_length=0.1008483598, confidence=100, name='Node335'),
#  Clade(branch_length=0.0010329384, name='S351'): Clade(branch_length=0.1008483598, confidence=100, name='Node335'),
#  Clade(branch_length=0.018050168, name='S113'): Clade(branch_length=0.0426258386, confidence=100, name='Node339'),
#  Clade(branch_length=0.00746164, name='S114'): Clade(branch_length=0.0426258386, confidence=100, name='Node339'),
#  Clade(branch_length=0.0053147923, name='S304'): Clade(branch_length=0.0069728884, confidence=100, name='Node344'),
#  Clade(branch_length=0.0008900932, name='S305'): Clade(branch_length=0.0069728884, confidence=100, name='Node344'),
#  Clade(branch_length=0.006227914, name='S306'): Clade(branch_length=0.0239747656, confidence=100, name='Node345'),
#  Clade(branch_length=0.0061811369, name='S307'): Clade(branch_length=0.0239747656, confidence=100, name='Node345'),
#  Clade(branch_length=0.0031459696, name='S118'): Clade(branch_length=0.0082943348, confidence=100, name='Node349'),
#  Clade(branch_length=1.0017e-06, name='S243'): Clade(branch_length=0.0082943348, confidence=100, name='Node349'),
#  Clade(branch_length=0.0031903929, name='S72'): Clade(branch_length=0.0096733787, confidence=100, name='Node360'),
#  Clade(branch_length=0.0095497568, name='S102'): Clade(branch_length=0.0096733787, confidence=100, name='Node360'),
#  Clade(branch_length=0.0135897839, confidence=33, name='Node10'): Clade(branch_length=0.0643327722, confidence=61, name='Node9'),
#  Clade(branch_length=0.0619509572, confidence=100, name='Node79'): Clade(branch_length=0.0643327722, confidence=61, name='Node9'),
#  Clade(branch_length=2.2918e-06, name='S50'): Clade(branch_length=0.0227601489, confidence=55, name='Node81'),
#  Clade(branch_length=0.0031790408, confidence=55, name='Node82'): Clade(branch_length=0.0227601489, confidence=55, name='Node81'),
#  Clade(branch_length=0.0348169011, confidence=96, name='Node92'): Clade(branch_length=0.0661169296, confidence=100, name='Node91'),
#  Clade(branch_length=0.0185353754, confidence=100, name='Node271'): Clade(branch_length=0.0661169296, confidence=100, name='Node91'),
#  Clade(branch_length=0.037728285, name='S82'): Clade(branch_length=0.0622208851, confidence=100, name='Node333'),
#  Clade(branch_length=0.0210834865, confidence=100, name='Node334'): Clade(branch_length=0.0622208851, confidence=100, name='Node333'),
#  Clade(branch_length=0.0542531464, confidence=61, name='Node11'): Clade(branch_length=0.0135897839, confidence=33, name='Node10'),
#  Clade(branch_length=0.0814399911, name='S70'): Clade(branch_length=0.0135897839, confidence=33, name='Node10'),
#  Clade(branch_length=0.0173099629, confidence=100, name='Node80'): Clade(branch_length=0.0619509572, confidence=100, name='Node79'),
#  Clade(branch_length=0.0250346641, name='S179'): Clade(branch_length=0.0619509572, confidence=100, name='Node79'),
#  Clade(branch_length=0.0221407179, confidence=100, name='Node83'): Clade(branch_length=0.0031790408, confidence=55, name='Node82'),
#  Clade(branch_length=0.015648187, confidence=60, name='Node84'): Clade(branch_length=0.0031790408, confidence=55, name='Node82'),
#  Clade(branch_length=0.3654029639, confidence=100, name='Node93'): Clade(branch_length=0.0348169011, confidence=96, name='Node92'),
#  Clade(branch_length=0.1751427126, name='S171'): Clade(branch_length=0.0348169011, confidence=96, name='Node92'),
#  Clade(branch_length=0.0459964063, confidence=100, name='Node272'): Clade(branch_length=0.0185353754, confidence=100, name='Node271'),
#  Clade(branch_length=2.2992e-06, name='S246'): Clade(branch_length=0.0185353754, confidence=100, name='Node271'),
#  Clade(branch_length=0.0608032207, name='S170'): Clade(branch_length=0.0210834865, confidence=100, name='Node334'),
#  Clade(branch_length=0.0474282087, name='S259'): Clade(branch_length=0.0210834865, confidence=100, name='Node334'),
#  Clade(branch_length=0.0119226788, confidence=75, name='Node12'): Clade(branch_length=0.0542531464, confidence=61, name='Node11'),
#  Clade(branch_length=0.0361644294, confidence=44, name='Node74'): Clade(branch_length=0.0542531464, confidence=61, name='Node11'),
#  Clade(branch_length=0.0582494145, name='S110'): Clade(branch_length=0.0173099629, confidence=100, name='Node80'),
#  Clade(branch_length=0.0432487416, name='S177'): Clade(branch_length=0.0173099629, confidence=100, name='Node80'),
#  Clade(branch_length=2.5822e-06, name='S51'): Clade(branch_length=0.0221407179, confidence=100, name='Node83'),
#  Clade(branch_length=0.0833248946, name='S59'): Clade(branch_length=0.0221407179, confidence=100, name='Node83'),
#  Clade(branch_length=0.0257440516, confidence=100, name='Node85'): Clade(branch_length=0.015648187, confidence=60, name='Node84'),
#  Clade(branch_length=0.2330889812, name='S192'): Clade(branch_length=0.015648187, confidence=60, name='Node84'),
#  Clade(branch_length=0.1038897902, confidence=100, name='Node94'): Clade(branch_length=0.3654029639, confidence=100, name='Node93'),
#  Clade(branch_length=0.1978418883, confidence=100, name='Node245'): Clade(branch_length=0.3654029639, confidence=100, name='Node93'),
#  Clade(branch_length=0.0206342642, confidence=100, name='Node273'): Clade(branch_length=0.0459964063, confidence=100, name='Node272'),
#  Clade(branch_length=2.0977e-06, name='S247'): Clade(branch_length=0.0459964063, confidence=100, name='Node272'),
#  Clade(branch_length=0.0510729086, confidence=98, name='Node13'): Clade(branch_length=0.0119226788, confidence=75, name='Node12'),
#  Clade(branch_length=0.0209776869, confidence=82, name='Node23'): Clade(branch_length=0.0119226788, confidence=75, name='Node12'),
#  Clade(branch_length=0.0728272623, name='S191'): Clade(branch_length=0.0361644294, confidence=44, name='Node74'),
#  Clade(branch_length=0.5782135812, confidence=100, name='Node75'): Clade(branch_length=0.0361644294, confidence=44, name='Node74'),
#  Clade(branch_length=2.3957e-06, name='S52'): Clade(branch_length=0.0257440516, confidence=100, name='Node85'),
#  Clade(branch_length=0.0720459115, name='S69'): Clade(branch_length=0.0257440516, confidence=100, name='Node85'),
#  Clade(branch_length=0.2481524426, confidence=100, name='Node95'): Clade(branch_length=0.1038897902, confidence=100, name='Node94'),
#  Clade(branch_length=0.3748384298, confidence=100, name='Node191'): Clade(branch_length=0.1038897902, confidence=100, name='Node94'),
#  Clade(branch_length=0.0602913106, confidence=100, name='Node246'): Clade(branch_length=0.1978418883, confidence=100, name='Node245'),
#  Clade(branch_length=0.2737409837, name='S169'): Clade(branch_length=0.1978418883, confidence=100, name='Node245'),
#  Clade(branch_length=0.0124173621, confidence=99, name='Node274'): Clade(branch_length=0.0206342642, confidence=100, name='Node273'),
#  Clade(branch_length=0.1634890562, name='S260'): Clade(branch_length=0.0206342642, confidence=100, name='Node273'),
#  Clade(branch_length=0.0209046625, confidence=89, name='Node14'): Clade(branch_length=0.0510729086, confidence=98, name='Node13'),
#  Clade(branch_length=0.0469241923, confidence=100, name='Node22'): Clade(branch_length=0.0510729086, confidence=98, name='Node13'),
#  Clade(branch_length=0.0163299429, confidence=72, name='Node24'): Clade(branch_length=0.0209776869, confidence=82, name='Node23'),
#  Clade(branch_length=0.0197761333, confidence=96, name='Node72'): Clade(branch_length=0.0209776869, confidence=82, name='Node23'),
#  Clade(branch_length=0.2334839609, name='S357'): Clade(branch_length=0.5782135812, confidence=100, name='Node75'),
#  Clade(branch_length=0.0838907947, confidence=92, name='Node76'): Clade(branch_length=0.5782135812, confidence=100, name='Node75'),
#  Clade(branch_length=0.1078503554, confidence=95, name='Node96'): Clade(branch_length=0.2481524426, confidence=100, name='Node95'),
#  Clade(branch_length=0.401581616, confidence=100, name='Node190'): Clade(branch_length=0.2481524426, confidence=100, name='Node95'),
#  Clade(branch_length=0.1930583528, confidence=100, name='Node192'): Clade(branch_length=0.3748384298, confidence=100, name='Node191'),
#  Clade(branch_length=0.0210876888, confidence=99, name='Node204'): Clade(branch_length=0.3748384298, confidence=100, name='Node191'),
#  Clade(branch_length=0.1385890122, confidence=100, name='Node247'): Clade(branch_length=0.0602913106, confidence=100, name='Node246'),
#  Clade(branch_length=0.1266329052, confidence=100, name='Node267'): Clade(branch_length=0.0602913106, confidence=100, name='Node246'),
#  Clade(branch_length=0.0130571658, confidence=47, name='Node275'): Clade(branch_length=0.0124173621, confidence=99, name='Node274'),
#  Clade(branch_length=0.1215263884, confidence=100, name='Node286'): Clade(branch_length=0.0124173621, confidence=99, name='Node274'),
#  Clade(branch_length=0.0102652145, confidence=73, name='Node15'): Clade(branch_length=0.0209046625, confidence=89, name='Node14'),
#  Clade(branch_length=0.0167511868, confidence=100, name='Node20'): Clade(branch_length=0.0209046625, confidence=89, name='Node14'),
#  Clade(branch_length=0.0096626701, name='S10'): Clade(branch_length=0.0469241923, confidence=100, name='Node22'),
#  Clade(branch_length=0.0270368737, name='S11'): Clade(branch_length=0.0469241923, confidence=100, name='Node22'),
#  Clade(branch_length=0.03617755, confidence=100, name='Node25'): Clade(branch_length=0.0163299429, confidence=72, name='Node24'),
#  Clade(branch_length=0.0160547647, confidence=83, name='Node59'): Clade(branch_length=0.0163299429, confidence=72, name='Node24'),
#  Clade(branch_length=0.0394175594, confidence=100, name='Node73'): Clade(branch_length=0.0197761333, confidence=96, name='Node72'),
#  Clade(branch_length=0.0212591872, name='S338'): Clade(branch_length=0.0197761333, confidence=96, name='Node72'),
#  Clade(branch_length=0.0623487199, name='S358'): Clade(branch_length=0.0838907947, confidence=92, name='Node76'),
#  Clade(branch_length=0.0113747544, confidence=77, name='Node77'): Clade(branch_length=0.0838907947, confidence=92, name='Node76'),
#  Clade(branch_length=0.670410466, confidence=100, name='Node97'): Clade(branch_length=0.1078503554, confidence=95, name='Node96'),
#  Clade(branch_length=0.6060499233, confidence=100, name='Node144'): Clade(branch_length=0.1078503554, confidence=95, name='Node96'),
#  Clade(branch_length=0.1468237708, name='S150'): Clade(branch_length=0.401581616, confidence=100, name='Node190'),
#  Clade(branch_length=0.2328381805, name='S151'): Clade(branch_length=0.401581616, confidence=100, name='Node190'),
#  Clade(branch_length=0.02790431, confidence=100, name='Node193'): Clade(branch_length=0.1930583528, confidence=100, name='Node192'),
#  Clade(branch_length=0.0016894152, name='S321'): Clade(branch_length=0.1930583528, confidence=100, name='Node192'),
#  Clade(branch_length=0.0671118236, confidence=99, name='Node205'): Clade(branch_length=0.0210876888, confidence=99, name='Node204'),
#  Clade(branch_length=0.0046735285, name='S261'): Clade(branch_length=0.0210876888, confidence=99, name='Node204'),
#  Clade(branch_length=0.1291536688, confidence=100, name='Node248'): Clade(branch_length=0.1385890122, confidence=100, name='Node247'),
#  Clade(branch_length=0.1218725305, confidence=100, name='Node264'): Clade(branch_length=0.1385890122, confidence=100, name='Node247'),
#  Clade(branch_length=0.0663729724, name='S129'): Clade(branch_length=0.1266329052, confidence=100, name='Node267'),
#  Clade(branch_length=0.0706337379, confidence=100, name='Node268'): Clade(branch_length=0.1266329052, confidence=100, name='Node267'),
#  Clade(branch_length=0.0412016089, confidence=48, name='Node276'): Clade(branch_length=0.0130571658, confidence=47, name='Node275'),
#  Clade(branch_length=2.4163e-06, name='S256'): Clade(branch_length=0.0130571658, confidence=47, name='Node275'),
#  Clade(branch_length=0.0318772347, confidence=100, name='Node287'): Clade(branch_length=0.1215263884, confidence=100, name='Node286'),
#  Clade(branch_length=2.2239e-06, name='S248'): Clade(branch_length=0.1215263884, confidence=100, name='Node286'),
#  Clade(branch_length=0.0062732967, confidence=73, name='Node16'): Clade(branch_length=0.0102652145, confidence=73, name='Node15'),
#  Clade(branch_length=0.0433250584, confidence=99, name='Node18'): Clade(branch_length=0.0102652145, confidence=73, name='Node15'),
#  Clade(branch_length=0.0134197604, name='S5'): Clade(branch_length=0.0167511868, confidence=100, name='Node20'),
#  Clade(branch_length=0.003086515, confidence=100, name='Node21'): Clade(branch_length=0.0167511868, confidence=100, name='Node20'),
#  Clade(branch_length=2.5188e-06, confidence=64, name='Node26'): Clade(branch_length=0.03617755, confidence=100, name='Node25'),
#  Clade(branch_length=0.0189259193, name='S39'): Clade(branch_length=0.03617755, confidence=100, name='Node25'),
#  Clade(branch_length=0.0089361657, confidence=83, name='Node60'): Clade(branch_length=0.0160547647, confidence=83, name='Node59'),
#  Clade(branch_length=0.0917427969, confidence=100, name='Node71'): Clade(branch_length=0.0160547647, confidence=83, name='Node59'),
#  Clade(branch_length=0.0265063602, name='S111'): Clade(branch_length=0.0394175594, confidence=100, name='Node73'),
#  Clade(branch_length=0.0131942888, name='S167'): Clade(branch_length=0.0394175594, confidence=100, name='Node73'),
#  Clade(branch_length=0.0227415334, confidence=83, name='Node78'): Clade(branch_length=0.0113747544, confidence=77, name='Node77'),
#  Clade(branch_length=0.0264892897, name='S360'): Clade(branch_length=0.0113747544, confidence=77, name='Node77'),
#  Clade(branch_length=0.0468830736, confidence=71, name='Node98'): Clade(branch_length=0.670410466, confidence=100, name='Node97'),
#  Clade(branch_length=0.0590172075, confidence=95, name='Node122'): Clade(branch_length=0.670410466, confidence=100, name='Node97'),
#  Clade(branch_length=0.1830694071, confidence=100, name='Node145'): Clade(branch_length=0.6060499233, confidence=100, name='Node144'),
#  Clade(branch_length=1.2236737674, name='S182'): Clade(branch_length=0.6060499233, confidence=100, name='Node144'),
#  Clade(branch_length=0.1148994431, confidence=100, name='Node194'): Clade(branch_length=0.02790431, confidence=100, name='Node193'),
#  Clade(branch_length=0.054838772, confidence=100, name='Node197'): Clade(branch_length=0.02790431, confidence=100, name='Node193'),
#  Clade(branch_length=0.0253067189, confidence=96, name='Node206'): Clade(branch_length=0.0671118236, confidence=99, name='Node205'),
#  Clade(branch_length=0.254096728, name='S168'): Clade(branch_length=0.0671118236, confidence=99, name='Node205'),
#  Clade(branch_length=0.0197162908, confidence=63, name='Node249'): Clade(branch_length=0.1291536688, confidence=100, name='Node248'),
#  Clade(branch_length=0.122328501, name='S225'): Clade(branch_length=0.1291536688, confidence=100, name='Node248'),
#  Clade(branch_length=0.1169233649, confidence=100, name='Node265'): Clade(branch_length=0.1218725305, confidence=100, name='Node264'),
#  Clade(branch_length=0.1305004629, confidence=100, name='Node266'): Clade(branch_length=0.1218725305, confidence=100, name='Node264'),
#  Clade(branch_length=0.0467638183, confidence=100, name='Node269'): Clade(branch_length=0.0706337379, confidence=100, name='Node268'),
#  Clade(branch_length=0.0642176091, name='S131'): Clade(branch_length=0.0706337379, confidence=100, name='Node268'),
#  Clade(branch_length=0.1813565594, confidence=100, name='Node277'): Clade(branch_length=0.0412016089, confidence=48, name='Node276'),
#  Clade(branch_length=0.0177366623, confidence=97, name='Node278'): Clade(branch_length=0.0412016089, confidence=48, name='Node276'),
#  Clade(branch_length=2.0706e-06, confidence=86, name='Node288'): Clade(branch_length=0.0318772347, confidence=100, name='Node287'),
#  Clade(branch_length=2.7372e-06, name='S249'): Clade(branch_length=0.0318772347, confidence=100, name='Node287'),
#  Clade(branch_length=0.0284308719, confidence=100, name='Node17'): Clade(branch_length=0.0062732967, confidence=73, name='Node16'),
#  Clade(branch_length=0.0238945438, name='S4'): Clade(branch_length=0.0062732967, confidence=73, name='Node16'),
#  Clade(branch_length=0.0356674046, name='S3'): Clade(branch_length=0.0433250584, confidence=99, name='Node18'),
#  Clade(branch_length=0.0393406289, confidence=100, name='Node19'): Clade(branch_length=0.0433250584, confidence=99, name='Node18'),
#  Clade(branch_length=0.0031672279, name='S6'): Clade(branch_length=0.003086515, confidence=100, name='Node21'),
#  Clade(branch_length=0.0263880244, name='S7'): Clade(branch_length=0.003086515, confidence=100, name='Node21'),
#  Clade(branch_length=0.0070017657, confidence=79, name='Node27'): Clade(branch_length=2.5188e-06, confidence=64, name='Node26'),
#  Clade(branch_length=0.0045256952, name='S33'): Clade(branch_length=2.5188e-06, confidence=64, name='Node26'),
#  Clade(branch_length=0.0235517927, confidence=84, name='Node61'): Clade(branch_length=0.0089361657, confidence=83, name='Node60'),
#  Clade(branch_length=2.8558e-06, name='S54'): Clade(branch_length=0.0089361657, confidence=83, name='Node60'),
#  Clade(branch_length=2.6864e-06, name='S62'): Clade(branch_length=0.0917427969, confidence=100, name='Node71'),
#  Clade(branch_length=2.5561e-06, name='S71'): Clade(branch_length=0.0917427969, confidence=100, name='Node71'),
#  Clade(branch_length=0.0901675977, name='S359'): Clade(branch_length=0.0227415334, confidence=83, name='Node78'),
#  Clade(branch_length=0.1035635177, name='S361'): Clade(branch_length=0.0227415334, confidence=83, name='Node78'),
#  Clade(branch_length=0.0075849829, confidence=71, name='Node99'): Clade(branch_length=0.0468830736, confidence=71, name='Node98'),
#  Clade(branch_length=0.015074624, confidence=94, name='Node115'): Clade(branch_length=0.0468830736, confidence=71, name='Node98'),
#  Clade(branch_length=0.0135055173, confidence=95, name='Node123'): Clade(branch_length=0.0590172075, confidence=95, name='Node122'),
#  Clade(branch_length=0.0807006035, name='S346'): Clade(branch_length=0.0590172075, confidence=95, name='Node122'),
#  Clade(branch_length=0.1461106142, confidence=99, name='Node146'): Clade(branch_length=0.1830694071, confidence=100, name='Node145'),
#  Clade(branch_length=1.5177366656, name='S314'): Clade(branch_length=0.1830694071, confidence=100, name='Node145'),
#  Clade(branch_length=0.0774159453, confidence=100, name='Node195'): Clade(branch_length=0.1148994431, confidence=100, name='Node194'),
#  Clade(branch_length=0.08903526, name='S86'): Clade(branch_length=0.1148994431, confidence=100, name='Node194'),
#  Clade(branch_length=0.0485729179, confidence=92, name='Node198'): Clade(branch_length=0.054838772, confidence=100, name='Node197'),
#  Clade(branch_length=0.2406341344, name='S326'): Clade(branch_length=0.054838772, confidence=100, name='Node197'),
#  Clade(branch_length=0.0088156278, confidence=97, name='Node207'): Clade(branch_length=0.0253067189, confidence=96, name='Node206'),
#  Clade(branch_length=2.2152e-06, confidence=74, name='Node209'): Clade(branch_length=0.0253067189, confidence=96, name='Node206'),
#  Clade(branch_length=0.0178274732, confidence=99, name='Node250'): Clade(branch_length=0.0197162908, confidence=63, name='Node249'),
#  Clade(branch_length=0.0953490974, confidence=100, name='Node258'): Clade(branch_length=0.0197162908, confidence=63, name='Node249'),
#  Clade(branch_length=1.0017e-06, name='S128'): Clade(branch_length=0.1169233649, confidence=100, name='Node265'),
#  Clade(branch_length=1.0017e-06, name='S230'): Clade(branch_length=0.1169233649, confidence=100, name='Node265'),
#  Clade(branch_length=1.0017e-06, name='S229'): Clade(branch_length=0.1305004629, confidence=100, name='Node266'),
#  Clade(branch_length=2.1206e-06, name='S231'): Clade(branch_length=0.1305004629, confidence=100, name='Node266'),
#  Clade(branch_length=0.0270756643, confidence=100, name='Node270'): Clade(branch_length=0.0467638183, confidence=100, name='Node269'),
#  Clade(branch_length=0.0222800995, name='S190'): Clade(branch_length=0.0467638183, confidence=100, name='Node269'),
#  Clade(branch_length=2.0889e-06, name='S74'): Clade(branch_length=0.1813565594, confidence=100, name='Node277'),
#  Clade(branch_length=2.02e-06, name='S122'): Clade(branch_length=0.1813565594, confidence=100, name='Node277'),
#  Clade(branch_length=0.0029628763, confidence=96, name='Node279'): Clade(branch_length=0.0177366623, confidence=97, name='Node278'),
#  Clade(branch_length=2.063e-06, confidence=97, name='Node285'): Clade(branch_length=0.0177366623, confidence=97, name='Node278'),
#  Clade(branch_length=0.0448988826, confidence=100, name='Node289'): Clade(branch_length=2.0706e-06, confidence=86, name='Node288'),
#  Clade(branch_length=0.0188286958, confidence=100, name='Node320'): Clade(branch_length=2.0706e-06, confidence=86, name='Node288'),
#  Clade(branch_length=0.0128301945, name='S1'): Clade(branch_length=0.0284308719, confidence=100, name='Node17'),
#  Clade(branch_length=2.7671e-06, name='S2'): Clade(branch_length=0.0284308719, confidence=100, name='Node17'),
#  Clade(branch_length=0.0064623803, name='S8'): Clade(branch_length=0.0393406289, confidence=100, name='Node19'),
#  Clade(branch_length=2.0734e-06, name='S9'): Clade(branch_length=0.0393406289, confidence=100, name='Node19'),
#  Clade(branch_length=0.0092710533, confidence=77, name='Node28'): Clade(branch_length=0.0070017657, confidence=79, name='Node27'),
#  Clade(branch_length=2.3485e-06, confidence=89, name='Node56'): Clade(branch_length=0.0070017657, confidence=79, name='Node27'),
#  Clade(branch_length=2.0788e-06, name='S53'): Clade(branch_length=0.0235517927, confidence=84, name='Node61'),
#  Clade(branch_length=0.0064282419, confidence=81, name='Node62'): Clade(branch_length=0.0235517927, confidence=84, name='Node61'),
#  Clade(branch_length=0.0224962622, confidence=71, name='Node100'): Clade(branch_length=0.0075849829, confidence=71, name='Node99'),
#  Clade(branch_length=2.1699e-06, name='S283'): Clade(branch_length=0.0075849829, confidence=71, name='Node99'),
#  Clade(branch_length=0.0098729061, confidence=92, name='Node116'): Clade(branch_length=0.015074624, confidence=94, name='Node115'),
#  Clade(branch_length=2.4626e-06, name='S284'): Clade(branch_length=0.015074624, confidence=94, name='Node115'),
#  Clade(branch_length=0.1880398745, name='S81'): Clade(branch_length=0.0135055173, confidence=95, name='Node123'),
#  Clade(branch_length=0.0306262848, confidence=73, name='Node124'): Clade(branch_length=0.0135055173, confidence=95, name='Node123'),
#  Clade(branch_length=1.12173157, confidence=100, name='Node147'): Clade(branch_length=0.1461106142, confidence=99, name='Node146'),
#  Clade(branch_length=0.3521039098, confidence=99, name='Node187'): Clade(branch_length=0.1461106142, confidence=99, name='Node146'),
#  Clade(branch_length=1.9805e-06, name='Node196'): Clade(branch_length=0.0774159453, confidence=100, name='Node195'),
#  Clade(branch_length=1.0017e-06, name='S126'): Clade(branch_length=0.0774159453, confidence=100, name='Node195'),
#  Clade(branch_length=0.0772135935, confidence=100, name='Node199'): Clade(branch_length=0.0485729179, confidence=92, name='Node198'),
#  Clade(branch_length=0.0234590238, confidence=92, name='Node203'): Clade(branch_length=0.0485729179, confidence=92, name='Node198'),
#  Clade(branch_length=0.0068068857, confidence=97, name='Node208'): Clade(branch_length=0.0088156278, confidence=97, name='Node207'),
#  Clade(branch_length=0.1393391554, name='S88'): Clade(branch_length=0.0088156278, confidence=97, name='Node207'),
#  Clade(branch_length=0.0216952004, confidence=99, name='Node210'): Clade(branch_length=2.2152e-06, confidence=74, name='Node209'),
#  Clade(branch_length=2.6577e-06, name='S262'): Clade(branch_length=2.2152e-06, confidence=74, name='Node209'),
#  Clade(branch_length=0.0573922441, confidence=100, name='Node251'): Clade(branch_length=0.0178274732, confidence=99, name='Node250'),
#  Clade(branch_length=0.0563001407, confidence=100, name='Node256'): Clade(branch_length=0.0178274732, confidence=99, name='Node250'),
#  Clade(branch_length=0.039752727, confidence=99, name='Node259'): Clade(branch_length=0.0953490974, confidence=100, name='Node258'),
#  Clade(branch_length=0.0274939715, confidence=100, name='Node262'): Clade(branch_length=0.0953490974, confidence=100, name='Node258'),
#  Clade(branch_length=0.0372286762, name='S130'): Clade(branch_length=0.0270756643, confidence=100, name='Node270'),
#  Clade(branch_length=0.1268341973, name='S132'): Clade(branch_length=0.0270756643, confidence=100, name='Node270'),
#  Clade(branch_length=0.0375631581, confidence=100, name='Node280'): Clade(branch_length=0.0029628763, confidence=96, name='Node279'),
#  Clade(branch_length=0.0470682125, confidence=100, name='Node281'): Clade(branch_length=0.0029628763, confidence=96, name='Node279'),
#  Clade(branch_length=1.0017e-06, name='S257'): Clade(branch_length=2.063e-06, confidence=97, name='Node285'),
#  Clade(branch_length=1.0017e-06, name='S258'): Clade(branch_length=2.063e-06, confidence=97, name='Node285'),
#  Clade(branch_length=0.0688100102, confidence=100, name='Node290'): Clade(branch_length=0.0448988826, confidence=100, name='Node289'),
#  Clade(branch_length=0.0019321553, name='S252'): Clade(branch_length=0.0448988826, confidence=100, name='Node289'),
#  Clade(branch_length=0.039642942, confidence=99, name='Node321'): Clade(branch_length=0.0188286958, confidence=100, name='Node320'),
#  Clade(branch_length=2.6863e-06, name='S250'): Clade(branch_length=0.0188286958, confidence=100, name='Node320'),
#  Clade(branch_length=0.0064140964, confidence=72, name='Node29'): Clade(branch_length=0.0092710533, confidence=77, name='Node28'),
#  Clade(branch_length=0.00640386, name='S25'): Clade(branch_length=0.0092710533, confidence=77, name='Node28'),
#  Clade(branch_length=0.0074716874, name='S20'): Clade(branch_length=2.3485e-06, confidence=89, name='Node56'),
#  Clade(branch_length=0.0066187237, confidence=92, name='Node57'): Clade(branch_length=2.3485e-06, confidence=89, name='Node56'),
#  Clade(branch_length=0.0070783433, confidence=99, name='Node63'): Clade(branch_length=0.0064282419, confidence=81, name='Node62'),
#  Clade(branch_length=0.0599028602, confidence=82, name='Node70'): Clade(branch_length=0.0064282419, confidence=81, name='Node62'),
#  Clade(branch_length=2.4936e-06, confidence=53, name='Node101'): Clade(branch_length=0.0224962622, confidence=71, name='Node100'),
#  Clade(branch_length=1.0017e-06, name='S285'): Clade(branch_length=0.0224962622, confidence=71, name='Node100'),
#  Clade(branch_length=0.0042083282, confidence=92, name='Node117'): Clade(branch_length=0.0098729061, confidence=92, name='Node116'),
#  Clade(branch_length=0.013964096, name='S139'): Clade(branch_length=0.0098729061, confidence=92, name='Node116'),
#  Clade(branch_length=0.0108164076, confidence=51, name='Node125'): Clade(branch_length=0.0306262848, confidence=73, name='Node124'),
#  Clade(branch_length=0.0535584729, confidence=98, name='Node143'): Clade(branch_length=0.0306262848, confidence=73, name='Node124'),
#  Clade(branch_length=0.4072133574, confidence=100, name='Node148'): Clade(branch_length=1.12173157, confidence=100, name='Node147'),
#  Clade(branch_length=0.3570328849, confidence=100, name='Node170'): Clade(branch_length=1.12173157, confidence=100, name='Node147'),
#  Clade(branch_length=0.919722351, confidence=100, name='Node188'): Clade(branch_length=0.3521039098, confidence=99, name='Node187'),
#  Clade(branch_length=1.7496219905, name='S352'): Clade(branch_length=0.3521039098, confidence=99, name='Node187'),
#  Clade(branch_length=0.0, name='S85'): Clade(branch_length=1.9805e-06, name='Node196'),
#  Clade(branch_length=0.0, name='S327'): Clade(branch_length=1.9805e-06, name='Node196'),
#  Clade(branch_length=0.0272850587, confidence=41, name='Node200'): Clade(branch_length=0.0772135935, confidence=100, name='Node199'),
#  Clade(branch_length=0.0443212838, confidence=100, name='Node202'): Clade(branch_length=0.0772135935, confidence=100, name='Node199'),
#  Clade(branch_length=0.0484550986, name='S324'): Clade(branch_length=0.0234590238, confidence=92, name='Node203'),
#  Clade(branch_length=0.210626574, name='S339'): Clade(branch_length=0.0234590238, confidence=92, name='Node203'),
#  Clade(branch_length=0.191186712, name='S87'): Clade(branch_length=0.0068068857, confidence=97, name='Node208'),
#  Clade(branch_length=2.5135e-06, name='S263'): Clade(branch_length=0.0068068857, confidence=97, name='Node208'),
#  Clade(branch_length=0.0092672724, confidence=58, name='Node211'): Clade(branch_length=0.0216952004, confidence=99, name='Node210'),
#  Clade(branch_length=2.437e-06, name='S264'): Clade(branch_length=0.0216952004, confidence=99, name='Node210'),
#  Clade(branch_length=0.0549530245, confidence=100, name='Node252'): Clade(branch_length=0.0573922441, confidence=100, name='Node251'),
#  Clade(branch_length=0.0721845324, name='S330'): Clade(branch_length=0.0573922441, confidence=100, name='Node251'),
#  Clade(branch_length=0.0754467248, confidence=100, name='Node257'): Clade(branch_length=0.0563001407, confidence=100, name='Node256'),
#  Clade(branch_length=0.1062541699, name='S227'): Clade(branch_length=0.0563001407, confidence=100, name='Node256'),
#  Clade(branch_length=0.0626347496, confidence=100, name='Node260'): Clade(branch_length=0.039752727, confidence=99, name='Node259'),
#  Clade(branch_length=0.1151287462, name='S226'): Clade(branch_length=0.039752727, confidence=99, name='Node259'),
#  Clade(branch_length=0.0835306316, name='S220'): Clade(branch_length=0.0274939715, confidence=100, name='Node262'),
#  Clade(branch_length=0.0745962201, confidence=100, name='Node263'): Clade(branch_length=0.0274939715, confidence=100, name='Node262'),
#  Clade(branch_length=1.0017e-06, name='S76'): Clade(branch_length=0.0375631581, confidence=100, name='Node280'),
#  Clade(branch_length=2.4193e-06, name='S121'): Clade(branch_length=0.0375631581, confidence=100, name='Node280'),
#  Clade(branch_length=0.0086712353, confidence=65, name='Node282'): Clade(branch_length=0.0470682125, confidence=100, name='Node281'),
#  Clade(branch_length=0.036717846, name='S124'): Clade(branch_length=0.0470682125, confidence=100, name='Node281'),
#  Clade(branch_length=2.0751e-06, confidence=40, name='Node291'): Clade(branch_length=0.0688100102, confidence=100, name='Node290'),
#  Clade(branch_length=0.1057233698, confidence=100, name='Node302'): Clade(branch_length=0.0688100102, confidence=100, name='Node290'),
#  Clade(branch_length=0.0330986344, confidence=98, name='Node322'): Clade(branch_length=0.039642942, confidence=99, name='Node321'),
#  Clade(branch_length=2.6747e-06, name='S251'): Clade(branch_length=0.039642942, confidence=99, name='Node321'),
#  Clade(branch_length=2.293e-06, confidence=41, name='Node30'): Clade(branch_length=0.0064140964, confidence=72, name='Node29'),
#  Clade(branch_length=0.0030541521, confidence=57, name='Node42'): Clade(branch_length=0.0064140964, confidence=72, name='Node29'),
#  Clade(branch_length=0.0075882786, confidence=100, name='Node58'): Clade(branch_length=0.0066187237, confidence=92, name='Node57'),
#  Clade(branch_length=0.0066793512, name='S32'): Clade(branch_length=0.0066187237, confidence=92, name='Node57'),
#  Clade(branch_length=0.0058543997, confidence=100, name='Node64'): Clade(branch_length=0.0070783433, confidence=99, name='Node63'),
#  Clade(branch_length=0.0861236165, confidence=100, name='Node68'): Clade(branch_length=0.0070783433, confidence=99, name='Node63'),
#  Clade(branch_length=0.1549540381, name='S65'): Clade(branch_length=0.0599028602, confidence=82, name='Node70'),
#  Clade(branch_length=0.1343454708, name='S356'): Clade(branch_length=0.0599028602, confidence=82, name='Node70'),
#  Clade(branch_length=0.0193040366, confidence=69, name='Node102'): Clade(branch_length=2.4936e-06, confidence=53, name='Node101'),
#  Clade(branch_length=0.0285069003, name='S149'): Clade(branch_length=2.4936e-06, confidence=53, name='Node101'),
#  Clade(branch_length=7.5166e-06, confidence=85, name='Node118'): Clade(branch_length=0.0042083282, confidence=92, name='Node117'),
#  Clade(branch_length=2.159e-06, name='S289'): Clade(branch_length=0.0042083282, confidence=92, name='Node117'),
#  Clade(branch_length=0.0157782186, confidence=47, name='Node126'): Clade(branch_length=0.0108164076, confidence=51, name='Node125'),
#  Clade(branch_length=0.0459465405, name='S134'): Clade(branch_length=0.0108164076, confidence=51, name='Node125'),
#  Clade(branch_length=0.0505893313, name='S308'): Clade(branch_length=0.0535584729, confidence=98, name='Node143'),
#  Clade(branch_length=0.0397096454, name='S341'): Clade(branch_length=0.0535584729, confidence=98, name='Node143'),
#  Clade(branch_length=0.0628577354, confidence=100, name='Node149'): Clade(branch_length=0.4072133574, confidence=100, name='Node148'),
#  Clade(branch_length=0.0966359509, confidence=98, name='Node169'): Clade(branch_length=0.4072133574, confidence=100, name='Node148'),
#  Clade(branch_length=0.4484081421, confidence=100, name='Node171'): Clade(branch_length=0.3570328849, confidence=100, name='Node170'),
#  Clade(branch_length=1.4302705758, name='S318'): Clade(branch_length=0.3570328849, confidence=100, name='Node170'),
#  Clade(branch_length=1.574633935, confidence=100, name='Node189'): Clade(branch_length=0.919722351, confidence=100, name='Node188'),
#  Clade(branch_length=0.8149530408, name='S353'): Clade(branch_length=0.919722351, confidence=100, name='Node188'),
#  Clade(branch_length=0.0853462412, confidence=100, name='Node201'): Clade(branch_length=0.0272850587, confidence=41, name='Node200'),
#  Clade(branch_length=0.0916319307, name='S335'): Clade(branch_length=0.0272850587, confidence=41, name='Node200'),
#  Clade(branch_length=0.0397882535, name='S240'): Clade(branch_length=0.0443212838, confidence=100, name='Node202'),
#  Clade(branch_length=0.0129598276, name='S328'): Clade(branch_length=0.0443212838, confidence=100, name='Node202'),
#  Clade(branch_length=0.0136686494, confidence=94, name='Node212'): Clade(branch_length=0.0092672724, confidence=58, name='Node211'),
#  Clade(branch_length=0.0386434594, confidence=100, name='Node229'): Clade(branch_length=0.0092672724, confidence=58, name='Node211'),
#  Clade(branch_length=0.1960654961, confidence=100, name='Node253'): Clade(branch_length=0.0549530245, confidence=100, name='Node252'),
#  Clade(branch_length=0.0185038947, confidence=75, name='Node254'): Clade(branch_length=0.0549530245, confidence=100, name='Node252'),
#  Clade(branch_length=1.0017e-06, name='S164'): Clade(branch_length=0.0754467248, confidence=100, name='Node257'),
#  Clade(branch_length=1.0017e-06, name='S223'): Clade(branch_length=0.0754467248, confidence=100, name='Node257'),
#  Clade(branch_length=0.0175400866, confidence=100, name='Node261'): Clade(branch_length=0.0626347496, confidence=100, name='Node260'),
#  Clade(branch_length=0.0522233065, name='S228'): Clade(branch_length=0.0626347496, confidence=100, name='Node260'),
#  Clade(branch_length=0.0277390691, name='S239'): Clade(branch_length=0.0745962201, confidence=100, name='Node263'),
#  Clade(branch_length=0.0187323503, name='S329'): Clade(branch_length=0.0745962201, confidence=100, name='Node263'),
#  Clade(branch_length=0.0063477627, confidence=66, name='Node283'): Clade(branch_length=0.0086712353, confidence=65, name='Node282'),
#  Clade(branch_length=2.3789e-06, confidence=91, name='Node284'): Clade(branch_length=0.0086712353, confidence=65, name='Node282'),
#  Clade(branch_length=0.0413339, confidence=99, name='Node292'): Clade(branch_length=2.0751e-06, confidence=40, name='Node291'),
#  Clade(branch_length=1.0017e-06, name='S253'): Clade(branch_length=2.0751e-06, confidence=40, name='Node291'),
#  Clade(branch_length=0.0639739302, confidence=99, name='Node303'): Clade(branch_length=0.1057233698, confidence=100, name='Node302'),
#  Clade(branch_length=2.7353e-06, name='S255'): Clade(branch_length=0.1057233698, confidence=100, name='Node302'),
#  Clade(branch_length=0.0111433045, confidence=97, name='Node323'): Clade(branch_length=0.0330986344, confidence=98, name='Node322'),
#  Clade(branch_length=0.0157393305, confidence=100, name='Node330'): Clade(branch_length=0.0330986344, confidence=98, name='Node322'),
#  Clade(branch_length=0.0093088078, confidence=47, name='Node31'): Clade(branch_length=2.293e-06, confidence=41, name='Node30'),
#  Clade(branch_length=0.0031829094, confidence=51, name='Node33'): Clade(branch_length=2.293e-06, confidence=41, name='Node30'),
#  Clade(branch_length=0.0038644137, confidence=58, name='Node43'): Clade(branch_length=0.0030541521, confidence=57, name='Node42'),
#  Clade(branch_length=0.0030702029, confidence=73, name='Node50'): Clade(branch_length=0.0030541521, confidence=57, name='Node42'),
#  Clade(branch_length=0.0075225305, name='S21'): Clade(branch_length=0.0075882786, confidence=100, name='Node58'),
#  Clade(branch_length=2.3048e-06, name='S30'): Clade(branch_length=0.0075882786, confidence=100, name='Node58'),
#  Clade(branch_length=2.6123e-06, name='S55'): Clade(branch_length=0.0058543997, confidence=100, name='Node64'),
#  Clade(branch_length=0.0632075739, confidence=100, name='Node65'): Clade(branch_length=0.0058543997, confidence=100, name='Node64'),
#  Clade(branch_length=0.0032932346, confidence=100, name='Node69'): Clade(branch_length=0.0861236165, confidence=100, name='Node68'),
#  Clade(branch_length=0.0488604162, name='S66'): Clade(branch_length=0.0861236165, confidence=100, name='Node68'),
#  Clade(branch_length=0.0064883468, confidence=45, name='Node103'): Clade(branch_length=0.0193040366, confidence=69, name='Node102'),
#  Clade(branch_length=0.0490030832, confidence=100, name='Node114'): Clade(branch_length=0.0193040366, confidence=69, name='Node102'),
#  Clade(branch_length=0.0255426173, name='S138'): Clade(branch_length=7.5166e-06, confidence=85, name='Node118'),
#  Clade(branch_length=0.017010838, confidence=94, name='Node119'): Clade(branch_length=7.5166e-06, confidence=85, name='Node118'),
#  Clade(branch_length=2.9414e-06, confidence=44, name='Node127'): Clade(branch_length=0.0157782186, confidence=47, name='Node126'),
#  Clade(branch_length=0.0498731246, confidence=96, name='Node140'): Clade(branch_length=0.0157782186, confidence=47, name='Node126'),
#  Clade(branch_length=0.1099699325, confidence=100, name='Node150'): Clade(branch_length=0.0628577354, confidence=100, name='Node149'),
#  Clade(branch_length=0.5933244013, confidence=100, name='Node168'): Clade(branch_length=0.0628577354, confidence=100, name='Node149'),
#  Clade(branch_length=0.3099794812, name='S319'): Clade(branch_length=0.0966359509, confidence=98, name='Node169'),
#  Clade(branch_length=0.4083845947, name='S347'): Clade(branch_length=0.0966359509, confidence=98, name='Node169'),
#  Clade(branch_length=0.3025905059, confidence=100, name='Node172'): Clade(branch_length=0.4484081421, confidence=100, name='Node171'),
#  Clade(branch_length=0.1799691216, confidence=89, name='Node180'): Clade(branch_length=0.4484081421, confidence=100, name='Node171'),
#  Clade(branch_length=0.0509074813, name='S195'): Clade(branch_length=1.574633935, confidence=100, name='Node189'),
#  Clade(branch_length=0.0442381521, name='S196'): Clade(branch_length=1.574633935, confidence=100, name='Node189'),
#  Clade(branch_length=0.0206473057, name='S166'): Clade(branch_length=0.0853462412, confidence=100, name='Node201'),
#  Clade(branch_length=0.0491662025, name='S325'): Clade(branch_length=0.0853462412, confidence=100, name='Node201'),
#  Clade(branch_length=0.0381861075, confidence=98, name='Node213'): Clade(branch_length=0.0136686494, confidence=94, name='Node212'),
#  Clade(branch_length=2.0591e-06, confidence=40, name='Node216'): Clade(branch_length=0.0136686494, confidence=94, name='Node212'),
#  Clade(branch_length=0.0170095331, confidence=58, name='Node230'): Clade(branch_length=0.0386434594, confidence=100, name='Node229'),
# ...
#  Clade(branch_length=0.0056366391, confidence=91, name='Node310'): Clade(branch_length=0.0011049426, confidence=89, name='Node307'),
#  Clade(branch_length=0.009648144, confidence=98, name='Node38'): Clade(branch_length=0.0064363008, confidence=100, name='Node37'),
#  Clade(branch_length=2.8685e-06, confidence=97, name='Node40'): Clade(branch_length=0.0064363008, confidence=100, name='Node37'),
#  Clade(branch_length=0.0258185435, name='S24'): Clade(branch_length=0.0094189847, confidence=80, name='Node47'),
#  Clade(branch_length=0.0354880443, name='S29'): Clade(branch_length=0.0094189847, confidence=80, name='Node47'),
#  Clade(branch_length=0.0503332257, confidence=100, name='Node108'): Clade(branch_length=0.023687602, confidence=100, name='Node107'),
#  Clade(branch_length=0.0104391652, confidence=100, name='Node109'): Clade(branch_length=0.023687602, confidence=100, name='Node107'),
#  Clade(branch_length=0.0445861987, confidence=100, name='Node132'): Clade(branch_length=0.0286508922, confidence=100, name='Node131'),
#  Clade(branch_length=2.8884e-06, name='S287'): Clade(branch_length=0.0286508922, confidence=100, name='Node131'),
#  Clade(branch_length=0.0457089672, confidence=100, name='Node155'): Clade(branch_length=0.1185147504, confidence=100, name='Node154'),
#  Clade(branch_length=0.0460892367, confidence=100, name='Node160'): Clade(branch_length=0.1185147504, confidence=100, name='Node154'),
#  Clade(branch_length=0.1611867018, name='S271'): Clade(branch_length=0.0894279138, confidence=100, name='Node162'),
#  Clade(branch_length=0.0785453245, confidence=100, name='Node163'): Clade(branch_length=0.0894279138, confidence=100, name='Node162'),
#  Clade(branch_length=0.1256613439, name='S153'): Clade(branch_length=0.0602789063, confidence=100, name='Node176'),
#  Clade(branch_length=0.278999927, name='S154'): Clade(branch_length=0.0602789063, confidence=100, name='Node176'),
#  Clade(branch_length=0.0777182629, confidence=100, name='Node178'): Clade(branch_length=0.0504842591, confidence=95, name='Node177'),
#  Clade(branch_length=0.1080028948, name='S199'): Clade(branch_length=0.0504842591, confidence=95, name='Node177'),
#  Clade(branch_length=0.0322227238, name='S272'): Clade(branch_length=0.2861623661, confidence=100, name='Node184'),
#  Clade(branch_length=0.0192979889, name='S275'): Clade(branch_length=0.2861623661, confidence=100, name='Node184'),
#  Clade(branch_length=0.0144646928, name='S273'): Clade(branch_length=0.1469921082, confidence=100, name='Node185'),
#  Clade(branch_length=0.0238596391, name='S274'): Clade(branch_length=0.1469921082, confidence=100, name='Node185'),
#  Clade(branch_length=0.0233522757, confidence=95, name='Node221'): Clade(branch_length=0.0163371753, confidence=95, name='Node220'),
#  Clade(branch_length=0.1337524559, confidence=100, name='Node225'): Clade(branch_length=0.0163371753, confidence=95, name='Node220'),
#  Clade(branch_length=0.0478937833, confidence=100, name='Node228'): Clade(branch_length=0.0458123844, confidence=100, name='Node227'),
#  Clade(branch_length=0.0434885568, name='S292'): Clade(branch_length=0.0458123844, confidence=100, name='Node227'),
#  Clade(branch_length=0.1001361627, confidence=100, name='Node235'): Clade(branch_length=0.0051475472, confidence=79, name='Node234'),
#  Clade(branch_length=0.0154034638, confidence=84, name='Node236'): Clade(branch_length=0.0051475472, confidence=79, name='Node234'),
#  Clade(branch_length=0.0193649766, confidence=94, name='Node239'): Clade(branch_length=0.0043066754, confidence=78, name='Node238'),
#  Clade(branch_length=0.0089257258, name='S267'): Clade(branch_length=0.0043066754, confidence=78, name='Node238'),
#  Clade(branch_length=1.0017e-06, name='S75'): Clade(branch_length=0.0031500494, confidence=100, name='Node297'),
#  Clade(branch_length=1.0017e-06, name='S201'): Clade(branch_length=0.0031500494, confidence=100, name='Node297'),
#  Clade(branch_length=0.0154304788, name='S213'): Clade(branch_length=0.0181114977, confidence=100, name='Node300'),
#  Clade(branch_length=0.0344675512, name='S216'): Clade(branch_length=0.0181114977, confidence=100, name='Node300'),
#  Clade(branch_length=0.0096819244, confidence=100, name='Node309'): Clade(branch_length=0.0097295797, confidence=99, name='Node308'),
#  Clade(branch_length=2.0736e-06, name='S208'): Clade(branch_length=0.0097295797, confidence=99, name='Node308'),
#  Clade(branch_length=0.0301790164, confidence=100, name='Node311'): Clade(branch_length=0.0056366391, confidence=91, name='Node310'),
#  Clade(branch_length=0.0099488084, confidence=93, name='Node316'): Clade(branch_length=0.0056366391, confidence=91, name='Node310'),
#  Clade(branch_length=0.0032299986, confidence=100, name='Node39'): Clade(branch_length=0.009648144, confidence=98, name='Node38'),
#  Clade(branch_length=0.0164132122, name='S42'): Clade(branch_length=0.009648144, confidence=98, name='Node38'),
#  Clade(branch_length=0.0036226011, confidence=100, name='Node41'): Clade(branch_length=2.8685e-06, confidence=97, name='Node40'),
#  Clade(branch_length=0.012956285, name='S46'): Clade(branch_length=2.8685e-06, confidence=97, name='Node40'),
#  Clade(branch_length=1.0017e-06, name='S73'): Clade(branch_length=0.0503332257, confidence=100, name='Node108'),
#  Clade(branch_length=1.0017e-06, name='S144'): Clade(branch_length=0.0503332257, confidence=100, name='Node108'),
#  Clade(branch_length=0.007842366, name='S140'): Clade(branch_length=0.0104391652, confidence=100, name='Node109'),
#  Clade(branch_length=0.0102549601, name='S147'): Clade(branch_length=0.0104391652, confidence=100, name='Node109'),
#  Clade(branch_length=0.0693727866, confidence=100, name='Node133'): Clade(branch_length=0.0445861987, confidence=100, name='Node132'),
#  Clade(branch_length=0.0461266749, confidence=100, name='Node134'): Clade(branch_length=0.0445861987, confidence=100, name='Node132'),
#  Clade(branch_length=0.0256704646, confidence=100, name='Node156'): Clade(branch_length=0.0457089672, confidence=100, name='Node155'),
#  Clade(branch_length=0.1084528227, name='S297'): Clade(branch_length=0.0457089672, confidence=100, name='Node155'),
#  Clade(branch_length=0.0512760921, name='S298'): Clade(branch_length=0.0460892367, confidence=100, name='Node160'),
#  Clade(branch_length=0.0575352592, confidence=100, name='Node161'): Clade(branch_length=0.0460892367, confidence=100, name='Node160'),
#  Clade(branch_length=0.3185822424, confidence=100, name='Node164'): Clade(branch_length=0.0785453245, confidence=100, name='Node163'),
#  Clade(branch_length=0.0822917804, confidence=100, name='Node165'): Clade(branch_length=0.0785453245, confidence=100, name='Node163'),
#  Clade(branch_length=0.0119262341, name='S198'): Clade(branch_length=0.0777182629, confidence=100, name='Node178'),
#  Clade(branch_length=0.0302065931, name='S200'): Clade(branch_length=0.0777182629, confidence=100, name='Node178'),
#  Clade(branch_length=0.0382271242, confidence=100, name='Node222'): Clade(branch_length=0.0233522757, confidence=95, name='Node221'),
#  Clade(branch_length=0.0062143228, confidence=89, name='Node223'): Clade(branch_length=0.0233522757, confidence=95, name='Node221'),
#  Clade(branch_length=2.3485e-06, name='Node226'): Clade(branch_length=0.1337524559, confidence=100, name='Node225'),
#  Clade(branch_length=2.2555e-06, name='S127'): Clade(branch_length=0.1337524559, confidence=100, name='Node225'),
#  Clade(branch_length=1.0017e-06, name='S92'): Clade(branch_length=0.0478937833, confidence=100, name='Node228'),
#  Clade(branch_length=2.3673e-06, name='S152'): Clade(branch_length=0.0478937833, confidence=100, name='Node228'),
#  Clade(branch_length=2.8866e-06, name='S95'): Clade(branch_length=0.1001361627, confidence=100, name='Node235'),
#  Clade(branch_length=2.6889e-06, name='S181'): Clade(branch_length=0.1001361627, confidence=100, name='Node235'),
#  Clade(branch_length=0.0156882566, confidence=76, name='Node237'): Clade(branch_length=0.0154034638, confidence=84, name='Node236'),
#  Clade(branch_length=0.0780287698, name='S197'): Clade(branch_length=0.0154034638, confidence=84, name='Node236'),
#  Clade(branch_length=0.0343074759, confidence=100, name='Node240'): Clade(branch_length=0.0193649766, confidence=94, name='Node239'),
#  Clade(branch_length=0.0127732514, confidence=94, name='Node242'): Clade(branch_length=0.0193649766, confidence=94, name='Node239'),
#  Clade(branch_length=2.3289e-06, name='S202'): Clade(branch_length=0.0096819244, confidence=100, name='Node309'),
#  Clade(branch_length=2.0276e-06, name='S205'): Clade(branch_length=0.0096819244, confidence=100, name='Node309'),
#  Clade(branch_length=0.0064306785, confidence=100, name='Node312'): Clade(branch_length=0.0301790164, confidence=100, name='Node311'),
#  Clade(branch_length=0.0129535656, confidence=100, name='Node314'): Clade(branch_length=0.0301790164, confidence=100, name='Node311'),
#  Clade(branch_length=0.0294928898, name='S214'): Clade(branch_length=0.0099488084, confidence=93, name='Node316'),
#  Clade(branch_length=0.0037096358, name='S217'): Clade(branch_length=0.0099488084, confidence=93, name='Node316'),
#  Clade(branch_length=1.0017e-06, name='S19'): Clade(branch_length=0.0032299986, confidence=100, name='Node39'),
#  Clade(branch_length=1.0017e-06, name='S41'): Clade(branch_length=0.0032299986, confidence=100, name='Node39'),
#  Clade(branch_length=0.0095809483, name='S44'): Clade(branch_length=0.0036226011, confidence=100, name='Node41'),
#  Clade(branch_length=0.0063445378, name='S47'): Clade(branch_length=0.0036226011, confidence=100, name='Node41'),
#  Clade(branch_length=2.7713e-06, name='S83'): Clade(branch_length=0.0693727866, confidence=100, name='Node133'),
#  Clade(branch_length=2.4128e-06, name='S133'): Clade(branch_length=0.0693727866, confidence=100, name='Node133'),
#  Clade(branch_length=0.0284710108, confidence=100, name='Node135'): Clade(branch_length=0.0461266749, confidence=100, name='Node134'),
#  Clade(branch_length=0.0253940613, name='S334'): Clade(branch_length=0.0461266749, confidence=100, name='Node134'),
#  Clade(branch_length=0.0665649634, confidence=100, name='Node157'): Clade(branch_length=0.0256704646, confidence=100, name='Node156'),
#  Clade(branch_length=0.1870826393, confidence=100, name='Node158'): Clade(branch_length=0.0256704646, confidence=100, name='Node156'),
#  Clade(branch_length=0.0071706175, name='S299'): Clade(branch_length=0.0575352592, confidence=100, name='Node161'),
#  Clade(branch_length=0.027912599, name='S300'): Clade(branch_length=0.0575352592, confidence=100, name='Node161'),
#  Clade(branch_length=0.0883739028, name='S276'): Clade(branch_length=0.3185822424, confidence=100, name='Node164'),
#  Clade(branch_length=0.0775589979, name='S278'): Clade(branch_length=0.3185822424, confidence=100, name='Node164'),
#  Clade(branch_length=0.052903868, name='S277'): Clade(branch_length=0.0822917804, confidence=100, name='Node165'),
#  Clade(branch_length=0.0150468713, name='S279'): Clade(branch_length=0.0822917804, confidence=100, name='Node165'),
#  Clade(branch_length=1.0017e-06, name='S91'): Clade(branch_length=0.0382271242, confidence=100, name='Node222'),
#  Clade(branch_length=1.0017e-06, name='S173'): Clade(branch_length=0.0382271242, confidence=100, name='Node222'),
#  Clade(branch_length=0.0981262691, confidence=100, name='Node224'): Clade(branch_length=0.0062143228, confidence=89, name='Node223'),
#  Clade(branch_length=0.0247247483, name='S189'): Clade(branch_length=0.0062143228, confidence=89, name='Node223'),
#  Clade(branch_length=0.0, name='S93'): Clade(branch_length=2.3485e-06, name='Node226'),
#  Clade(branch_length=0.0, name='S174'): Clade(branch_length=2.3485e-06, name='Node226'),
#  Clade(branch_length=0.0643417359, name='S99'): Clade(branch_length=0.0156882566, confidence=76, name='Node237'),
#  Clade(branch_length=0.1232332713, name='S303'): Clade(branch_length=0.0156882566, confidence=76, name='Node237'),
#  Clade(branch_length=0.0147968714, name='S96'): Clade(branch_length=0.0343074759, confidence=100, name='Node240'),
#  Clade(branch_length=0.0172628535, confidence=99, name='Node241'): Clade(branch_length=0.0343074759, confidence=100, name='Node240'),
#  Clade(branch_length=0.1063655738, confidence=100, name='Node243'): Clade(branch_length=0.0127732514, confidence=94, name='Node242'),
#  Clade(branch_length=0.0625151082, name='S344'): Clade(branch_length=0.0127732514, confidence=94, name='Node242'),
#  Clade(branch_length=0.0127417895, confidence=100, name='Node313'): Clade(branch_length=0.0064306785, confidence=100, name='Node312'),
#  Clade(branch_length=0.0094979432, name='S209'): Clade(branch_length=0.0064306785, confidence=100, name='Node312'),
#  Clade(branch_length=0.0258232949, confidence=100, name='Node315'): Clade(branch_length=0.0129535656, confidence=100, name='Node314'),
#  Clade(branch_length=0.0061013149, name='S218'): Clade(branch_length=0.0129535656, confidence=100, name='Node314'),
#  Clade(branch_length=0.0085812908, confidence=98, name='Node136'): Clade(branch_length=0.0284710108, confidence=100, name='Node135'),
#  Clade(branch_length=2.756e-06, name='S336'): Clade(branch_length=0.0284710108, confidence=100, name='Node135'),
#  Clade(branch_length=0.1375488754, name='S107'): Clade(branch_length=0.0665649634, confidence=100, name='Node157'),
#  Clade(branch_length=0.1117712527, name='S108'): Clade(branch_length=0.0665649634, confidence=100, name='Node157'),
#  Clade(branch_length=0.0244597051, confidence=100, name='Node159'): Clade(branch_length=0.1870826393, confidence=100, name='Node158'),
#  Clade(branch_length=0.0105555973, name='S157'): Clade(branch_length=0.1870826393, confidence=100, name='Node158'),
#  Clade(branch_length=2.18e-06, name='S94'): Clade(branch_length=0.0981262691, confidence=100, name='Node224'),
#  Clade(branch_length=2.4008e-06, name='S175'): Clade(branch_length=0.0981262691, confidence=100, name='Node224'),
#  Clade(branch_length=0.0274350788, name='S97'): Clade(branch_length=0.0172628535, confidence=99, name='Node241'),
#  Clade(branch_length=0.07645183, name='S291'): Clade(branch_length=0.0172628535, confidence=99, name='Node241'),
#  Clade(branch_length=1.0017e-06, name='S98'): Clade(branch_length=0.1063655738, confidence=100, name='Node243'),
#  Clade(branch_length=1.0017e-06, name='S172'): Clade(branch_length=0.1063655738, confidence=100, name='Node243'),
#  Clade(branch_length=0.0063137284, name='S203'): Clade(branch_length=0.0127417895, confidence=100, name='Node313'),
#  Clade(branch_length=1.0017e-06, name='S206'): Clade(branch_length=0.0127417895, confidence=100, name='Node313'),
#  Clade(branch_length=0.0062550112, name='S212'): Clade(branch_length=0.0258232949, confidence=100, name='Node315'),
#  Clade(branch_length=2.1328e-06, name='S215'): Clade(branch_length=0.0258232949, confidence=100, name='Node315'),
#  Clade(branch_length=0.0178129685, confidence=100, name='Node137'): Clade(branch_length=0.0085812908, confidence=98, name='Node136'),
#  Clade(branch_length=0.0093015476, name='S337'): Clade(branch_length=0.0085812908, confidence=98, name='Node136'),
#  Clade(branch_length=0.0164209146, name='S155'): Clade(branch_length=0.0244597051, confidence=100, name='Node159'),
#  Clade(branch_length=0.0383535642, name='S301'): Clade(branch_length=0.0244597051, confidence=100, name='Node159'),
#  Clade(branch_length=0.0128164574, confidence=100, name='Node138'): Clade(branch_length=0.0178129685, confidence=100, name='Node137'),
#  Clade(branch_length=0.1022715385, name='S160'): Clade(branch_length=0.0178129685, confidence=100, name='Node137'),
#  Clade(branch_length=0.0031323366, confidence=99, name='Node139'): Clade(branch_length=0.0128164574, confidence=100, name='Node138'),
#  Clade(branch_length=0.0057127311, name='S159'): Clade(branch_length=0.0128164574, confidence=100, name='Node138'),
#  Clade(branch_length=2.1813e-06, name='S158'): Clade(branch_length=0.0031323366, confidence=99, name='Node139'),
#  Clade(branch_length=0.0180829221, name='S161'): Clade(branch_length=0.0031323366, confidence=99, name='Node139')}

# %%
import os
import shutil 
from deepBreaks.preprocessing import read_data

# %%
# defining user params, file pathes, analysis type

#assign your path to folder containing all the datasplits
#path = './vpod_1.1_data_splits_2024-05-02_16-58-09'
# path to sequences of interest
seqFileName = f'wt_aligned_VPOD_1_gap_dropped.fasta' 
tr = read_data(seqFileName, seq_type = 'aa', is_main=True, gap_threshold=1)

sequences = []
with open(seqFileName, 'r') as f:
    x = 0
    seq = ''
    for line in f:
        if '>' in line:
            if x == 0:
                x+=1
            else:
                sequences.append(seq)
                seq = ''
        else:
            seq+=line.strip().replace('\n','')
    sequences.append(seq)

# %%
import pandas as pd

# Define your amino acid alphabet including '-'
amino_acids = list("ACDEFGHIKLMNPQRSTVWY")
amino_acids.append('nan')
# Create a dictionary to map amino acids to their numerical codes
aa_to_code = {aa: i for i, aa in enumerate(amino_acids)}

# Hot encode the DataFrame
for col in tr.columns:
    # Convert amino acids to numerical codes
    tr[col] = tr[col].map(aa_to_code)
    
    # One-hot encode
    #one_hot = pd.get_dummies(tr[col], prefix=col)
    #tr = tr.drop(col, axis=1)  
    #tr = tr.join(one_hot)
tr.fillna(20.0)

# %%
import pymc as pm
import numpy as np
with pm.Model() as model:
    # Define priors for the root of the phylogeny
    root_prior = pm.Normal('root_prior', mu=0, sigma=1)
    
    # Dictionary to hold the nodes in the model
    node_priors = {tree.root.name: root_prior}
    aa_probs = pm.Dirichlet(f"aa_probs", a=np.ones(21)) 

    # Define priors for each node based on its parent
    for clade in tree.find_clades():
        if clade is tree.root:
            pass
        else:
            parent_clade = parent_dict[clade]
            parent_prior = node_priors[parent_clade.name]
            
            # Define the prior for the current node
            node_priors[clade.name] = pm.Normal(clade.name, mu=parent_prior, sigma=1)
    
    # Observed data
        if clade.name in tr:
            #for pos in range(tr.shape[1]):
                #pm.Categorical(name = f'obs_{clade.name}_{tr.columns[pos]}', 
                #                p = aa_probs, observed=tr.loc[clade.name][pos])
            pm.Categorical(name = f'obs_{clade.name}',  
                observed=tr.loc[clade.name])
            
    # Inference
    trace = pm.sample(draws = 2000, tune=1000, cores=8)
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 29
#      25             pm.Categorical(name = f'obs_{clade.name}_{tr.columns[pos]}',
#      26                             p = aa_probs, observed=tr.loc[clade.name][pos])
#      28 # Inference
# ---> 29 trace = pm.sample(draws = 2000, tune=1000, cores=8)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:679, in sample(draws, tune, chains, cores, random_seed, progressbar, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, model, **kwargs)
#     676         auto_nuts_init = False
#     678 initial_points = None
# --> 679 step = assign_step_methods(model, step, methods=pm.STEP_METHODS, step_kwargs=kwargs)
#     681 if nuts_sampler != "pymc":
#     682     if not isinstance(step, NUTS):
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:218, in assign_step_methods(model, step, methods, step_kwargs)
#     216 if has_gradient:
#     217     try:
# --> 218         tg.grad(model_logp, var)  # type: ignore
#     219     except (NotImplementedError, tg.NullTypeGradError):
#     220         has_gradient = False
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:505, in grad(cost, wrt, consider_constant, disconnected_inputs, add_names, known_grads, return_disconnected, null_gradients)
#     502 if known_grads is not None:
#     503     outputs.extend(list(known_grads.keys()))
# --> 505 var_to_app_to_idx = _populate_var_to_app_to_idx(outputs, _wrt, consider_constant)
#     507 # build a dict mapping var to the gradient of cost with respect to var
#     508 grad_dict = {}
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:949, in _populate_var_to_app_to_idx(outputs, wrt, consider_constant)
#     947 # add all variables that are true ancestors of the cost
#     948 for output in outputs:
# --> 949     account_for(output)
#     951 # determine which variables have elements of wrt as a true
#     952 # ancestor. Do this with an upward pass starting from wrt,
#     953 # following only true connections
#     954 visited = set()
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:945, in _populate_var_to_app_to_idx.<locals>.account_for(var)
#     943 if i not in idx:
#     944     idx.append(i)
# --> 945 account_for(ipt)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:945, in _populate_var_to_app_to_idx.<locals>.account_for(var)
#     943 if i not in idx:
#     944     idx.append(i)
# --> 945 account_for(ipt)
#
#     [... skipping similar frames: _populate_var_to_app_to_idx.<locals>.account_for at line 945 (6 times)]
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:945, in _populate_var_to_app_to_idx.<locals>.account_for(var)
#     943 if i not in idx:
#     944     idx.append(i)
# --> 945 account_for(ipt)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:921, in _populate_var_to_app_to_idx.<locals>.account_for(var)
#     918 if var.owner is not None:
#     919     app = var.owner
# --> 921     connection_pattern = _node_to_pattern(app)
#     923     var_idx = app.outputs.index(var)
#     925     for i, ipt in enumerate(app.inputs):
#     926         # don't process ipt if it is not a true
#     927         # parent of var
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\gradient.py:800, in _node_to_pattern(node)
#     793 """given an apply node, obtain its connection pattern
#     794 this is just a wrapper around Op.connection_pattern
#     795 that does type checking and supplies the default value
#     796 if the method is not implemented
#     797 """
#     799 if hasattr(node.op, "connection_pattern"):
# --> 800     connection_pattern = node.op.connection_pattern(node)
#     802     if not isinstance(connection_pattern, list):
#     803         raise TypeError(
#     804             "Op.connection_pattern should return "
#     805             + f"list of list of bool, but for Op={node.op}"
#     806             + f"got {connection_pattern} with type {type(connection_pattern)}."
#     807         )
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\tensor\elemwise.py:533, in Elemwise.connection_pattern(self, node)
#     530 if hasattr(self.scalar_op, "connection_pattern"):
#     531     return self.scalar_op.connection_pattern(node)
# --> 533 return [[True for output in node.outputs] for ipt in node.inputs]
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\tensor\elemwise.py:533, in <listcomp>(.0)
#     530 if hasattr(self.scalar_op, "connection_pattern"):
#     531     return self.scalar_op.connection_pattern(node)
# --> 533 return [[True for output in node.outputs] for ipt in node.inputs]
#
# KeyboardInterrupt:

# %%
import pymc as pm
import ete3
with pm.Model() as model:
    # Define priors for the root of the phylogeny
    root_prior = pm.Normal('root', mu=0, sigma=1)
    
    # Dictionary to hold the nodes in the model
    #node_priors = {clades[0].name: root_prior}
    node_priors = {tree.root.name: root_prior}

    # Define priors for each node based on its parent
    for clade in clades:
        if clade is tree.root:
            pass
        else:
            parent_clade = parent_dict[clade]
            parent_prior = node_priors[parent_clade.name]
            
            # Define the prior for the current node
            node_priors[clade.name] = pm.Normal(clade.name, mu=parent_prior, sigma=1)
        
    # Observed data
    #for clade in clades:
        #if clade.name in tr:
            #for pos in range(tr.shape[1]):
                #pm.Categorical(name = f'obs_{clade.name}_{tr.columns[pos]}', 
                #                p = aa_probs, observed=tr.loc[clade.name][pos])
        #        pm.Categorical(name = f'obs_{clade.name}',  
         #                      observed=tr.loc[clade.name])
    # Inference
    trace2 = pm.sample(draws = 1000, tune=500, cores=8, target_accept=0.95)
# Out:
# c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\tensor\rewriting\elemwise.py:1030: UserWarning: Loop fusion failed because the resulting node would exceed the kernel argument limit.
#   warn(
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\vm.py:406, in Loop.__call__(self)
#     403 for thunk, node, old_storage in zip_longest(
#     404     self.thunks, self.nodes, self.post_thunk_clear, fillvalue=()
#     405 ):
# --> 406     thunk()
#     407     for old_s in old_storage:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\graph\op.py:518, in Op.make_py_thunk.<locals>.rval(p, i, o, n)
#     516 @is_thunk_type
#     517 def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 518     r = p(n, [x[0] for x in i], o)
#     519     for o in node.outputs:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\tensor\elemwise.py:748, in Elemwise.perform(self, node, inputs, output_storage)
#     747     else:
# --> 748         ufunc = node.tag.ufunc
#     749 else:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\graph\utils.py:286, in Scratchpad.__getattribute__(self, name)
#     285 def __getattribute__(self, name):
# --> 286     return super().__getattribute__(name)
#
# AttributeError: 'Scratchpad' object has no attribute 'ufunc'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 31
#      20         node_priors[clade.name] = pm.Normal(clade.name, mu=parent_prior, sigma=1)
#      22 # Observed data
#      23 #for clade in clades:
#      24     #if clade.name in tr:
#    (...)
#      29      #                      observed=tr.loc[clade.name])
#      30 # Inference
# ---> 31 trace2 = pm.sample(draws = 1000, tune=500, cores=8, target_accept=0.95)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:709, in sample(draws, tune, chains, cores, random_seed, progressbar, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, model, **kwargs)
#     707         [kwargs.setdefault(k, v) for k, v in nuts_kwargs.items()]
#     708     _log.info("Auto-assigning NUTS sampler...")
# --> 709     initial_points, step = init_nuts(
#     710         init=init,
#     711         chains=chains,
#     712         n_init=n_init,
#     713         model=model,
#     714         random_seed=random_seed_list,
#     715         progressbar=progressbar,
#     716         jitter_max_retries=jitter_max_retries,
#     717         tune=tune,
#     718         initvals=initvals,
#     719         **kwargs,
#     720     )
#     722 if initial_points is None:
#     723     # Time to draw/evaluate numeric start points for each chain.
#     724     ipfns = make_initial_point_fns_per_chain(
#     725         model=model,
#     726         overrides=initvals,
#     727         jitter_rvs=set(),
#     728         chains=chains,
#     729     )
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:1362, in init_nuts(init, chains, n_init, model, random_seed, progressbar, jitter_max_retries, tune, initvals, **kwargs)
#    1355 _log.info(f"Initializing NUTS using {init}...")
#    1357 cb = [
#    1358     pm.callbacks.CheckParametersConvergence(tolerance=1e-2, diff="absolute"),
#    1359     pm.callbacks.CheckParametersConvergence(tolerance=1e-2, diff="relative"),
#    1360 ]
# -> 1362 initial_points = _init_jitter(
#    1363     model,
#    1364     initvals,
#    1365     seeds=random_seed_list,
#    1366     jitter="jitter" in init,
#    1367     jitter_max_retries=jitter_max_retries,
#    1368 )
#    1370 apoints = [DictToArrayBijection.map(point) for point in initial_points]
#    1371 apoints_data = [apoint.data for apoint in apoints]
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:1253, in _init_jitter(model, initvals, seeds, jitter, jitter_max_retries)
#    1251 rng = np.random.RandomState(seed)
#    1252 for i in range(jitter_max_retries + 1):
# -> 1253     point = ipfn(seed)
#    1254     if i < jitter_max_retries:
#    1255         try:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\initial_point.py:170, in make_initial_point_fn.<locals>.make_seeded_function.<locals>.inner(seed, *args, **kwargs)
#     167 @functools.wraps(func)
#     168 def inner(seed, *args, **kwargs):
#     169     reseed_rngs(rngs, seed)
# --> 170     values = func(*args, **kwargs)
#     171     return dict(zip(varnames, values))
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\compile\function\types.py:970, in Function.__call__(self, *args, **kwargs)
#     967 t0_fn = time.perf_counter()
#     968 try:
#     969     outputs = (
# --> 970         self.vm()
#     971         if output_subset is None
#     972         else self.vm(output_subset=output_subset)
#     973     )
#     974 except Exception:
#     975     restore_defaults()
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\vm.py:410, in Loop.__call__(self)
#     408                 old_s[0] = None
#     409     except Exception:
# --> 410         raise_with_op(self.fgraph, node, thunk)
#     412 return self.perform_updates()
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\utils.py:531, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     526     warnings.warn(
#     527         f"{exc_type} error does not allow us to add an extra error message"
#     528     )
#     529     # Some exception need extra parameter in inputs. So forget the
#     530     # extra long error message in that case.
# --> 531 raise exc_value.with_traceback(exc_trace)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\vm.py:406, in Loop.__call__(self)
#     402 try:
#     403     for thunk, node, old_storage in zip_longest(
#     404         self.thunks, self.nodes, self.post_thunk_clear, fillvalue=()
#     405     ):
# --> 406         thunk()
#     407         for old_s in old_storage:
#     408             old_s[0] = None
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\graph\op.py:518, in Op.make_py_thunk.<locals>.rval(p, i, o, n)
#     516 @is_thunk_type
#     517 def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 518     r = p(n, [x[0] for x in i], o)
#     519     for o in node.outputs:
#     520         compute_map[o][0] = True
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\tensor\elemwise.py:748, in Elemwise.perform(self, node, inputs, output_storage)
#     746         ufunc = self.ufunc
#     747     else:
# --> 748         ufunc = node.tag.ufunc
#     749 else:
#     750     ufunc = node.tag.ufunc
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\graph\utils.py:286, in Scratchpad.__getattribute__(self, name)
#     285 def __getattribute__(self, name):
# --> 286     return super().__getattribute__(name)
#
# AttributeError: 'Scratchpad' object has no attribute 'ufunc'
# Apply node that caused the error: Add(root_jitter, Node2_jitter, Node3_jitter, Node4_jitter, Node5_jitter, Node86_jitter, Node89_jitter, Node90_jitter, Node91_jitter, Node92_jitter, Node93_jitter, Node94_jitter, Node95_jitter, Node96_jitter, Node97_jitter, Node122_jitter, Node123_jitter, Node124_jitter, Node125_jitter, Node126_jitter, Node127_jitter, Node128_jitter, Node129_jitter, Node130_jitter, Node131_jitter, Node132_jitter, Node134_jitter, Node135_jitter, Node136_jitter, Node137_jitter, Node138_jitter, Node139_jitter)
# Toposort index: 1436
# Inputs types: [TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=())]
# Inputs shapes: [(), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), ()]
# Inputs strides: [(), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), (), ()]
# Inputs values: [array(0.87712358), array(0.04512234), array(0.2767082), array(-0.8422431), array(-0.73928787), array(-0.73794746), array(0.33479769), array(0.60874361), array(-0.36545198), array(-0.64621179), array(-0.91520799), array(0.115159), array(0.29096329), array(-0.01434334), array(-0.62251574), array(-0.44300901), array(0.97317872), array(0.30005434), array(0.84251319), array(-0.33996592), array(-0.80177847), array(0.58282157), array(0.08027265), array(0.00617958), array(-0.03374552), array(0.52281789), array(-0.35038642), array(-0.98016791), array(-0.14476924), array(-0.16691221), array(-0.27111873), array(-0.34098217)]
# Outputs clients: [['output']]
#
# HINT: Re-running with most PyTensor optimizations disabled could provide a back-trace showing when this node was created. This can be done by setting the PyTensor flag 'optimizer=fast_compile'. If that does not work, PyTensor optimizations can be disabled with 'optimizer=None'.
# HINT: Use the PyTensor flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
# Rename nodes (optional, but recommended for robustness)
name_counts = {}  # To track duplicate names
for i, node in enumerate(tree.traverse()):
    original_name = node.name
    if original_name.isdigit(): # Rename nodes with only digits
        node.name = f"Node_{original_name}" 
    else:  # Keep names with non-digit characters
        if original_name in name_counts:
            name_counts[original_name] += 1
            node.name = f"{original_name}_{name_counts[original_name]}"
        else:
            name_counts[original_name] = 0

# %%
import pymc as pm
import numpy as np
import ete3

# ... (Load your phylogenetic tree data into an ete3.Tree object)

with pm.Model() as model:
    # Root prior (adjust as needed)
    root_prior = pm.Normal('root', mu=0, sigma=1) 
    node_priors = {} # Store the priors of all nodes
    aa_probs = pm.Dirichlet(f"aa_probs", a=np.ones(21)) 

    # Iterate over nodes in postorder and define priors and likelihood
    for node in tree.traverse("postorder"):
        name = node.name
        parent_name = node.up.name if node.up else None

        if parent_name:
            if parent_name not in node_priors:  
                # Ensure parent node's prior is defined
                node_priors[parent_name] = pm.Normal(parent_name, mu=root_prior, sigma=1) 
            if name not in node_priors:  
                node_priors[name] = pm.Normal(name, mu=node_priors[parent_name], sigma=1)
                #aa_probs = pm.Dirichlet(f"aa_probs_{name}", a=np.ones(21)) 
        else:
            node_priors[name] = root_prior
            #aa_probs = pm.Dirichlet(f"aa_probs_{name}", a=np.ones(21)) 

        # Dirichlet prior for amino acid probabilities at each node (Adjust concentration parameter as needed)
            
        
        # Likelihood (assuming your sequences are aligned and encoded as integers)
        if name in tr:
            for pos in range(tr.shape[1]):
                pm.Categorical(f"obs_{name}_{pos}", p=aa_probs, observed=tr.loc[name][pos])

    # Inference
    trace = pm.sample(draws=2000, tune=1000, cores=8, target_accept=0.95)
# Out:
# You can find the C code in this temporary file: C:\Users\safra\AppData\Local\Temp\pytensor_compilation_error_k8v1o6cg
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\vm.py:1235, in VMLinker.make_all(self, profiler, input_storage, output_storage, storage_map)
#    1231 # no-recycling is done at each VM.__call__ So there is
#    1232 # no need to cause duplicate c code by passing
#    1233 # no_recycling here.
#    1234 thunks.append(
# -> 1235     node.op.make_thunk(node, storage_map, compute_map, [], impl=impl)
#    1236 )
#    1237 linker_make_thunk_time[node] = time.perf_counter() - thunk_start
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\op.py:119, in COp.make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     118 try:
# --> 119     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#     120 except (NotImplementedError, MethodNotDefined):
#     121     # We requested the c code, so don't catch the error.
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\op.py:84, in COp.make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#      83         raise NotImplementedError("float16")
# ---> 84 outputs = cl.make_thunk(
#      85     input_storage=node_input_storage, output_storage=node_output_storage
#      86 )
#      87 thunk, node_input_filters, node_output_filters = outputs
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1189, in CLinker.make_thunk(self, input_storage, output_storage, storage_map, cache, **kwargs)
#    1188 init_tasks, tasks = self.get_init_tasks()
# -> 1189 cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1190     input_storage, output_storage, storage_map, cache
#    1191 )
#    1193 res = _CThunk(cthunk, init_tasks, tasks, error_storage, module)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1109, in CLinker.__compile__(self, input_storage, output_storage, storage_map, cache)
#    1108 output_storage = tuple(output_storage)
# -> 1109 thunk, module = self.cthunk_factory(
#    1110     error_storage,
#    1111     input_storage,
#    1112     output_storage,
#    1113     storage_map,
#    1114     cache,
#    1115 )
#    1116 return (
#    1117     thunk,
#    1118     module,
#    (...)
#    1127     error_storage,
#    1128 )
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1631, in CLinker.cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, cache)
#    1630         cache = get_module_cache()
# -> 1631     module = cache.module_from_key(key=key, lnk=self)
#    1633 vars = self.inputs + self.outputs + self.orphans
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\cmodule.py:1231, in ModuleCache.module_from_key(self, key, lnk)
#    1230 location = dlimport_workdir(self.dirname)
# -> 1231 module = lnk.compile_cmodule(location)
#    1232 name = module.__file__
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1532, in CLinker.compile_cmodule(self, location)
#    1531     _logger.debug(f"LOCATION {location}")
# -> 1532     module = c_compiler.compile_str(
#    1533         module_name=mod.code_hash,
#    1534         src_code=src_code,
#    1535         location=location,
#    1536         include_dirs=self.header_dirs(),
#    1537         lib_dirs=self.lib_dirs(),
#    1538         libs=libs,
#    1539         preargs=preargs,
#    1540     )
#    1541 except Exception as e:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\cmodule.py:2639, in GCC_compiler.compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2635     # We replace '\n' by '. ' in the error message because when Python
#    2636     # prints the exception, having '\n' in the text makes it more
#    2637     # difficult to read.
#    2638     # compile_stderr = compile_stderr.replace("\n", ". ")
# -> 2639     raise CompileError(
#    2640         f"Compilation failed (return status={status}):\n{' '.join(cmd)}\n{compile_stderr}"
#    2641     )
#    2642 elif config.cmodule__compilation_warning and compile_stderr:
#    2643     # Print errors just below the command line.
#
# CompileError: Compilation failed (return status=1):
# "C:\Users\safra\anaconda3\envs\deepBreaks\Library\mingw-w64\bin\g++.exe" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=bdver4 -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -msse4a -mcx16 -msahf -mmovbe -maes -msha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mno-rtm -mno-hle -mrdrnd -mf16c -mfsgsbase -mrdseed -mprfchw -madx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mclflushopt -mxsavec -mxsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mclwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=bdver4 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\numpy\core\include" -I"c:\Users\safra\anaconda3\envs\deepBreaks\include" -I"c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\safra\anaconda3\envs\deepBreaks\libs" -L"c:\Users\safra\anaconda3\envs\deepBreaks" -o "C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\m6f8bc7fe716ef31363fbaefa07497cc1e412bb3ab6244162223af9a5674b6307.pyd" "C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\mod.cpp" "c:\Users\safra\anaconda3\envs\deepBreaks\python39.dll"
# C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\mod.cpp: In member function 'int {anonymous}::__struct_compiled_op_m6f8bc7fe716ef31363fbaefa07497cc1e412bb3ab6244162223af9a5674b6307::run()':
# C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\mod.cpp:138818:9: internal compiler error: Segmentation fault
#          }
#          ^
# libbacktrace could not find executable to open
# Please submit a full bug report,
# with preprocessed source if appropriate.
# See <https://sourceforge.net/projects/msys2> for instructions.
#
#
# During handling of the above exception, another exception occurred:
#
# CompileError                              Traceback (most recent call last)
# Cell In[30], line 39
#      36             pm.Categorical(f"obs_{name}_{pos}", p=aa_probs, observed=tr.loc[name][pos])
#      38 # Inference
# ---> 39 trace = pm.sample(draws=2000, tune=1000, cores=8, target_accept=0.95)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:679, in sample(draws, tune, chains, cores, random_seed, progressbar, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, model, **kwargs)
#     676         auto_nuts_init = False
#     678 initial_points = None
# --> 679 step = assign_step_methods(model, step, methods=pm.STEP_METHODS, step_kwargs=kwargs)
#     681 if nuts_sampler != "pymc":
#     682     if not isinstance(step, NUTS):
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:232, in assign_step_methods(model, step, methods, step_kwargs)
#     224         selected = max(
#     225             methods_list,
#     226             key=lambda method, var=rv_var, has_gradient=has_gradient: method._competence(  # type: ignore
#     227                 var, has_gradient
#     228             ),
#     229         )
#     230         selected_steps.setdefault(selected, []).append(var)
# --> 232 return instantiate_steppers(model, steps, selected_steps, step_kwargs)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\sampling\mcmc.py:133, in instantiate_steppers(model, steps, selected_steps, step_kwargs)
#     131         args = step_kwargs.get(name, {})
#     132         used_keys.add(name)
# --> 133         step = step_class(vars=vars, model=model, **args)
#     134         steps.append(step)
#     136 unused_args = set(step_kwargs).difference(used_keys)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\step_methods\hmc\nuts.py:180, in NUTS.__init__(self, vars, max_treedepth, early_max_treedepth, **kwargs)
#     122 def __init__(self, vars=None, max_treedepth=10, early_max_treedepth=8, **kwargs):
#     123     r"""Set up the No-U-Turn sampler.
#     124
#     125     Parameters
#    (...)
#     178     `pm.sample` to the desired number of tuning steps.
#     179     """
# --> 180     super().__init__(vars, **kwargs)
#     182     self.max_treedepth = max_treedepth
#     183     self.early_max_treedepth = early_max_treedepth
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\step_methods\hmc\base_hmc.py:109, in BaseHMC.__init__(self, vars, scaling, step_scale, is_cov, model, blocked, potential, dtype, Emax, target_accept, gamma, k, t0, adapt_step_size, step_rand, **pytensor_kwargs)
#     107 else:
#     108     vars = get_value_vars_from_user_vars(vars, self._model)
# --> 109 super().__init__(vars, blocked=blocked, model=self._model, dtype=dtype, **pytensor_kwargs)
#     111 self.adapt_step_size = adapt_step_size
#     112 self.Emax = Emax
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\step_methods\arraystep.py:162, in GradientSharedStep.__init__(self, vars, model, blocked, dtype, logp_dlogp_func, **pytensor_kwargs)
#     159 model = modelcontext(model)
#     161 if logp_dlogp_func is None:
# --> 162     func = model.logp_dlogp_function(vars, dtype=dtype, **pytensor_kwargs)
#     163 else:
#     164     func = logp_dlogp_func
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\model\core.py:608, in Model.logp_dlogp_function(self, grad_vars, tempered, **kwargs)
#     602 ip = self.initial_point(0)
#     603 extra_vars_and_values = {
#     604     var: ip[var.name]
#     605     for var in self.value_vars
#     606     if var in input_vars and var not in grad_vars
#     607 }
# --> 608 return ValueGradFunction(costs, grad_vars, extra_vars_and_values, **kwargs)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\model\core.py:342, in ValueGradFunction.__init__(self, costs, grad_vars, extra_vars_and_values, dtype, casting, compute_grads, **kwargs)
#     338     outputs = [cost]
#     340 inputs = grad_vars
# --> 342 self._pytensor_function = compile_pymc(inputs, outputs, givens=givens, **kwargs)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pymc\pytensorf.py:985, in compile_pymc(inputs, outputs, random_seed, mode, **kwargs)
#     983 opt_qry = mode.provided_optimizer.including("random_make_inplace", check_parameter_opt)
#     984 mode = Mode(linker=mode.linker, optimizer=opt_qry)
# --> 985 pytensor_function = pytensor.function(
#     986     inputs,
#     987     outputs,
#     988     updates={**rng_updates, **kwargs.pop("updates", {})},
#     989     mode=mode,
#     990     **kwargs,
#     991 )
#     992 return pytensor_function
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\compile\function\__init__.py:315, in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     309     fn = orig_function(
#     310         inputs, outputs, mode=mode, accept_inplace=accept_inplace, name=name
#     311     )
#     312 else:
#     313     # note: pfunc will also call orig_function -- orig_function is
#     314     #      a choke point that all compilation must pass through
# --> 315     fn = pfunc(
#     316         params=inputs,
#     317         outputs=outputs,
#     318         mode=mode,
#     319         updates=updates,
#     320         givens=givens,
#     321         no_default_updates=no_default_updates,
#     322         accept_inplace=accept_inplace,
#     323         name=name,
#     324         rebuild_strict=rebuild_strict,
#     325         allow_input_downcast=allow_input_downcast,
#     326         on_unused_input=on_unused_input,
#     327         profile=profile,
#     328         output_keys=output_keys,
#     329     )
#     330 return fn
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\compile\function\pfunc.py:469, in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys, fgraph)
#     455     profile = ProfileStats(message=profile)
#     457 inputs, cloned_outputs = construct_pfunc_ins_and_outs(
#     458     params,
#     459     outputs,
#    (...)
#     466     fgraph=fgraph,
#     467 )
# --> 469 return orig_function(
#     470     inputs,
#     471     cloned_outputs,
#     472     mode,
#     473     accept_inplace=accept_inplace,
#     474     name=name,
#     475     profile=profile,
#     476     on_unused_input=on_unused_input,
#     477     output_keys=output_keys,
#     478     fgraph=fgraph,
#     479 )
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\compile\function\types.py:1762, in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys, fgraph)
#    1750     m = Maker(
#    1751         inputs,
#    1752         outputs,
#    (...)
#    1759         fgraph=fgraph,
#    1760     )
#    1761     with config.change_flags(compute_test_value="off"):
# -> 1762         fn = m.create(defaults)
#    1763 finally:
#    1764     if profile and fn:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\compile\function\types.py:1654, in FunctionMaker.create(self, input_storage, storage_map)
#    1651 start_import_time = pytensor.link.c.cmodule.import_time
#    1653 with config.change_flags(traceback__limit=config.traceback__compile_limit):
# -> 1654     _fn, _i, _o = self.linker.make_thunk(
#    1655         input_storage=input_storage_lists, storage_map=storage_map
#    1656     )
#    1658 end_linker = time.perf_counter()
#    1660 linker_time = end_linker - start_linker
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\basic.py:245, in LocalLinker.make_thunk(self, input_storage, output_storage, storage_map, **kwargs)
#     238 def make_thunk(
#     239     self,
#     240     input_storage: Optional["InputStorageType"] = None,
#    (...)
#     243     **kwargs,
#     244 ) -> tuple["BasicThunkType", "InputStorageType", "OutputStorageType"]:
# --> 245     return self.make_all(
#     246         input_storage=input_storage,
#     247         output_storage=output_storage,
#     248         storage_map=storage_map,
#     249     )[:3]
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\vm.py:1244, in VMLinker.make_all(self, profiler, input_storage, output_storage, storage_map)
#    1242             thunks[-1].lazy = False
#    1243     except Exception:
# -> 1244         raise_with_op(fgraph, node)
#    1246 t1 = time.perf_counter()
#    1248 if self.profile:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\utils.py:531, in raise_with_op(fgraph, node, thunk, exc_info, storage_map)
#     526     warnings.warn(
#     527         f"{exc_type} error does not allow us to add an extra error message"
#     528     )
#     529     # Some exception need extra parameter in inputs. So forget the
#     530     # extra long error message in that case.
# --> 531 raise exc_value.with_traceback(exc_trace)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\vm.py:1235, in VMLinker.make_all(self, profiler, input_storage, output_storage, storage_map)
#    1230 thunk_start = time.perf_counter()
#    1231 # no-recycling is done at each VM.__call__ So there is
#    1232 # no need to cause duplicate c code by passing
#    1233 # no_recycling here.
#    1234 thunks.append(
# -> 1235     node.op.make_thunk(node, storage_map, compute_map, [], impl=impl)
#    1236 )
#    1237 linker_make_thunk_time[node] = time.perf_counter() - thunk_start
#    1238 if not hasattr(thunks[-1], "lazy"):
#    1239     # We don't want all ops maker to think about lazy Ops.
#    1240     # So if they didn't specify that its lazy or not, it isn't.
#    1241     # If this member isn't present, it will crash later.
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\op.py:119, in COp.make_thunk(self, node, storage_map, compute_map, no_recycling, impl)
#     115 self.prepare_node(
#     116     node, storage_map=storage_map, compute_map=compute_map, impl="c"
#     117 )
#     118 try:
# --> 119     return self.make_c_thunk(node, storage_map, compute_map, no_recycling)
#     120 except (NotImplementedError, MethodNotDefined):
#     121     # We requested the c code, so don't catch the error.
#     122     if impl == "c":
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\op.py:84, in COp.make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#      82         print(f"Disabling C code for {self} due to unsupported float16")
#      83         raise NotImplementedError("float16")
# ---> 84 outputs = cl.make_thunk(
#      85     input_storage=node_input_storage, output_storage=node_output_storage
#      86 )
#      87 thunk, node_input_filters, node_output_filters = outputs
#      89 @is_cthunk_wrapper_type
#      90 def rval():
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1189, in CLinker.make_thunk(self, input_storage, output_storage, storage_map, cache, **kwargs)
#    1154 """Compile this linker's `self.fgraph` and return a function that performs the computations.
#    1155
#    1156 The return values can be used as follows:
#    (...)
#    1186
#    1187 """
#    1188 init_tasks, tasks = self.get_init_tasks()
# -> 1189 cthunk, module, in_storage, out_storage, error_storage = self.__compile__(
#    1190     input_storage, output_storage, storage_map, cache
#    1191 )
#    1193 res = _CThunk(cthunk, init_tasks, tasks, error_storage, module)
#    1194 res.nodes = self.node_order
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1109, in CLinker.__compile__(self, input_storage, output_storage, storage_map, cache)
#    1107 input_storage = tuple(input_storage)
#    1108 output_storage = tuple(output_storage)
# -> 1109 thunk, module = self.cthunk_factory(
#    1110     error_storage,
#    1111     input_storage,
#    1112     output_storage,
#    1113     storage_map,
#    1114     cache,
#    1115 )
#    1116 return (
#    1117     thunk,
#    1118     module,
#    (...)
#    1127     error_storage,
#    1128 )
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1631, in CLinker.cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, cache)
#    1629     if cache is None:
#    1630         cache = get_module_cache()
# -> 1631     module = cache.module_from_key(key=key, lnk=self)
#    1633 vars = self.inputs + self.outputs + self.orphans
#    1634 # List of indices that should be ignored when passing the arguments
#    1635 # (basically, everything that the previous call to uniq eliminated)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\cmodule.py:1231, in ModuleCache.module_from_key(self, key, lnk)
#    1229 try:
#    1230     location = dlimport_workdir(self.dirname)
# -> 1231     module = lnk.compile_cmodule(location)
#    1232     name = module.__file__
#    1233     assert name.startswith(location)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\basic.py:1532, in CLinker.compile_cmodule(self, location)
#    1530 try:
#    1531     _logger.debug(f"LOCATION {location}")
# -> 1532     module = c_compiler.compile_str(
#    1533         module_name=mod.code_hash,
#    1534         src_code=src_code,
#    1535         location=location,
#    1536         include_dirs=self.header_dirs(),
#    1537         lib_dirs=self.lib_dirs(),
#    1538         libs=libs,
#    1539         preargs=preargs,
#    1540     )
#    1541 except Exception as e:
#    1542     e.args += (str(self.fgraph),)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\cmodule.py:2639, in GCC_compiler.compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module, hide_symbols)
#    2631                 print(
#    2632                     "Check if package python-dev or python-devel is installed."
#    2633                 )
#    2635     # We replace '\n' by '. ' in the error message because when Python
#    2636     # prints the exception, having '\n' in the text makes it more
#    2637     # difficult to read.
#    2638     # compile_stderr = compile_stderr.replace("\n", ". ")
# -> 2639     raise CompileError(
#    2640         f"Compilation failed (return status={status}):\n{' '.join(cmd)}\n{compile_stderr}"
#    2641     )
#    2642 elif config.cmodule__compilation_warning and compile_stderr:
#    2643     # Print errors just below the command line.
#    2644     print(compile_stderr)
#
# CompileError: Compilation failed (return status=1):
# "C:\Users\safra\anaconda3\envs\deepBreaks\Library\mingw-w64\bin\g++.exe" -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wno-c++11-narrowing -fno-exceptions -fno-unwind-tables -fno-asynchronous-unwind-tables -march=bdver4 -mmmx -mno-3dnow -msse -msse2 -msse3 -mssse3 -msse4a -mcx16 -msahf -mmovbe -maes -msha -mpclmul -mpopcnt -mabm -mno-lwp -mfma -mno-fma4 -mno-xop -mbmi -mbmi2 -mno-tbm -mavx -mavx2 -msse4.2 -msse4.1 -mlzcnt -mno-rtm -mno-hle -mrdrnd -mf16c -mfsgsbase -mrdseed -mprfchw -madx -mfxsr -mxsave -mxsaveopt -mno-avx512f -mno-avx512er -mno-avx512cd -mno-avx512pf -mno-prefetchwt1 -mclflushopt -mxsavec -mxsaves -mno-avx512dq -mno-avx512bw -mno-avx512vl -mno-avx512ifma -mno-avx512vbmi -mclwb -mno-pcommit -mno-mwaitx --param l1-cache-size=32 --param l1-cache-line-size=64 --param l2-cache-size=512 -mtune=bdver4 -DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -DMS_WIN64 -I"c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\numpy\core\include" -I"c:\Users\safra\anaconda3\envs\deepBreaks\include" -I"c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\pytensor\link\c\c_code" -L"c:\Users\safra\anaconda3\envs\deepBreaks\libs" -L"c:\Users\safra\anaconda3\envs\deepBreaks" -o "C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\m6f8bc7fe716ef31363fbaefa07497cc1e412bb3ab6244162223af9a5674b6307.pyd" "C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\mod.cpp" "c:\Users\safra\anaconda3\envs\deepBreaks\python39.dll"
# C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\mod.cpp: In member function 'int {anonymous}::__struct_compiled_op_m6f8bc7fe716ef31363fbaefa07497cc1e412bb3ab6244162223af9a5674b6307::run()':
# C:\Users\safra\AppData\Local\PyTensor\compiledir_Windows-10-10.0.19045-SP0-AMD64_Family_23_Model_96_Stepping_1_AuthenticAMD-3.9.17-64\tmp5l9fls0t\mod.cpp:138818:9: internal compiler error: Segmentation fault
#          }
#          ^
# libbacktrace could not find executable to open
# Please submit a full bug report,
# with preprocessed source if appropriate.
# See <https://sourceforge.net/projects/msys2> for instructions.
#
# Apply node that caused the error: Composite{...}(Sum{axes=None}.0, max, 21.0, -380.1528459086232, -0.5, S349, Node_93, S302, Node_100, S348, Node_77, S103, Node_74, S101, S102, S72, S194, Node_96, S105, S104, S106, S61, S245, Node_97, S187, S117, S243, S118, S116, S342, S307, S306, S305, S304, S68, Node_50, root, S115, S114, S113, S112, S40, Node_56, Node_52, S351, S350, S259, S170, S82, S246, S247, S260, S248, S249, S250, S251, Node_99, S242, S120, S241, S119, S235, S80, S234, S79, S233, S78, S232, S77, S252, S255, S332, Node_98, S237, Node_87, S333, S236, S340, Node_86, S211, S217, S214, S218, S215, S212, S209, S206, S203, S208, S205, S202, S162, Node_83, S253, Node_40, S254, S331, S238, S216, S213, S210, Node_51, S163, Node_90, S207, S204, S201, S75, S256, Node_47, S258, S257, S124, S244, Node_91, S125, Node_65, S188, Node_66, S123, S121, S76, Node_48, S122, S74, S171, S169, S131, S190, S132, S130, S129, S231, S229, S230, S128, S225, S329, S239, S220, S226, S228, S224, S165, S227, S223, S164, S330, S222, Node_75, S221, S219, S109, S84, S261, S168, S262, S264, S345, S100, S322, Node_58, S323, S320, Node_84, S267, Node_78, S344, Node_94, S172, S98, S291, S97, S96, S197, S303, Node_76, S99, S181, S95, S265, S268, S266, S292, S152, S92, S127, S174, _2, S93, S189, Node_89, S175, S94, S173, S91, S343, S90, S176, S89, S88, S263, S87, S321, S326, S339, Node_92, S324, S328, S240, S335, Node_41, S325, S166, S86, S126, S327, _1, S85, S151, S150, S182, S314, S352, S353, S196, S195, S318, S317, S315, S274, S273, S275, S272, S270, S156, S316, S313, S185, S184, S199, Node_95, S200, S198, S154, S153, S347, S319, S354, S183, S355, S294, S293, S296, S295, S279, S277, S278, S276, S271, S300, S299, S298, S297, S157, S301, S155, S108, S107, S346, S341, S308, S134, S136, S137, S186, S135, S286, Node_44, S282, Node_71, S281, S280, S287, S334, S336, S337, S160, S159, S161, S158, S133, S83, S81, S284, S139, S289, S312, S311, S310, S309, S138, Node_85, S283, S285, S149, Node_53, S143, S142, Node_69, S288, Node_67, S290, S148, Node_80, S141, Node_45, S269, S193, Node_49, S145, S146, S147, S140, S144, S73, S180, S178, S60, S48, S49, S192, Node_60, S69, S52, S59, S51, S50, Node_55, S179, S177, S110, S70, Node_33, S360, S361, S359, S358, S357, S191, Node_61, S338, S167, S111, S71, S62, S54, S356, Node_82, S65, Node_81, S66, S67, S56, S64, S58, S63, S57, S55, S53, S39, S33, Node_64, S32, S30, S21, S20, Node_79, S25, S35, S34, S16, S28, S26, S22, S15, Node_57, S43, S38, S37, S27, S36, S29, S24, S13, Node_72, S31, S23, S46, S47, S44, S42, S41, S19, S18, S17, Node_63, S45, S14, S12, S11, S10, S7, S6, S5, S9, S8, S3, S4, Node_73, S2, S1, Sum{axes=None}.0, -inf, 42.335616460753485, Sum{axes=None}.0, Any{axis=0}.0, Any{axis=0}.0)
# Toposort index: 28
# Inputs types: [TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float64, shape=()), TensorType(float6 ...
#
# HINT: Use a linker other than the C linker to print the inputs' shapes and strides.
# HINT: Re-running with most PyTensor optimizations disabled could provide a back-trace showing when this node was created. This can be done by setting the PyTensor flag 'optimizer=fast_compile'. If that does not work, PyTensor optimizations can be disabled with 'optimizer=None'.
# HINT: Use the PyTensor flag `exception_verbosity=high` for a debug print-out and storage map footprint of this Apply node.

# %%
import arviz as az
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=300)
az.plot_trace(trace)
plt.subplots_adjust(hspace=0.35)

plt.show()

# %%
trace
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats

# %%
print(trace.posterior.data_vars)
# Out:
# Data variables:
#     root_prior  (chain, draw) float64 128kB -0.6581 0.1451 ... -2.027 -1.74
#     aa_probs    (chain, draw, aa_probs_dim_0) float64 256kB 0.2037 ... 0.1292

# %%
position_to_analyze = 1600
posterior_aa_probs_at_pos5 = trace.posterior['aa_probs'][:, position_to_analyze]

# %%
posterior_aa_probs_at_pos5
# Out:
# <xarray.DataArray 'aa_probs' (chain: 8, aa_probs_dim_0: 2)> Size: 128B
# array([[0.75342953, 0.24657047],
#        [0.86921336, 0.13078664],
#        [0.85455149, 0.14544851],
#        [0.4342834 , 0.5657166 ],
#        [0.26017936, 0.73982064],
#        [0.76743594, 0.23256406],
#        [0.83596601, 0.16403399],
#        [0.51047901, 0.48952099]])
# Coordinates:
#   * chain           (chain) int32 32B 0 1 2 3 4 5 6 7
#     draw            int32 4B 1600
#   * aa_probs_dim_0  (aa_probs_dim_0) int32 8B 0 1

# %%
az.plot_posterior(posterior_aa_probs_at_pos5, hdi_prob=0.95)
# Out:
# array([<Axes: title={'center': 'aa_probs\n0'}>,
#        <Axes: title={'center': 'aa_probs\n1'}>], dtype=object)

# %%
posterior_aa_probs_at_pos5[1]
# Out:
# <xarray.DataArray 'aa_probs' (aa_probs_dim_0: 2)> Size: 16B
# array([0.44232643, 0.55767357])
# Coordinates:
#     chain           int32 4B 1
#     draw            int32 4B 352
#   * aa_probs_dim_0  (aa_probs_dim_0) int32 8B 0 1

# %%
relevant_samples_for_clade
# Out:
# <xarray.DataArray 'aa_probs' (aa_probs_dim_0: 2)> Size: 16B
# array([0.08672269, 0.91327731])
# Coordinates:
#     chain           int32 4B 0
#     draw            int32 4B 352
#   * aa_probs_dim_0  (aa_probs_dim_0) int32 8B 0 1

# %%
az.plot_posterior(trace)
plt.show()

# %%
with model:
    ppc = pm.sample_posterior_predictive(trace)

# %%
inference_data  = az.from_pymc(trace = trace, posterior_predictive=ppc, model=model)
az.plot_ppc(ppc)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 az.plot_ppc(ppc)
#       3 plt.show()
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\site-packages\arviz\plots\ppcplot.py:226, in plot_ppc(data, kind, alpha, mean, observed, observed_rug, color, colors, grid, figsize, textsize, data_pairs, var_names, filter_vars, coords, flatten, flatten_pp, num_pp_samples, random_seed, jitter, animated, animation_kwargs, legend, labeller, ax, backend, backend_kwargs, group, show)
#     224 for groups in (f"{group}_predictive", "observed_data"):
#     225     if not hasattr(data, groups):
# --> 226         raise TypeError(f'`data` argument must have the group "{groups}" for ppcplot')
#     228 if kind.lower() not in ("kde", "cumulative", "scatter"):
#     229     raise TypeError("`kind` argument must be either `kde`, `cumulative`, or `scatter`")
#
# TypeError: `data` argument must have the group "posterior_predictive" for ppcplot
